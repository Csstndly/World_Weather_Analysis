# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import o_weather
import requests
import gmaps
from scipy.stats import linregress
from datetime import datetime
from config import g_maps_key
gmaps.configure(api_key=g_maps_key)
from citipy import citipy

# %%
# Starting URL for Weather Map API Call. 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + o_weather

# %%
#Create a new set of 2,000 random latitudes and longitudes.lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
#Create a empty list for df
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters./ want the 1st iteration of the logging for each recorded response
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Looping through every city in the list 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description":city_descr })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 40 of Set 43 | jamestown
# Processing Record 41 of Set 43 | atuona
# Processing Record 42 of Set 43 | vila velha
# Processing Record 43 of Set 43 | paita
# Processing Record 44 of Set 43 | souillac
# Processing Record 45 of Set 43 | aswan
# Processing Record 46 of Set 43 | san jose de rio tinto
# Processing Record 47 of Set 43 | saint-philippe
# Processing Record 48 of Set 43 | puerto ayora
# Processing Record 49 of Set 43 | nikolskoye
# Processing Record 50 of Set 43 | georgetown
# Processing Record 51 of Set 43 | sarangani
# Processing Record 52 of Set 43 | cayenne
# Processing Record 53 of Set 43 | bambous virieux
# Processing Record 54 of Set 43 | ushuaia
# Processing Record 55 of Set 43 | aripuana
# Processing Record 56 of Set 43 | mar del plata
# Processing Record 57 of Set 43 | tapayan
# Processing Record 58 of Set 43 | japura
# Processing Record 59 of Set 43 | busselton
# Processing Record 60 of Set 43 | punta arenas
# Processing Record 61 of Set 43 | butaritari
# Processing Record 62 of Set 43 | samusu
# City not found. Skipping...
# Processing Record 63 of Set 43 | zapolyarnyy
# Processing Record 64 of Set 43 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 65 of Set 43 | porto santo
# Processing Record 66 of Set 43 | dikson
# Processing Record 67 of Set 43 | bredasdorp
# Processing Record 68 of Set 43 | kapaa
# Processing Record 69 of Set 43 | hermanus
# Processing Record 70 of Set 43 | cabo san lucas
# Processing Record 71 of Set 43 | grindavik
# Processing Record 72 of Set 43 | barrow
# Processing Record 73 of Set 43 | provideniya
# Processing Record 74 of Set 43 | thompson
# Processing Record 75 of Set 43 | severo-kurilsk
# Processing Record 76 of Set 43 | rikitea
# Processing Record 77 of Set 43 | phan rang
# City not found. Skipping...
# Processing Record 78 of Set 43 | san cristobal
# Processing Record 79 of Set 43 | ust-nera
# Processing Record 80 of Set 43 | lata
# Processing Record 81 of Set 43 | zakamensk
# Processing Record 82 of Set 43 | tuktoyaktuk
# Processing Record 83 of Set 43 | kango
# Processing Record 84 of Set 43 | chokurdakh
# Processing Record 85 of Set 43 | xai-xai
# Processing Record 86 of Set 43 | cherskiy
# Processing Record 87 of Set 43 | skalistyy
# City not found. Skipping...
# Processing Record 88 of Set 43 | samarai
# Processing Record 89 of Set 43 | flin flon
# Processing Record 1 of Set 44 | muros
# Processing Record 2 of Set 44 | lompoc
# Processing Record 3 of Set 44 | vuktyl
# Processing Record 4 of Set 44 | west bay
# Processing Record 5 of Set 44 | saint-jean-de-maurienne
# Processing Record 6 of Set 44 | albany
# Processing Record 7 of Set 44 | havelock
# Processing Record 8 of Set 44 | mataura
# Processing Record 9 of Set 44 | vaini
# Processing Record 10 of Set 44 | asau
# Processing Record 11 of Set 44 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 44 | port macquarie
# Processing Record 13 of Set 44 | awjilah
# Processing Record 14 of Set 44 | east london
# Processing Record 15 of Set 44 | obarsia-closani
# City not found. Skipping...
# Processing Record 16 of Set 44 | omboue
# Processing Record 17 of Set 44 | saskylakh
# Processing Record 18 of Set 44 | komarov
# Processing Record 19 of Set 44 | ambon
# Processing Record 20 of Set 44 | castro
# Processing Record 21 of Set 44 | geraldton
# Processing Record 22 of Set 44 | sao joao da barra
# Processing Record 23 of Set 44 | kirkuk
# Processing Record 24 of Set 44 | manokwari
# Processing Record 25 of Set 44 | ixtapa
# Processing Record 26 of Set 44 | lavrentiya
# Processing Record 27 of Set 44 | katobu
# Processing Record 28 of Set 44 | nome
# Processing Record 29 of Set 44 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 44 | hervey bay
# Processing Record 31 of Set 44 | cody
# Processing Record 32 of Set 44 | labuhan
# Processing Record 33 of Set 44 | hobart
# Processing Record 34 of Set 44 | brae
# Processing Record 35 of Set 44 | irricana
# Processing Record 36 of Set 44 | new norfolk
# Processing Record 37 of Set 44 | oxbow
# Processing Record 38 of Set 44 | bulgan
# Processing Record 39 of Set 44 | pundaguitan
# Processing Record 40 of Set 44 | virden
# Processing Record 41 of Set 44 | kaitangata
# Processing Record 42 of Set 44 | taoudenni
# Processing Record 43 of Set 44 | lagoa
# Processing Record 44 of Set 44 | narsaq
# Processing Record 45 of Set 44 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 44 | port alfred
# Processing Record 47 of Set 44 | cape town
# Processing Record 48 of Set 44 | hithadhoo
# Processing Record 49 of Set 44 | udachnyy
# Processing Record 50 of Set 44 | kalmunai
# Processing Record 1 of Set 45 | la palma
# Processing Record 2 of Set 45 | goya
# Processing Record 3 of Set 45 | vao
# Processing Record 4 of Set 45 | guntur
# Processing Record 5 of Set 45 | fare
# Processing Record 6 of Set 45 | hofn
# Processing Record 7 of Set 45 | san carlos de bariloche
# Processing Record 8 of Set 45 | kodinsk
# Processing Record 9 of Set 45 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 45 | salalah
# Processing Record 11 of Set 45 | vestmanna
# Processing Record 12 of Set 45 | esperance
# Processing Record 13 of Set 45 | carnarvon
# Processing Record 14 of Set 45 | faanui
# Processing Record 15 of Set 45 | bluff
# Processing Record 16 of Set 45 | kodiak
# Processing Record 17 of Set 45 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 45 | cidreira
# Processing Record 19 of Set 45 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 45 | saint george
# Processing Record 21 of Set 45 | alofi
# Processing Record 22 of Set 45 | suntar
# Processing Record 23 of Set 45 | qaanaaq
# Processing Record 24 of Set 45 | fort saint james
# Processing Record 25 of Set 45 | xichang
# Processing Record 26 of Set 45 | gao
# Processing Record 27 of Set 45 | daru
# Processing Record 28 of Set 45 | karratha
# Processing Record 29 of Set 45 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 45 | tezu
# Processing Record 31 of Set 45 | sharjah
# Processing Record 32 of Set 45 | san policarpo
# Processing Record 33 of Set 45 | mareeba
# Processing Record 34 of Set 45 | yarmouth
# Processing Record 35 of Set 45 | college
# Processing Record 36 of Set 45 | krasnaya polyana
# Processing Record 37 of Set 45 | clonmel
# Processing Record 38 of Set 45 | vanavara
# Processing Record 39 of Set 45 | fortuna
# Processing Record 40 of Set 45 | bafra
# Processing Record 41 of Set 45 | husavik
# Processing Record 42 of Set 45 | provost
# Processing Record 43 of Set 45 | hovd
# Processing Record 44 of Set 45 | khuzdar
# Processing Record 45 of Set 45 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 45 | hilo
# Processing Record 47 of Set 45 | livingston
# Processing Record 48 of Set 45 | savelugu
# Processing Record 49 of Set 45 | guatire
# Processing Record 50 of Set 45 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 46 | tiksi
# Processing Record 2 of Set 46 | tomatlan
# Processing Record 3 of Set 46 | tres arroyos
# Processing Record 4 of Set 46 | divnomorskoye
# Processing Record 5 of Set 46 | lebu
# Processing Record 6 of Set 46 | avera
# Processing Record 7 of Set 46 | neuquen
# Processing Record 8 of Set 46 | ulaanbaatar
# Processing Record 9 of Set 46 | sur
# Processing Record 10 of Set 46 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 46 | port keats
# Processing Record 12 of Set 46 | san lorenzo
# Processing Record 13 of Set 46 | barcelos
# Processing Record 14 of Set 46 | talnakh
# Processing Record 15 of Set 46 | miri
# Processing Record 16 of Set 46 | reforma
# Processing Record 17 of Set 46 | rio grande
# Processing Record 18 of Set 46 | okha
# Processing Record 19 of Set 46 | atambua
# Processing Record 20 of Set 46 | tocopilla
# Processing Record 21 of Set 46 | berbera
# Processing Record 22 of Set 46 | rock sound
# Processing Record 23 of Set 46 | southbridge
# Processing Record 24 of Set 46 | santo tomas
# Processing Record 25 of Set 46 | sibolga
# Processing Record 26 of Set 46 | arraial do cabo
# Processing Record 27 of Set 46 | longyearbyen
# Processing Record 28 of Set 46 | khatanga
# Processing Record 29 of Set 46 | riaba
# City not found. Skipping...
# Processing Record 30 of Set 46 | mbanza-ngungu
# Processing Record 31 of Set 46 | hamilton
# Processing Record 32 of Set 46 | meadow lake
# Processing Record 33 of Set 46 | soyo
# Processing Record 34 of Set 46 | strelka
# Processing Record 35 of Set 46 | ribeira grande
# Processing Record 36 of Set 46 | high prairie
# Processing Record 37 of Set 46 | ponta do sol
# Processing Record 38 of Set 46 | bandarbeyla
# Processing Record 39 of Set 46 | kochubey
# Processing Record 40 of Set 46 | bethel
# Processing Record 41 of Set 46 | biak
# Processing Record 42 of Set 46 | krasnaya zarya
# Processing Record 43 of Set 46 | upernavik
# Processing Record 44 of Set 46 | marabba
# Processing Record 45 of Set 46 | nishihara
# Processing Record 46 of Set 46 | sao filipe
# Processing Record 47 of Set 46 | bengkulu
# Processing Record 48 of Set 46 | okhotsk
# Processing Record 49 of Set 46 | malakal
# Processing Record 50 of Set 46 | los llanos de aridane
# Processing Record 1 of Set 47 | orshanka
# Processing Record 2 of Set 47 | wanning
# Processing Record 3 of Set 47 | yar-sale
# Processing Record 4 of Set 47 | havre-saint-pierre
# Processing Record 5 of Set 47 | malanje
# Processing Record 6 of Set 47 | tasiilaq
# Processing Record 7 of Set 47 | hualmay
# Processing Record 8 of Set 47 | poum
# Processing Record 9 of Set 47 | lieksa
# Processing Record 10 of Set 47 | honiara
# Processing Record 11 of Set 47 | torbay
# Processing Record 12 of Set 47 | gat
# Processing Record 13 of Set 47 | shangqiu
# Processing Record 14 of Set 47 | isangel
# Processing Record 15 of Set 47 | minot
# Processing Record 16 of Set 47 | mpika
# Processing Record 17 of Set 47 | rawson
# Processing Record 18 of Set 47 | caravelas
# Processing Record 19 of Set 47 | burica
# City not found. Skipping...
# Processing Record 20 of Set 47 | dwarka
# Processing Record 21 of Set 47 | saldanha
# Processing Record 22 of Set 47 | beaverlodge
# Processing Record 23 of Set 47 | srednekolymsk
# Processing Record 24 of Set 47 | severnyy
# Processing Record 25 of Set 47 | berlevag
# Processing Record 26 of Set 47 | dingle
# Processing Record 27 of Set 47 | athabasca
# Processing Record 28 of Set 47 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 47 | vila
# Processing Record 30 of Set 47 | mukhen
# Processing Record 31 of Set 47 | fuzhou
# Processing Record 32 of Set 47 | axim
# Processing Record 33 of Set 47 | ancud
# Processing Record 34 of Set 47 | hobyo
# Processing Record 35 of Set 47 | alice springs
# Processing Record 36 of Set 47 | makakilo city
# Processing Record 37 of Set 47 | mayo
# Processing Record 38 of Set 47 | hasaki
# Processing Record 39 of Set 47 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 47 | yellowknife
# Processing Record 41 of Set 47 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 47 | manado
# Processing Record 43 of Set 47 | pisco
# Processing Record 44 of Set 47 | clyde river
# Processing Record 45 of Set 47 | puerto escondido
# Processing Record 46 of Set 47 | oborniki
# Processing Record 47 of Set 47 | arbroath
# Processing Record 48 of Set 47 | pevek
# Processing Record 49 of Set 47 | mao
# Processing Record 50 of Set 47 | bals
# Processing Record 1 of Set 48 | kununurra
# Processing Record 2 of Set 48 | kondagaon
# Processing Record 3 of Set 48 | kano
# Processing Record 4 of Set 48 | anadyr
# Processing Record 5 of Set 48 | bathsheba
# Processing Record 6 of Set 48 | turochak
# Processing Record 7 of Set 48 | aklavik
# Processing Record 8 of Set 48 | kirakira
# Processing Record 9 of Set 48 | eureka
# Processing Record 10 of Set 48 | kharp
# Processing Record 11 of Set 48 | tamworth
# Processing Record 12 of Set 48 | luganville
# Processing Record 13 of Set 48 | sitka
# Processing Record 14 of Set 48 | columbus
# Processing Record 15 of Set 48 | norman wells
# Processing Record 16 of Set 48 | henties bay
# Processing Record 17 of Set 48 | tual
# Processing Record 18 of Set 48 | hambantota
# Processing Record 19 of Set 48 | port hedland
# Processing Record 20 of Set 48 | thinadhoo
# Processing Record 21 of Set 48 | oriximina
# Processing Record 22 of Set 48 | kerteh
# City not found. Skipping...
# Processing Record 23 of Set 48 | punta
# Processing Record 24 of Set 48 | solnechnyy
# Processing Record 25 of Set 48 | westport
# Processing Record 26 of Set 48 | haldibari
# Processing Record 27 of Set 48 | koundara
# Processing Record 28 of Set 48 | saint-pierre
# Processing Record 29 of Set 48 | mogadishu
# Processing Record 30 of Set 48 | batemans bay
# Processing Record 31 of Set 48 | yaan
# Processing Record 32 of Set 48 | nacala
# Processing Record 33 of Set 48 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 48 | nandaime
# Processing Record 35 of Set 48 | taicheng
# Processing Record 36 of Set 48 | tastur
# Processing Record 37 of Set 48 | richards bay
# Processing Record 38 of Set 48 | imeni babushkina
# Processing Record 39 of Set 48 | portland
# Processing Record 40 of Set 48 | muskogee
# Processing Record 41 of Set 48 | krasnoarmeysk
# Processing Record 42 of Set 48 | mount isa
# Processing Record 43 of Set 48 | contai
# Processing Record 44 of Set 48 | asyut
# Processing Record 45 of Set 48 | jaunpur
# Processing Record 46 of Set 48 | anchorage
# Processing Record 47 of Set 48 | bac lieu
# Processing Record 48 of Set 48 | kirkenes
# Processing Record 49 of Set 48 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 48 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 49 | avarua
# Processing Record 2 of Set 49 | kavieng
# Processing Record 3 of Set 49 | milyutinskaya
# Processing Record 4 of Set 49 | houma
# Processing Record 5 of Set 49 | northam
# Processing Record 6 of Set 49 | itarema
# Processing Record 7 of Set 49 | noumea
# Processing Record 8 of Set 49 | klaksvik
# Processing Record 9 of Set 49 | broome
# Processing Record 10 of Set 49 | almaznyy
# Processing Record 11 of Set 49 | marsh harbour
# Processing Record 12 of Set 49 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 49 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 49 | goderich
# Processing Record 15 of Set 49 | haines junction
# Processing Record 16 of Set 49 | kidal
# Processing Record 17 of Set 49 | sinnamary
# Processing Record 18 of Set 49 | jumla
# Processing Record 19 of Set 49 | wajir
# Processing Record 20 of Set 49 | maniitsoq
# Processing Record 21 of Set 49 | sioux lookout
# Processing Record 22 of Set 49 | burnie
# Processing Record 23 of Set 49 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 49 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 49 | simi
# Processing Record 26 of Set 49 | la dorada
# Processing Record 27 of Set 49 | buala
# Processing Record 28 of Set 49 | tsienyane
# City not found. Skipping...
# Processing Record 29 of Set 49 | vajszlo
# Processing Record 30 of Set 49 | nuevitas
# Processing Record 31 of Set 49 | balabac
# Processing Record 32 of Set 49 | constitucion
# Processing Record 33 of Set 49 | marzuq
# Processing Record 34 of Set 49 | covington
# Processing Record 35 of Set 49 | dingzhou
# Processing Record 36 of Set 49 | nantucket
# Processing Record 37 of Set 49 | pyaozerskiy
# Processing Record 38 of Set 49 | port hueneme
# Processing Record 39 of Set 49 | jilib
# Processing Record 40 of Set 49 | san quintin
# Processing Record 41 of Set 49 | stykkisholmur
# Processing Record 42 of Set 49 | port lincoln
# Processing Record 43 of Set 49 | lorengau
# Processing Record 44 of Set 49 | luderitz
# Processing Record 45 of Set 49 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 49 | chuy
# Processing Record 47 of Set 49 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 49 | aracruz
# Processing Record 49 of Set 49 | itaituba
# Processing Record 50 of Set 49 | fernie
# Processing Record 1 of Set 50 | bremerton
# Processing Record 2 of Set 50 | zaraza
# Processing Record 3 of Set 50 | waiuku
# Processing Record 4 of Set 50 | touros
# Processing Record 5 of Set 50 | tura
# Processing Record 6 of Set 50 | kahului
# Processing Record 7 of Set 50 | tuatapere
# Processing Record 8 of Set 50 | camacha
# Processing Record 9 of Set 50 | atbasar
# Processing Record 10 of Set 50 | honavar
# Processing Record 11 of Set 50 | payson
# Processing Record 12 of Set 50 | lodwar
# Processing Record 13 of Set 50 | namatanai
# Processing Record 14 of Set 50 | qaqortoq
# Processing Record 15 of Set 50 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 50 | port blair
# Processing Record 17 of Set 50 | honningsvag
# Processing Record 18 of Set 50 | hvide sande
# Processing Record 19 of Set 50 | camacupa
# Processing Record 20 of Set 50 | uyuni
# Processing Record 21 of Set 50 | tasbuget
# City not found. Skipping...
# Processing Record 22 of Set 50 | muisne
# Processing Record 23 of Set 50 | montepuez
# Processing Record 24 of Set 50 | mnogovershinnyy
# Processing Record 25 of Set 50 | nuuk
# Processing Record 26 of Set 50 | axixa do tocantins
# City not found. Skipping...
# Processing Record 27 of Set 50 | qorveh
# Processing Record 28 of Set 50 | mount gambier
# Processing Record 29 of Set 50 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 50 | khandyga
# Processing Record 31 of Set 50 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 50 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 50 | rocha
# Processing Record 34 of Set 50 | kenora
# Processing Record 35 of Set 50 | sambava
# Processing Record 36 of Set 50 | marrakesh
# Processing Record 37 of Set 50 | horta
# Processing Record 38 of Set 50 | semporna
# Processing Record 39 of Set 50 | basco
# Processing Record 40 of Set 50 | matara
# Processing Record 41 of Set 50 | zyryanka
# Processing Record 42 of Set 50 | severo-yeniseyskiy
# Processing Record 43 of Set 50 | saint-esteve
# Processing Record 44 of Set 50 | fengrun
# Processing Record 45 of Set 50 | port augusta
# Processing Record 46 of Set 50 | victor harbor
# Processing Record 47 of Set 50 | felanitx
# Processing Record 48 of Set 50 | puerto baquerizo moreno
# Processing Record 49 of Set 50 | patzcuaro
# Processing Record 50 of Set 50 | kpandu
# Processing Record 1 of Set 51 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 51 | hibbing
# Processing Record 3 of Set 51 | ketchikan
# Processing Record 4 of Set 51 | ostrovnoy
# Processing Record 5 of Set 51 | coquimbo
# Processing Record 6 of Set 51 | kankaanpaa
# Processing Record 7 of Set 51 | mujiayingzi
# Processing Record 8 of Set 51 | yushala
# Processing Record 9 of Set 51 | katsuura
# Processing Record 10 of Set 51 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 51 | vostok
# Processing Record 12 of Set 51 | cururupu
# Processing Record 13 of Set 51 | mahebourg
# Processing Record 14 of Set 51 | port-gentil
# Processing Record 15 of Set 51 | mocuba
# Processing Record 16 of Set 51 | vardo
# Processing Record 17 of Set 51 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 51 | port hardy
# Processing Record 19 of Set 51 | airai
# Processing Record 20 of Set 51 | berdigestyakh
# Processing Record 21 of Set 51 | zhuji
# Processing Record 22 of Set 51 | seoul
# Processing Record 23 of Set 51 | tiarei
# Processing Record 24 of Set 51 | coroico
# Processing Record 25 of Set 51 | forestville
# Processing Record 26 of Set 51 | elwood
# Processing Record 27 of Set 51 | coruripe
# Processing Record 28 of Set 51 | inuvik
# Processing Record 29 of Set 51 | verkhnyaya inta
# Processing Record 30 of Set 51 | banda aceh
# Processing Record 31 of Set 51 | north platte
# Processing Record 32 of Set 51 | acarau
# Processing Record 33 of Set 51 | saint pete beach
# Processing Record 34 of Set 51 | edgewood
# Processing Record 35 of Set 51 | vastervik
# City not found. Skipping...
# Processing Record 36 of Set 51 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 51 | nizwa
# Processing Record 38 of Set 51 | paka
# Processing Record 39 of Set 51 | port elizabeth
# Processing Record 40 of Set 51 | yulara
# Processing Record 41 of Set 51 | vestmannaeyjar
# Processing Record 42 of Set 51 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 51 | chapadinha
# Processing Record 44 of Set 51 | khaniotis
# Processing Record 45 of Set 51 | adrar
# Processing Record 46 of Set 51 | isiro
# Processing Record 47 of Set 51 | buluang
# Processing Record 48 of Set 51 | shimoda
# Processing Record 49 of Set 51 | santiago
# Processing Record 50 of Set 51 | nanortalik
# Processing Record 1 of Set 52 | khomeynishahr
# City not found. Skipping...
# Processing Record 2 of Set 52 | am timan
# Processing Record 3 of Set 52 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 52 | tessalit
# Processing Record 5 of Set 52 | namibe
# Processing Record 6 of Set 52 | magdalena
# Processing Record 7 of Set 52 | aksu
# Processing Record 8 of Set 52 | mokhsogollokh
# Processing Record 9 of Set 52 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 52 | orlik
# Processing Record 11 of Set 52 | karasburg
# Processing Record 12 of Set 52 | ballina
# Processing Record 13 of Set 52 | alaca
# Processing Record 14 of Set 52 | bianzhuang
# Processing Record 15 of Set 52 | waitati
# Processing Record 16 of Set 52 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 52 | calvinia
# Processing Record 18 of Set 52 | hunchun
# Processing Record 19 of Set 52 | prado
# Processing Record 20 of Set 52 | rincon
# Processing Record 21 of Set 52 | vanimo
# Processing Record 22 of Set 52 | limbourg
# Processing Record 23 of Set 52 | saint-joseph
# Processing Record 24 of Set 52 | belmonte
# Processing Record 25 of Set 52 | chapais
# Processing Record 26 of Set 52 | fairbanks
# Processing Record 27 of Set 52 | sao jose da coroa grande
# Processing Record 28 of Set 52 | saint anthony
# Processing Record 29 of Set 52 | djambala
# Processing Record 30 of Set 52 | manitouwadge
# Processing Record 31 of Set 52 | petatlan
# Processing Record 32 of Set 52 | angoram
# Processing Record 33 of Set 52 | lazaro cardenas
# Processing Record 34 of Set 52 | pimenta bueno
# Processing Record 35 of Set 52 | terenga
# City not found. Skipping...
# Processing Record 36 of Set 52 | agadir
# Processing Record 37 of Set 52 | santa cruz
# Processing Record 38 of Set 52 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 52 | vilyuysk
# Processing Record 40 of Set 52 | chitral
# Processing Record 41 of Set 52 | hokitika
# Processing Record 42 of Set 52 | salinopolis
# Processing Record 43 of Set 52 | young
# Processing Record 44 of Set 52 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 52 | san patricio
# Processing Record 46 of Set 52 | munster
# Processing Record 47 of Set 52 | porto walter
# Processing Record 48 of Set 52 | luangwa
# Processing Record 49 of Set 52 | carlyle
# Processing Record 50 of Set 52 | umm kaddadah
# Processing Record 1 of Set 53 | westerland
# Processing Record 2 of Set 53 | palauig
# Processing Record 3 of Set 53 | qandala
# Processing Record 4 of Set 53 | qingquan
# Processing Record 5 of Set 53 | dunedin
# Processing Record 6 of Set 53 | laela
# Processing Record 7 of Set 53 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 53 | karamay
# City not found. Skipping...
# Processing Record 9 of Set 53 | timra
# Processing Record 10 of Set 53 | saquarema
# Processing Record 11 of Set 53 | youkounkoun
# Processing Record 12 of Set 53 | bud
# Processing Record 13 of Set 53 | komsomolskiy
# Processing Record 14 of Set 53 | sabha
# Processing Record 15 of Set 53 | guanica
# Processing Record 16 of Set 53 | rehoboth
# Processing Record 17 of Set 53 | iqaluit
# Processing Record 18 of Set 53 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 53 | dasoguz
# Processing Record 20 of Set 53 | comodoro rivadavia
# Processing Record 21 of Set 53 | kailua
# Processing Record 22 of Set 53 | vila franca do campo
# Processing Record 23 of Set 53 | catemaco
# Processing Record 24 of Set 53 | sao goncalo do sapucai
# Processing Record 25 of Set 53 | nenjiang
# Processing Record 26 of Set 53 | khilok
# Processing Record 27 of Set 53 | springbok
# Processing Record 28 of Set 53 | tanete
# Processing Record 29 of Set 53 | qom
# Processing Record 30 of Set 53 | pangnirtung
# Processing Record 31 of Set 53 | chicama
# Processing Record 32 of Set 53 | gravdal
# Processing Record 33 of Set 53 | lar gerd
# City not found. Skipping...
# Processing Record 34 of Set 53 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 53 | turbat
# Processing Record 36 of Set 53 | zambezi
# Processing Record 37 of Set 53 | ulety
# Processing Record 38 of Set 53 | baiyin
# Processing Record 39 of Set 53 | darlawn
# Processing Record 40 of Set 53 | sovetskaya gavan
# Processing Record 41 of Set 53 | salvador
# Processing Record 42 of Set 53 | shakhtinsk
# Processing Record 43 of Set 53 | arman
# Processing Record 44 of Set 53 | menongue
# Processing Record 45 of Set 53 | carutapera
# Processing Record 46 of Set 53 | beloha
# Processing Record 47 of Set 53 | lithgow
# Processing Record 48 of Set 53 | juegang
# Processing Record 49 of Set 53 | kassala
# Processing Record 50 of Set 53 | dudinka
# Processing Record 1 of Set 54 | kurchanskaya
# Processing Record 2 of Set 54 | antalaha
# Processing Record 3 of Set 54 | kosh-agach
# Processing Record 4 of Set 54 | saint-honore
# Processing Record 5 of Set 54 | tigil
# Processing Record 6 of Set 54 | kutum
# Processing Record 7 of Set 54 | coahuayana
# Processing Record 8 of Set 54 | fairhope
# Processing Record 9 of Set 54 | san juan del parana
# Processing Record 10 of Set 54 | mariestad
# Processing Record 11 of Set 54 | krasnyy chikoy
# Processing Record 12 of Set 54 | mindelo
# Processing Record 13 of Set 54 | quibor
# Processing Record 14 of Set 54 | mahon
# Processing Record 15 of Set 54 | nhulunbuy
# Processing Record 16 of Set 54 | sao felix do xingu
# Processing Record 17 of Set 54 | natal
# Processing Record 18 of Set 54 | humaita
# Processing Record 19 of Set 54 | alma
# Processing Record 20 of Set 54 | buta
# Processing Record 21 of Set 54 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 54 | xuddur
# Processing Record 23 of Set 54 | amuntai
# Processing Record 24 of Set 54 | kloulklubed
# Processing Record 25 of Set 54 | itoman
# Processing Record 26 of Set 54 | iquique
# Processing Record 27 of Set 54 | doha
# Processing Record 28 of Set 54 | rio pardo de minas
# Processing Record 29 of Set 54 | tabas
# Processing Record 30 of Set 54 | kaoma
# Processing Record 31 of Set 54 | gondanglegi
# Processing Record 32 of Set 54 | mezen
# Processing Record 33 of Set 54 | saint-georges
# Processing Record 34 of Set 54 | boralday
# Processing Record 35 of Set 54 | maraba
# Processing Record 36 of Set 54 | turukhansk
# Processing Record 37 of Set 54 | ibra
# Processing Record 38 of Set 54 | linqu
# Processing Record 39 of Set 54 | ilulissat
# Processing Record 40 of Set 54 | toccoa
# Processing Record 41 of Set 54 | jaisalmer
# Processing Record 42 of Set 54 | lewistown
# Processing Record 43 of Set 54 | akdepe
# Processing Record 44 of Set 54 | mubi
# Processing Record 45 of Set 54 | waingapu
# Processing Record 46 of Set 54 | sept-iles
# Processing Record 47 of Set 54 | somotillo
# Processing Record 48 of Set 54 | kerouane
# Processing Record 49 of Set 54 | cerritos
# Processing Record 50 of Set 54 | porto novo
# Processing Record 1 of Set 55 | la plata
# Processing Record 2 of Set 55 | indri
# Processing Record 3 of Set 55 | milingimbi
# City not found. Skipping...
# Processing Record 4 of Set 55 | brantford
# Processing Record 5 of Set 55 | gidole
# Processing Record 6 of Set 55 | anar darreh
# City not found. Skipping...
# Processing Record 7 of Set 55 | pangkalanbuun
# Processing Record 8 of Set 55 | xiaoweizhai
# Processing Record 9 of Set 55 | bayanday
# Processing Record 10 of Set 55 | hakui
# Processing Record 11 of Set 55 | mayumba
# Processing Record 12 of Set 55 | aloleng
# Processing Record 13 of Set 55 | barhi
# Processing Record 14 of Set 55 | trincomalee
# Processing Record 15 of Set 55 | garden city
# Processing Record 16 of Set 55 | zapadnaya dvina
# Processing Record 17 of Set 55 | dakar
# Processing Record 18 of Set 55 | takoradi
# Processing Record 19 of Set 55 | batagay
# Processing Record 20 of Set 55 | kawardha
# Processing Record 21 of Set 55 | barranca
# Processing Record 22 of Set 55 | olafsvik
# Processing Record 23 of Set 55 | kieta
# Processing Record 24 of Set 55 | chilliwack
# Processing Record 25 of Set 55 | half moon bay
# Processing Record 26 of Set 55 | tarko-sale
# Processing Record 27 of Set 55 | bayji
# Processing Record 28 of Set 55 | meulaboh
# Processing Record 29 of Set 55 | belaya gora
# Processing Record 30 of Set 55 | grand gaube
# Processing Record 31 of Set 55 | salair
# Processing Record 32 of Set 55 | lichtenfels
# Processing Record 33 of Set 55 | mansa
# Processing Record 34 of Set 55 | halifax
# Processing Record 35 of Set 55 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 55 | rio gallegos
# Processing Record 37 of Set 55 | beirut
# Processing Record 38 of Set 55 | carlsbad
# Processing Record 39 of Set 55 | manggar
# Processing Record 40 of Set 55 | victoria
# Processing Record 41 of Set 55 | arona
# Processing Record 42 of Set 55 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 55 | orcopampa
# Processing Record 44 of Set 55 | tumpat
# Processing Record 45 of Set 55 | radstadt
# Processing Record 46 of Set 55 | tolaga bay
# Processing Record 47 of Set 55 | deputatskiy
# Processing Record 48 of Set 55 | mandalgovi
# Processing Record 49 of Set 55 | kosa
# Processing Record 50 of Set 55 | sorata
# Processing Record 1 of Set 56 | asheville
# Processing Record 2 of Set 56 | codrington
# Processing Record 3 of Set 56 | hochstadt
# Processing Record 4 of Set 56 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 56 | marystown
# Processing Record 6 of Set 56 | velyka bahachka
# Processing Record 7 of Set 56 | billings
# Processing Record 8 of Set 56 | winburg
# Processing Record 9 of Set 56 | north bend
# Processing Record 10 of Set 56 | juneau
# Processing Record 11 of Set 56 | heilbronn
# Processing Record 12 of Set 56 | caxito
# Processing Record 13 of Set 56 | voiron
# Processing Record 14 of Set 56 | santarem
# Processing Record 15 of Set 56 | duekoue
# Processing Record 16 of Set 56 | fonte boa
# Processing Record 17 of Set 56 | celestun
# Processing Record 18 of Set 56 | canutama
# Processing Record 19 of Set 56 | yelizovo
# Processing Record 20 of Set 56 | mana
# Processing Record 21 of Set 56 | aktau
# Processing Record 22 of Set 56 | catamarca
# Processing Record 23 of Set 56 | kuandian
# Processing Record 24 of Set 56 | mangrol
# Processing Record 25 of Set 56 | coihaique
# Processing Record 26 of Set 56 | quatre cocos
# Processing Record 27 of Set 56 | sakaraha
# Processing Record 28 of Set 56 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 56 | kishtwar
# Processing Record 30 of Set 56 | francisco sa
# Processing Record 31 of Set 56 | ponta delgada
# Processing Record 32 of Set 56 | cozumel
# Processing Record 33 of Set 56 | blythe
# Processing Record 34 of Set 56 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 56 | bauchi
# Processing Record 36 of Set 56 | tilichiki
# Processing Record 37 of Set 56 | pacific grove
# Processing Record 38 of Set 56 | fukue
# Processing Record 39 of Set 56 | kankakee
# Processing Record 40 of Set 56 | luanda
# Processing Record 41 of Set 56 | hadejia
# Processing Record 42 of Set 56 | yomitan
# City not found. Skipping...
# Processing Record 43 of Set 56 | uray
# Processing Record 44 of Set 56 | shetpe
# Processing Record 45 of Set 56 | trofors
# Processing Record 46 of Set 56 | sovetskiy
# Processing Record 47 of Set 56 | maragogi
# Processing Record 48 of Set 56 | cutzamala
# City not found. Skipping...
# Processing Record 49 of Set 56 | faya
# Processing Record 50 of Set 56 | cuamba
# Processing Record 1 of Set 57 | puerto del rosario
# Processing Record 2 of Set 57 | wonthaggi
# Processing Record 3 of Set 57 | dawei
# Processing Record 4 of Set 57 | zhigansk
# Processing Record 5 of Set 57 | sisimiut
# Processing Record 6 of Set 57 | naze
# Processing Record 7 of Set 57 | luwuk
# Processing Record 8 of Set 57 | prince rupert
# Processing Record 9 of Set 57 | la malbaie
# Processing Record 10 of Set 57 | howick
# Processing Record 11 of Set 57 | casablanca
# Processing Record 12 of Set 57 | alta floresta
# Processing Record 13 of Set 57 | santa isabel do rio negro
# Processing Record 14 of Set 57 | altay
# Processing Record 15 of Set 57 | algiers
# Processing Record 16 of Set 57 | shuangyang
# Processing Record 17 of Set 57 | araouane
# Processing Record 18 of Set 57 | skibotn
# Processing Record 19 of Set 57 | kamenka
# Processing Record 20 of Set 57 | dewa
# Processing Record 21 of Set 57 | den helder
# Processing Record 22 of Set 57 | sokoni
# Processing Record 23 of Set 57 | borujan
# City not found. Skipping...
# Processing Record 24 of Set 57 | kaa-khem
# Processing Record 25 of Set 57 | bowmore
# Processing Record 26 of Set 57 | muroto
# Processing Record 27 of Set 57 | crossville
# Processing Record 28 of Set 57 | varzea da palma
# Processing Record 29 of Set 57 | vilhena
# Processing Record 30 of Set 57 | isawa
# Processing Record 31 of Set 57 | ormara
# Processing Record 32 of Set 57 | nam tha
# City not found. Skipping...
# Processing Record 33 of Set 57 | shelburne
# Processing Record 34 of Set 57 | koslan
# Processing Record 35 of Set 57 | muravlenko
# Processing Record 36 of Set 57 | dinsor
# City not found. Skipping...
# Processing Record 37 of Set 57 | umea
# Processing Record 38 of Set 57 | bloemfontein
# Processing Record 39 of Set 57 | colorado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
city_data
# Out:
# [{'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 60.39,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:14'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.76,
#   'Humidity': 77,
#   'Cloudiness': 23,
#   'Wind Speed': 19.35,
#   'Country': 'PF',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:14'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 71.55,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:19:05'},
#  {'City': 'Paita',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 64.62,
#   'Humidity': 86,
#   'Cloudiness': 60,
#   'Wind Speed': 16.62,
#   'Country': 'PE',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:14'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 70.36,
#   'Humidity': 79,
#   'Cloudiness': 25,
#   'Wind Speed': 15.55,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:15'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 78.01,
#   'Humidity': 28,
#   'Cloudiness': 14,
#   'Wind Speed': 11.21,
#   'Country': 'EG',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:15'},
#  {'City': 'San Jose De Rio Tinto',
#   'Lat': 14.9333,
#   'Lng': -85.7,
#   'Max Temp': 78.37,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'HN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:16'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 67.55,
#   'Humidity': 87,
#   'Cloudiness': 68,
#   'Wind Speed': 12.73,
#   'Country': 'RE',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:16'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.51,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 8.43,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:16'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 47.01,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 8.52,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:17'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.13,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MY',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:17'},
#  {'City': 'Sarangani',
#   'Lat': 5.4033,
#   'Lng': 125.4636,
#   'Max Temp': 83.05,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.07,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:17'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 83.08,
#   'Humidity': 82,
#   'Cloudiness': 12,
#   'Wind Speed': 4,
#   'Country': 'GF',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:18'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 70.21,
#   'Humidity': 76,
#   'Cloudiness': 22,
#   'Wind Speed': 16.58,
#   'Country': 'MU',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:18'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.06,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:09'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 76.24,
#   'Humidity': 76,
#   'Cloudiness': 81,
#   'Wind Speed': 2.1,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:19'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 58.08,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:19'},
#  {'City': 'Tapayan',
#   'Lat': 7.2944,
#   'Lng': 124.2661,
#   'Max Temp': 81.63,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 4.61,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:19'},
#  {'City': 'Japura',
#   'Lat': -0.3167,
#   'Lng': 102.35,
#   'Max Temp': 78.26,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 1.28,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:20'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 59.04,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 1.19,
#   'Country': 'AU',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:20'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 35.71,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:20'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.17,
#   'Humidity': 75,
#   'Cloudiness': 13,
#   'Wind Speed': 10.45,
#   'Country': 'KI',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:21'},
#  {'City': 'Zapolyarnyy',
#   'Lat': 69.4154,
#   'Lng': 30.8136,
#   'Max Temp': 38.48,
#   'Humidity': 92,
#   'Cloudiness': 91,
#   'Wind Speed': 5.66,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:21'},
#  {'City': 'Porto Santo',
#   'Lat': 33.072,
#   'Lng': -16.3415,
#   'Max Temp': 71.51,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:22'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 36.19,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 19.86,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:22'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 53.28,
#   'Humidity': 93,
#   'Cloudiness': 53,
#   'Wind Speed': 2.48,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:23'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.18,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:23'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 58.89,
#   'Humidity': 90,
#   'Cloudiness': 65,
#   'Wind Speed': 6.46,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:24'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 87.62,
#   'Humidity': 72,
#   'Cloudiness': 50,
#   'Wind Speed': 8.99,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:16:53'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 40.95,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Country': 'IS',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:24'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 24.82,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:25'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 33.84,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:25'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 48.36,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:25'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 48.96,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 12.91,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:26'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.89,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 14.83,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:26'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 66.25,
#   'Humidity': 98,
#   'Cloudiness': 71,
#   'Wind Speed': 4.27,
#   'Country': 'VE',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:27'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 39.11,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 5.35,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:27'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 61.81,
#   'Humidity': 96,
#   'Cloudiness': 25,
#   'Wind Speed': 2.17,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:27'},
#  {'City': 'Zakamensk',
#   'Lat': 50.3741,
#   'Lng': 103.2863,
#   'Max Temp': 32.86,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 2.48,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:28'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 33.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Current Description': 'light snow',
#   'Date': '2021-09-26 01:16:27'},
#  {'City': 'Kango',
#   'Lat': 0.1943,
#   'Lng': 10.0951,
#   'Max Temp': 74.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Country': 'GA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:28'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 33.17,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 12.12,
#   'Country': 'RU',
#   'Current Description': 'light snow',
#   'Date': '2021-09-26 01:20:29'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 63.41,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 7.29,
#   'Country': 'MZ',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:29'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 33.08,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 13.22,
#   'Country': 'RU',
#   'Current Description': 'light snow',
#   'Date': '2021-09-26 01:20:29'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 80.49,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 12.21,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:30'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 51.96,
#   'Humidity': 78,
#   'Cloudiness': 6,
#   'Wind Speed': 5.61,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:30'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 65.23,
#   'Humidity': 93,
#   'Cloudiness': 44,
#   'Wind Speed': 6.4,
#   'Country': 'ES',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:31'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 71.74,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:31'},
#  {'City': 'Vuktyl',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 39.24,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 13.13,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:31'},
#  {'City': 'West Bay',
#   'Lat': 19.3667,
#   'Lng': -81.4167,
#   'Max Temp': 84.27,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'KY',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:32'},
#  {'City': 'Saint-Jean-De-Maurienne',
#   'Lat': 45.1667,
#   'Lng': 6.5833,
#   'Max Temp': 45.37,
#   'Humidity': 92,
#   'Cloudiness': 54,
#   'Wind Speed': 7.58,
#   'Country': 'FR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:32'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 61.14,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:33'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 69.93,
#   'Humidity': 86,
#   'Cloudiness': 58,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:34'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 45.48,
#   'Humidity': 84,
#   'Cloudiness': 38,
#   'Wind Speed': 7.25,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:34'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'TO',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:35'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 53.76,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.55,
#   'Country': 'RO',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:35'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 58.37,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 12.62,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:18:45'},
#  {'City': 'Awjilah',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 69.73,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 8.25,
#   'Country': 'LY',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:36'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.34,
#   'Humidity': 49,
#   'Cloudiness': 48,
#   'Wind Speed': 12.01,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:36'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 75.99,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.96,
#   'Country': 'GA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:37'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 32.74,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:37'},
#  {'City': 'Komarov',
#   'Lat': 49.8065,
#   'Lng': 13.8564,
#   'Max Temp': 57.02,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 2.21,
#   'Country': 'CZ',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:37'},
#  {'City': 'Ambon',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 80.74,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.14,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:38'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 59.94,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 4.52,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:38'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 64.81,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:38'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 72.14,
#   'Humidity': 75,
#   'Cloudiness': 52,
#   'Wind Speed': 21.18,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:39'},
#  {'City': 'Kirkuk',
#   'Lat': 35.4681,
#   'Lng': 44.3922,
#   'Max Temp': 71.38,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'IQ',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:39'},
#  {'City': 'Manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 82.62,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.5,
#   'Country': 'ID',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:40'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 78.22,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:40'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 33.33,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 3.83,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:41'},
#  {'City': 'Katobu',
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Max Temp': 83.91,
#   'Humidity': 68,
#   'Cloudiness': 39,
#   'Wind Speed': 5.48,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:42'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 45.16,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:42'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 82.04,
#   'Humidity': 69,
#   'Cloudiness': 6,
#   'Wind Speed': 6.42,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:42'},
#  {'City': 'Cody',
#   'Lat': 44.5263,
#   'Lng': -109.0565,
#   'Max Temp': 77.22,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:15:49'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 81.52,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 6.31,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:43'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.06,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:28'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 55.31,
#   'Humidity': 96,
#   'Cloudiness': 73,
#   'Wind Speed': 11.83,
#   'Country': 'GB',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:44'},
#  {'City': 'Irricana',
#   'Lat': 51.3237,
#   'Lng': -113.6048,
#   'Max Temp': 68.7,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:44'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 54.72,
#   'Humidity': 41,
#   'Cloudiness': 7,
#   'Wind Speed': 3.65,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:44'},
#  {'City': 'Oxbow',
#   'Lat': 49.2333,
#   'Lng': -102.1676,
#   'Max Temp': 73.35,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 6.49,
#   'Country': 'CA',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:45'},
#  {'City': 'Bulgan',
#   'Lat': 48.8125,
#   'Lng': 103.5347,
#   'Max Temp': 36,
#   'Humidity': 68,
#   'Cloudiness': 17,
#   'Wind Speed': 3.27,
#   'Country': 'MN',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:45'},
#  {'City': 'Pundaguitan',
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 81.91,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 4.68,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:45'},
#  {'City': 'Virden',
#   'Lat': 39.5009,
#   'Lng': -89.7679,
#   'Max Temp': 60.71,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 4.52,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:46'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 46.36,
#   'Humidity': 67,
#   'Cloudiness': 95,
#   'Wind Speed': 10.54,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:46'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 93,
#   'Humidity': 8,
#   'Cloudiness': 50,
#   'Wind Speed': 9.26,
#   'Country': 'ML',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:47'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 70.25,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:47'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 32.22,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 7.07,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:48'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 61.61,
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 12.57,
#   'Country': 'ZA',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:48'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.28,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:49'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.01,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 15.59,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:49'},
#  {'City': 'Udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 35.67,
#   'Humidity': 54,
#   'Cloudiness': 14,
#   'Wind Speed': 6.35,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:49'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 79.47,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Country': 'LK',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:50'},
#  {'City': 'La Palma',
#   'Lat': 33.8464,
#   'Lng': -118.0467,
#   'Max Temp': 86.5,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:20:50'},
#  {'City': 'Goya',
#   'Lat': -29.14,
#   'Lng': -59.2626,
#   'Max Temp': 61.39,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:50'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 68.31,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 10.76,
#   'Country': 'NC',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:51'},
#  {'City': 'Guntur',
#   'Lat': 16.3,
#   'Lng': 80.45,
#   'Max Temp': 78.69,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:51'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 79.27,
#   'Humidity': 72,
#   'Cloudiness': 2,
#   'Wind Speed': 7.11,
#   'Country': 'PF',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:51'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 39.69,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 15.88,
#   'Country': 'IS',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:20:52'},
#  {'City': 'San Carlos De Bariloche',
#   'Lat': -41.1456,
#   'Lng': -71.3082,
#   'Max Temp': 38.95,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:52'},
#  {'City': 'Kodinsk',
#   'Lat': 58.6881,
#   'Lng': 99.1844,
#   'Max Temp': 34.72,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:52'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 82.49,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'OM',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:53'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 50.92,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:20:53'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 66.15,
#   'Humidity': 51,
#   'Cloudiness': 22,
#   'Wind Speed': 17.94,
#   'Country': 'AU',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:20:54'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 71.67,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:20:55'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 79.16,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 8.37,
#   'Country': 'PF',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:57'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 45.81,
#   'Humidity': 57,
#   'Cloudiness': 72,
#   'Wind Speed': 14.81,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:02'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 47.71,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:03'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.8,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 9.13,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:03'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 90.07,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:58'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 78.69,
#   'Humidity': 53,
#   'Cloudiness': 4,
#   'Wind Speed': 6.91,
#   'Country': 'NU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:04'},
#  {'City': 'Suntar',
#   'Lat': 62.1444,
#   'Lng': 117.6319,
#   'Max Temp': 37.98,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:05'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 20.91,
#   'Humidity': 70,
#   'Cloudiness': 97,
#   'Wind Speed': 6.62,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:05'},
#  {'City': 'Fort Saint James',
#   'Lat': 54.4333,
#   'Lng': -124.25,
#   'Max Temp': 51.48,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.12,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:05'},
#  {'City': 'Xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 67.95,
#   'Humidity': 82,
#   'Cloudiness': 29,
#   'Wind Speed': 1.92,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:06'},
#  {'City': 'Gao',
#   'Lat': 16.6362,
#   'Lng': 1.637,
#   'Max Temp': 90.84,
#   'Humidity': 23,
#   'Cloudiness': 33,
#   'Wind Speed': 5.57,
#   'Country': 'ML',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:06'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 79.52,
#   'Humidity': 88,
#   'Cloudiness': 39,
#   'Wind Speed': 14.76,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:06'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 77.41,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 15.1,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:07'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 82.08,
#   'Humidity': 66,
#   'Cloudiness': 36,
#   'Wind Speed': 1.45,
#   'Country': 'IN',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:19:12'},
#  {'City': 'Sharjah',
#   'Lat': 25.3573,
#   'Lng': 55.4033,
#   'Max Temp': 88.25,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AE',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:08'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 82.76,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 1.14,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:08'},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 83.44,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:08'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 68.14,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'mist',
#   'Date': '2021-09-26 01:21:09'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 35.58,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'light snow',
#   'Date': '2021-09-26 01:21:09'},
#  {'City': 'Krasnaya Polyana',
#   'Lat': 56.242,
#   'Lng': 51.1442,
#   'Max Temp': 46.06,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.16,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:09'},
#  {'City': 'Clonmel',
#   'Lat': 52.355,
#   'Lng': -7.7039,
#   'Max Temp': 61.41,
#   'Humidity': 97,
#   'Cloudiness': 81,
#   'Wind Speed': 5.57,
#   'Country': 'IE',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:10'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 36.54,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Country': 'RU',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:21:10'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 70.41,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:11'},
#  {'City': 'Bafra',
#   'Lat': 41.5678,
#   'Lng': 35.9069,
#   'Max Temp': 58.82,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.4,
#   'Country': 'TR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:11'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 39.11,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 18.9,
#   'Country': 'IS',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:21:12'},
#  {'City': 'Provost',
#   'Lat': 52.3501,
#   'Lng': -110.2683,
#   'Max Temp': 64.85,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:12'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 38.39,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'MN',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:13'},
#  {'City': 'Khuzdar',
#   'Lat': 27.7384,
#   'Lng': 66.6434,
#   'Max Temp': 75.31,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 4.09,
#   'Country': 'PK',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:13'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 83.93,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:16:50'},
#  {'City': 'Livingston',
#   'Lat': 55.9029,
#   'Lng': -3.5226,
#   'Max Temp': 62.47,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'GB',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:14'},
#  {'City': 'Savelugu',
#   'Lat': 9.6244,
#   'Lng': -0.8253,
#   'Max Temp': 73.85,
#   'Humidity': 92,
#   'Cloudiness': 42,
#   'Wind Speed': 4.94,
#   'Country': 'GH',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:21:14'},
#  {'City': 'Guatire',
#   'Lat': 10.4762,
#   'Lng': -66.5427,
#   'Max Temp': 81.1,
#   'Humidity': 95,
#   'Cloudiness': 12,
#   'Wind Speed': 3.24,
#   'Country': 'VE',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:21:14'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 32.99,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 20.47,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:15'},
#  {'City': 'Tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 78.69,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 1.23,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:15'},
#  {'City': 'Tres Arroyos',
#   'Lat': -38.3739,
#   'Lng': -60.2798,
#   'Max Temp': 56.5,
#   'Humidity': 76,
#   'Cloudiness': 77,
#   'Wind Speed': 13.02,
#   'Country': 'AR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:16'},
#  {'City': 'Divnomorskoye',
#   'Lat': 44.5011,
#   'Lng': 38.1353,
#   'Max Temp': 60.42,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 8.55,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:16'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 48.24,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 9.55,
#   'Country': 'CL',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:21:16'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 66.7,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:17'},
#  {'City': 'Neuquen',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 62.49,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:19:16'},
#  {'City': 'Ulaanbaatar',
#   'Lat': 47.9077,
#   'Lng': 106.8832,
#   'Max Temp': 35.73,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'MN',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:18:51'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 84.72,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Country': 'OM',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:18'},
#  {'City': 'Port Keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 86.52,
#   'Humidity': 51,
#   'Cloudiness': 5,
#   'Wind Speed': 7.56,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:19'},
#  {'City': 'San Lorenzo',
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp': 65.59,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'PY',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:19'},
#  {'City': 'Barcelos',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 64.54,
#   'Humidity': 96,
#   'Cloudiness': 62,
#   'Wind Speed': 4,
#   'Country': 'PT',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:20'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 31.8,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:20'},
#  {'City': 'Miri',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 84.34,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MY',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:21'},
#  {'City': 'Reforma',
#   'Lat': 18.1,
#   'Lng': -91.0167,
#   'Max Temp': 75.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.55,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:21'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 61.95,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 0.45,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:21'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 55.6,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:22'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 84.25,
#   'Humidity': 50,
#   'Cloudiness': 85,
#   'Wind Speed': 0.92,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:22'},
#  {'City': 'Tocopilla',
#   'Lat': -22.092,
#   'Lng': -70.1979,
#   'Max Temp': 64.92,
#   'Humidity': 65,
#   'Cloudiness': 2,
#   'Wind Speed': 8.46,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:22'},
#  {'City': 'Berbera',
#   'Lat': 10.4396,
#   'Lng': 45.0143,
#   'Max Temp': 87.67,
#   'Humidity': 63,
#   'Cloudiness': 27,
#   'Wind Speed': 0.2,
#   'Country': 'SO',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:23'},
#  {'City': 'Rock Sound',
#   'Lat': 24.9,
#   'Lng': -76.2,
#   'Max Temp': 83.53,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Country': 'BS',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:23'},
#  {'City': 'Southbridge',
#   'Lat': 42.0751,
#   'Lng': -72.0334,
#   'Max Temp': 67.03,
#   'Humidity': 94,
#   'Cloudiness': 72,
#   'Wind Speed': 1.07,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:23'},
#  {'City': 'Santo Tomas',
#   'Lat': 14.1079,
#   'Lng': 121.1414,
#   'Max Temp': 87.33,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4.83,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:24'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 79,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.72,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:24'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 70.29,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 27.25,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:26'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 39.04,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'SJ',
#   'Current Description': 'light intensity drizzle',
#   'Date': '2021-09-26 01:21:26'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 29.91,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 10.8,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:27'},
#  {'City': 'Mbanza-Ngungu',
#   'Lat': -5.25,
#   'Lng': 14.8667,
#   'Max Temp': 70.56,
#   'Humidity': 81,
#   'Cloudiness': 86,
#   'Wind Speed': 7.63,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:27'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 58.62,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:18:39'},
#  {'City': 'Meadow Lake',
#   'Lat': 34.8014,
#   'Lng': -106.5436,
#   'Max Temp': 69.67,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 15.03,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:28'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 74.73,
#   'Humidity': 86,
#   'Cloudiness': 76,
#   'Wind Speed': 6.06,
#   'Country': 'AO',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:28'},
#  {'City': 'Strelka',
#   'Lat': 58.0728,
#   'Lng': 93.0344,
#   'Max Temp': 36.84,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:28'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 71.58,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:29'},
#  {'City': 'High Prairie',
#   'Lat': 55.4334,
#   'Lng': -116.4858,
#   'Max Temp': 60.1,
#   'Humidity': 50,
#   'Cloudiness': 85,
#   'Wind Speed': 4.07,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:29'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 72.23,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:30'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 77.49,
#   'Humidity': 81,
#   'Cloudiness': 30,
#   'Wind Speed': 20.51,
#   'Country': 'SO',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:30'},
#  {'City': 'Kochubey',
#   'Lat': 44.3861,
#   'Lng': 46.5825,
#   'Max Temp': 55.38,
#   'Humidity': 83,
#   'Cloudiness': 92,
#   'Wind Speed': 13.78,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:30'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 63.66,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:31'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 81.3,
#   'Humidity': 72,
#   'Cloudiness': 92,
#   'Wind Speed': 7.34,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:31'},
#  {'City': 'Krasnaya Zarya',
#   'Lat': 52.7825,
#   'Lng': 37.6806,
#   'Max Temp': 50.29,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'RU',
#   'Current Description': 'moderate rain',
#   'Date': '2021-09-26 01:21:31'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 19.56,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:32'},
#  {'City': 'Marabba',
#   'Lat': 12.35,
#   'Lng': 32.1833,
#   'Max Temp': 73.13,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Country': 'SD',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:21:32'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 87.08,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'JP',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:21:32'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 78.17,
#   'Humidity': 75,
#   'Cloudiness': 21,
#   'Wind Speed': 1.95,
#   'Country': 'CV',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:18:51'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 74.44,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'ID',
#   'Current Description': 'moderate rain',
#   'Date': '2021-09-26 01:19:06'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 51.98,
#   'Humidity': 54,
#   'Cloudiness': 59,
#   'Wind Speed': 16.28,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:33'},
#  {'City': 'Malakal',
#   'Lat': 9.5334,
#   'Lng': 31.6605,
#   'Max Temp': 68.74,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Country': 'SS',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:34'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 69.55,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'ES',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:34'},
#  {'City': 'Orshanka',
#   'Lat': 56.9161,
#   'Lng': 47.8933,
#   'Max Temp': 41.68,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.54,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:35'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 78.53,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:35'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 32.31,
#   'Humidity': 84,
#   'Cloudiness': 10,
#   'Wind Speed': 6.91,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:35'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 54.19,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'mist',
#   'Date': '2021-09-26 01:21:36'},
#  {'City': 'Malanje',
#   'Lat': -9.5402,
#   'Lng': 16.341,
#   'Max Temp': 67.21,
#   'Humidity': 73,
#   'Cloudiness': 8,
#   'Wind Speed': 6.31,
#   'Country': 'AO',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:36'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 39.36,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:36'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 63.68,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.51,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:37'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 72.46,
#   'Humidity': 70,
#   'Cloudiness': 58,
#   'Wind Speed': 5.37,
#   'Country': 'NC',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:37'},
#  {'City': 'Lieksa',
#   'Lat': 63.3167,
#   'Lng': 30.0167,
#   'Max Temp': 45.95,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.19,
#   'Country': 'FI',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:37'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 85.71,
#   'Humidity': 70,
#   'Cloudiness': 84,
#   'Wind Speed': 6.22,
#   'Country': 'SB',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:38'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 46.58,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:38'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 72.39,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.94,
#   'Country': 'IL',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:01'},
#  {'City': 'Shangqiu',
#   'Lat': 34.45,
#   'Lng': 115.65,
#   'Max Temp': 69.12,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:16:58'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 75.31,
#   'Humidity': 64,
#   'Cloudiness': 7,
#   'Wind Speed': 5.75,
#   'Country': 'VU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:39'},
#  {'City': 'Minot',
#   'Lat': 48.2325,
#   'Lng': -101.2963,
#   'Max Temp': 75.42,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:19:23'},
#  {'City': 'Mpika',
#   'Lat': -11.8343,
#   'Lng': 31.4529,
#   'Max Temp': 59.58,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 5.97,
#   'Country': 'ZM',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:39'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 64.4,
#   'Humidity': 31,
#   'Cloudiness': 61,
#   'Wind Speed': 24.16,
#   'Country': 'AR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:21:40'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 71.2,
#   'Humidity': 70,
#   'Cloudiness': 45,
#   'Wind Speed': 8.3,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:21:41'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 80.47,
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 12.33,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:21:41'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 57.25,
#   'Humidity': 94,
#   'Cloudiness': 6,
#   'Wind Speed': 5.41,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:42'},
#  {'City': 'Beaverlodge',
#   'Lat': 55.2166,
#   'Lng': -119.4361,
#   'Max Temp': 58.35,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Country': 'CA',
# ...
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:08'},
#  {'City': 'Duekoue',
#   'Lat': 6.7472,
#   'Lng': -7.3496,
#   'Max Temp': 71.4,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'CI',
#   'Current Description': 'light rain',
#   'Date': '2021-09-26 01:24:09'},
#  {'City': 'Fonte Boa',
#   'Lat': -2.4959,
#   'Lng': -66.2662,
#   'Max Temp': 73.18,
#   'Humidity': 94,
#   'Cloudiness': 61,
#   'Wind Speed': 2.21,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:09'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 82.17,
#   'Humidity': 77,
#   'Cloudiness': 66,
#   'Wind Speed': 10.47,
#   'Country': 'MX',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:09'},
#  {'City': 'Canutama',
#   'Lat': -6.5339,
#   'Lng': -64.3831,
#   'Max Temp': 75.16,
#   'Humidity': 86,
#   'Cloudiness': 93,
#   'Wind Speed': 2.04,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:10'},
#  {'City': 'Yelizovo',
#   'Lat': 53.1873,
#   'Lng': 158.3805,
#   'Max Temp': 57.34,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:24:10'},
#  {'City': 'Mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 80.08,
#   'Humidity': 85,
#   'Cloudiness': 6,
#   'Wind Speed': 8.86,
#   'Country': 'GF',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:10'},
#  {'City': 'Aktau',
#   'Lat': 43.65,
#   'Lng': 51.2,
#   'Max Temp': 55.98,
#   'Humidity': 65,
#   'Cloudiness': 97,
#   'Wind Speed': 14.72,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:11'},
#  {'City': 'Catamarca',
#   'Lat': -28.4696,
#   'Lng': -65.7852,
#   'Max Temp': 71.58,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 17.52,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:20:44'},
#  {'City': 'Kuandian',
#   'Lat': 40.7286,
#   'Lng': 124.7847,
#   'Max Temp': 66.61,
#   'Humidity': 79,
#   'Cloudiness': 7,
#   'Wind Speed': 2.59,
#   'Country': 'CN',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:11'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 79.16,
#   'Humidity': 82,
#   'Cloudiness': 81,
#   'Wind Speed': 7.96,
#   'Country': 'IN',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:12'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 33.75,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:12'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 69.1,
#   'Humidity': 76,
#   'Cloudiness': 28,
#   'Wind Speed': 16.67,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:09'},
#  {'City': 'Sakaraha',
#   'Lat': -22.9,
#   'Lng': 44.5333,
#   'Max Temp': 60.84,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Country': 'MG',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:13'},
#  {'City': 'Kishtwar',
#   'Lat': 33.3167,
#   'Lng': 75.7667,
#   'Max Temp': 59.02,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.31,
#   'Country': 'IN',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:13'},
#  {'City': 'Francisco Sa',
#   'Lat': -16.4758,
#   'Lng': -43.4883,
#   'Max Temp': 73.54,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 15.3,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:13'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 71.51,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:14'},
#  {'City': 'Cozumel',
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 82.38,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:14'},
#  {'City': 'Blythe',
#   'Lat': 33.6103,
#   'Lng': -114.5964,
#   'Max Temp': 91.04,
#   'Humidity': 27,
#   'Cloudiness': 39,
#   'Wind Speed': 2.8,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:14'},
#  {'City': 'Bauchi',
#   'Lat': 10.5,
#   'Lng': 10,
#   'Max Temp': 71.38,
#   'Humidity': 83,
#   'Cloudiness': 74,
#   'Wind Speed': 5.55,
#   'Country': 'NG',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:15'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 46.69,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:16'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 73.62,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:16'},
#  {'City': 'Fukue',
#   'Lat': 32.6881,
#   'Lng': 128.8419,
#   'Max Temp': 77.36,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:16'},
#  {'City': 'Kankakee',
#   'Lat': 41.15,
#   'Lng': -87.8667,
#   'Max Temp': 64.87,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:17'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AO',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:17'},
#  {'City': 'Hadejia',
#   'Lat': 12.4498,
#   'Lng': 10.0444,
#   'Max Temp': 77.97,
#   'Humidity': 62,
#   'Cloudiness': 8,
#   'Wind Speed': 6.89,
#   'Country': 'NG',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:17'},
#  {'City': 'Uray',
#   'Lat': 60.1247,
#   'Lng': 64.7758,
#   'Max Temp': 30.38,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.64,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:18'},
#  {'City': 'Shetpe',
#   'Lat': 44.1667,
#   'Lng': 52.1167,
#   'Max Temp': 55.49,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:18'},
#  {'City': 'Trofors',
#   'Lat': 65.5333,
#   'Lng': 13.4063,
#   'Max Temp': 47.55,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.44,
#   'Country': 'NO',
#   'Current Description': 'moderate rain',
#   'Date': '2021-09-26 01:24:19'},
#  {'City': 'Sovetskiy',
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp': 31.1,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 8.37,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:19'},
#  {'City': 'Maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 75.25,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 9.57,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:19'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 61.32,
#   'Humidity': 25,
#   'Cloudiness': 51,
#   'Wind Speed': 5.91,
#   'Country': 'SA',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:20'},
#  {'City': 'Cuamba',
#   'Lat': -14.8031,
#   'Lng': 36.5372,
#   'Max Temp': 69.85,
#   'Humidity': 59,
#   'Cloudiness': 8,
#   'Wind Speed': 3.09,
#   'Country': 'MZ',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:20'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 71.35,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ES',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:21'},
#  {'City': 'Wonthaggi',
#   'Lat': -38.6044,
#   'Lng': 145.5913,
#   'Max Temp': 60.94,
#   'Humidity': 54,
#   'Cloudiness': 6,
#   'Wind Speed': 6.71,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:21'},
#  {'City': 'Dawei',
#   'Lat': 14.0833,
#   'Lng': 98.2,
#   'Max Temp': 74.37,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Country': 'MM',
#   'Current Description': 'moderate rain',
#   'Date': '2021-09-26 01:24:21'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 35.44,
#   'Humidity': 76,
#   'Cloudiness': 35,
#   'Wind Speed': 15.03,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:22'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 27.03,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 8.21,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:22'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 79.72,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 12.5,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:22'},
#  {'City': 'Luwuk',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Max Temp': 83.89,
#   'Humidity': 71,
#   'Cloudiness': 93,
#   'Wind Speed': 6.73,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:23'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 51.89,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:23'},
#  {'City': 'La Malbaie',
#   'Lat': 47.6575,
#   'Lng': -70.1559,
#   'Max Temp': 59.9,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:24'},
#  {'City': 'Howick',
#   'Lat': -29.4779,
#   'Lng': 30.2306,
#   'Max Temp': 65.1,
#   'Humidity': 41,
#   'Cloudiness': 10,
#   'Wind Speed': 5.99,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:24'},
#  {'City': 'Casablanca',
#   'Lat': 33.5928,
#   'Lng': -7.6192,
#   'Max Temp': 71.33,
#   'Humidity': 68,
#   'Cloudiness': 5,
#   'Wind Speed': 11.01,
#   'Country': 'MA',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:21:02'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 79.75,
#   'Humidity': 62,
#   'Cloudiness': 97,
#   'Wind Speed': 3.04,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:25'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 73.47,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 1.1,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:25'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 37.99,
#   'Humidity': 41,
#   'Cloudiness': 88,
#   'Wind Speed': 2.77,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:25'},
#  {'City': 'Algiers',
#   'Lat': 36.7525,
#   'Lng': 3.042,
#   'Max Temp': 75.02,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'DZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:26'},
#  {'City': 'Shuangyang',
#   'Lat': 43.5242,
#   'Lng': 125.6736,
#   'Max Temp': 65.14,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:26'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 93.33,
#   'Humidity': 16,
#   'Cloudiness': 16,
#   'Wind Speed': 1.7,
#   'Country': 'ML',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:24:26'},
#  {'City': 'Skibotn',
#   'Lat': 69.3913,
#   'Lng': 20.2679,
#   'Max Temp': 42.89,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 3.96,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:27'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 47.8,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.93,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:27'},
#  {'City': 'Dewa',
#   'Lat': 27.0333,
#   'Lng': 81.1667,
#   'Max Temp': 78.8,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 5.26,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:28'},
#  {'City': 'Den Helder',
#   'Lat': 52.9599,
#   'Lng': 4.7593,
#   'Max Temp': 62.94,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'NL',
#   'Current Description': 'mist',
#   'Date': '2021-09-26 01:24:28'},
#  {'City': 'Sokoni',
#   'Lat': -6.4333,
#   'Lng': 39.55,
#   'Max Temp': 76.19,
#   'Humidity': 78,
#   'Cloudiness': 31,
#   'Wind Speed': 10.42,
#   'Country': 'TZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:28'},
#  {'City': 'Kaa-Khem',
#   'Lat': 51.6833,
#   'Lng': 94.7333,
#   'Max Temp': 38.46,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:29'},
#  {'City': 'Bowmore',
#   'Lat': 34.9421,
#   'Lng': -79.3031,
#   'Max Temp': 66.74,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:29'},
#  {'City': 'Muroto',
#   'Lat': 33.2833,
#   'Lng': 134.15,
#   'Max Temp': 80.64,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 12.93,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:30'},
#  {'City': 'Crossville',
#   'Lat': 35.949,
#   'Lng': -85.0269,
#   'Max Temp': 60.93,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:20'},
#  {'City': 'Varzea Da Palma',
#   'Lat': -17.5981,
#   'Lng': -44.7308,
#   'Max Temp': 81.32,
#   'Humidity': 37,
#   'Cloudiness': 45,
#   'Wind Speed': 8.7,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:30'},
#  {'City': 'Vilhena',
#   'Lat': -12.7406,
#   'Lng': -60.1458,
#   'Max Temp': 82.65,
#   'Humidity': 42,
#   'Cloudiness': 94,
#   'Wind Speed': 5.91,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:31'},
#  {'City': 'Isawa',
#   'Lat': 35.65,
#   'Lng': 138.6333,
#   'Max Temp': 67.37,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 1.01,
#   'Country': 'JP',
#   'Current Description': 'moderate rain',
#   'Date': '2021-09-26 01:24:31'},
#  {'City': 'Ormara',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 81.36,
#   'Humidity': 77,
#   'Cloudiness': 11,
#   'Wind Speed': 8.37,
#   'Country': 'PK',
#   'Current Description': 'few clouds',
#   'Date': '2021-09-26 01:24:31'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 48.85,
#   'Humidity': 95,
#   'Cloudiness': 1,
#   'Wind Speed': 6.55,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:32'},
#  {'City': 'Koslan',
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp': 44.73,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:32'},
#  {'City': 'Muravlenko',
#   'Lat': 63.7898,
#   'Lng': 74.523,
#   'Max Temp': 30.85,
#   'Humidity': 80,
#   'Cloudiness': 68,
#   'Wind Speed': 8.34,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2021-09-26 01:24:33'},
#  {'City': 'Umea',
#   'Lat': 63.8284,
#   'Lng': 20.2597,
#   'Max Temp': 37.33,
#   'Humidity': 93,
#   'Cloudiness': 42,
#   'Wind Speed': 5.75,
#   'Country': 'SE',
#   'Current Description': 'scattered clouds',
#   'Date': '2021-09-26 01:24:34'},
#  {'City': 'Bloemfontein',
#   'Lat': -29.1211,
#   'Lng': 26.214,
#   'Max Temp': 51.28,
#   'Humidity': 62,
#   'Cloudiness': 86,
#   'Wind Speed': 1.14,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2021-09-26 01:24:34'},
#  {'City': 'Colorado',
#   'Lat': -22.8375,
#   'Lng': -51.9731,
#   'Max Temp': 75.29,
#   'Humidity': 55,
#   'Cloudiness': 10,
#   'Wind Speed': 6.26,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2021-09-26 01:24:34'}]

# %%
#Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Jamestown  42.0970  -79.2353     60.39        62          75
# 1                 Atuona  -9.8000 -139.0333     77.76        77          23
# 2             Vila Velha -20.3297  -40.2925     71.55        73          75
# 3                  Paita  -5.0892  -81.1144     64.62        86          60
# 4               Souillac -20.5167   57.5167     70.36        79          25
# 5                  Aswan  24.0934   32.9070     78.01        28          14
# 6  San Jose De Rio Tinto  14.9333  -85.7000     78.37        97         100
# 7         Saint-Philippe -21.3585   55.7679     67.55        87          68
# 8           Puerto Ayora  -0.7393  -90.3518     69.51        90          92
# 9             Nikolskoye  59.7035   30.7861     47.01        93          99
#
#    Wind Speed Country Current Description                 Date
# 0        4.00      US       broken clouds  2021-09-26 01:20:14
# 1       19.35      PF          light rain  2021-09-26 01:20:14
# 2        6.91      BR       broken clouds  2021-09-26 01:19:05
# 3       16.62      PE       broken clouds  2021-09-26 01:20:14
# 4       15.55      MU    scattered clouds  2021-09-26 01:20:15
# 5       11.21      EG          few clouds  2021-09-26 01:20:15
# 6        3.60      HN     overcast clouds  2021-09-26 01:20:16
# 7       12.73      RE          light rain  2021-09-26 01:20:16
# 8        8.43      EC     overcast clouds  2021-09-26 01:20:16
# 9        8.52      RU     overcast clouds  2021-09-26 01:20:17

# %%
new_column_order =  ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown      US  42.0970  -79.2353     60.39        62          75
# 1           Atuona      PF  -9.8000 -139.0333     77.76        77          23
# 2       Vila Velha      BR -20.3297  -40.2925     71.55        73          75
# 3            Paita      PE  -5.0892  -81.1144     64.62        86          60
# 4         Souillac      MU -20.5167   57.5167     70.36        79          25
# ...            ...     ...      ...       ...       ...       ...         ...
# 1339        Koslan      RU  63.4564   48.8989     44.94        96         100
# 1340    Muravlenko      RU  63.7898   74.5230     31.62        79          50
# 1341          Umea      SE  63.8284   20.2597     37.33        93           0
# 1342  Bloemfontein      ZA -29.1211   26.2140     51.28        62          93
# 1343      Colorado      BR -22.8375  -51.9731     73.54        58           6
#
#       Wind Speed Current Description
# 0           4.00       broken clouds
# 1          19.35          light rain
# 2           6.91       broken clouds
# 3          16.62       broken clouds
# 4          15.55    scattered clouds
# ...          ...                 ...
# 1339        6.85     overcast clouds
# 1340        7.76    scattered clouds
# 1341        2.30           clear sky
# 1342        1.14     overcast clouds
# 1343        5.93           clear sky
#
# [1344 rows x 9 columns]
