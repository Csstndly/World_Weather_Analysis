# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import o_weather
import requests
import gmaps
from scipy.stats import linregress
from datetime import datetime
from config import g_maps_key
gmaps.configure(api_key=g_maps_key)
from citipy import citipy

# %%
## Deliverable 1

# %%
# Starting URL for Weather Map API Call. 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + o_weather

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
#Create a empty list for df
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters./ want the 1st iteration of the logging for each recorded response
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Looping through every city in the list 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description":city_descr })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | dubbo
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | port blair
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | huarmey
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | los llanos de aridane
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | tevaitoa
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | pacifica
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | kempele
# Processing Record 21 of Set 1 | aloleng
# Processing Record 22 of Set 1 | tadine
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | fairview
# Processing Record 25 of Set 1 | korla
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | galeana
# Processing Record 28 of Set 1 | sobolevo
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | fort nelson
# Processing Record 32 of Set 1 | saint anthony
# Processing Record 33 of Set 1 | mae sai
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | vostok
# Processing Record 37 of Set 1 | shakawe
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | griffith
# Processing Record 40 of Set 1 | kamen-na-obi
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | yaan
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | vao
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | college
# Processing Record 1 of Set 2 | neosho
# Processing Record 2 of Set 2 | asau
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | zhangjiakou
# Processing Record 9 of Set 2 | talnakh
# Processing Record 10 of Set 2 | vigia
# Processing Record 11 of Set 2 | mount isa
# Processing Record 12 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 13 of Set 2 | tumaco
# Processing Record 14 of Set 2 | kuzhener
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | kilmez
# City not found. Skipping...
# Processing Record 17 of Set 2 | alta floresta
# Processing Record 18 of Set 2 | rupert
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | tessalit
# Processing Record 24 of Set 2 | xining
# Processing Record 25 of Set 2 | taltal
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | palmer
# Processing Record 28 of Set 2 | husavik
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | itanhem
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | pedernales
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | seguela
# Processing Record 39 of Set 2 | dzhida
# Processing Record 40 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | ornskoldsvik
# Processing Record 44 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 45 of Set 2 | bray
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | kande
# Processing Record 48 of Set 2 | san cosme y damian
# Processing Record 49 of Set 2 | west point
# Processing Record 50 of Set 2 | cayenne
# Processing Record 1 of Set 3 | nelson bay
# Processing Record 2 of Set 3 | dalbandin
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | beloha
# Processing Record 5 of Set 3 | yulara
# Processing Record 6 of Set 3 | roberval
# Processing Record 7 of Set 3 | cravo norte
# Processing Record 8 of Set 3 | xinyang
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | ahipara
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | elverum
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | ponta delgada
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | mairi
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | busselton
# Processing Record 24 of Set 3 | viedma
# Processing Record 25 of Set 3 | buala
# Processing Record 26 of Set 3 | hargeysa
# Processing Record 27 of Set 3 | saint-pierre
# Processing Record 28 of Set 3 | oistins
# Processing Record 29 of Set 3 | bayan
# Processing Record 30 of Set 3 | pochutla
# Processing Record 31 of Set 3 | skjervoy
# Processing Record 32 of Set 3 | marzuq
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | dingle
# Processing Record 35 of Set 3 | mahon
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | khandyga
# Processing Record 39 of Set 3 | soure
# Processing Record 40 of Set 3 | san cristobal
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | lethem
# Processing Record 43 of Set 3 | zyryanka
# Processing Record 44 of Set 3 | ferrol
# Processing Record 45 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 3 | yerbogachen
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | comodoro rivadavia
# Processing Record 49 of Set 3 | tahta
# Processing Record 50 of Set 3 | mahajanga
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | darbhanga
# Processing Record 6 of Set 4 | qrendi
# Processing Record 7 of Set 4 | yuncheng
# Processing Record 8 of Set 4 | nantucket
# Processing Record 9 of Set 4 | grand gaube
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | le port
# Processing Record 12 of Set 4 | kitzingen
# Processing Record 13 of Set 4 | dezhou
# Processing Record 14 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | axim
# Processing Record 19 of Set 4 | moquegua
# Processing Record 20 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 4 | corlu
# Processing Record 22 of Set 4 | pareora
# Processing Record 23 of Set 4 | port keats
# Processing Record 24 of Set 4 | dikson
# Processing Record 25 of Set 4 | bara
# Processing Record 26 of Set 4 | luganville
# Processing Record 27 of Set 4 | mpika
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | cockburn town
# Processing Record 30 of Set 4 | vestmannaeyjar
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | banepa
# Processing Record 33 of Set 4 | jacareacanga
# Processing Record 34 of Set 4 | terney
# Processing Record 35 of Set 4 | otjiwarongo
# Processing Record 36 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 37 of Set 4 | porto novo
# Processing Record 38 of Set 4 | port elizabeth
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | sibolga
# Processing Record 41 of Set 4 | lasa
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | krasnokamensk
# Processing Record 44 of Set 4 | kirakira
# Processing Record 45 of Set 4 | hambantota
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | north bend
# Processing Record 48 of Set 4 | newport
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | tuatapere
# Processing Record 1 of Set 5 | barrow
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | edgecumbe
# Processing Record 4 of Set 5 | sri aman
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | westport
# Processing Record 8 of Set 5 | yunhe
# Processing Record 9 of Set 5 | usinsk
# Processing Record 10 of Set 5 | tecoanapa
# Processing Record 11 of Set 5 | koumac
# Processing Record 12 of Set 5 | creel
# Processing Record 13 of Set 5 | nueve de julio
# Processing Record 14 of Set 5 | arlit
# Processing Record 15 of Set 5 | lumberton
# Processing Record 16 of Set 5 | lavrentiya
# Processing Record 17 of Set 5 | dir
# Processing Record 18 of Set 5 | charters towers
# Processing Record 19 of Set 5 | janauba
# Processing Record 20 of Set 5 | rabo de peixe
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | te anau
# Processing Record 24 of Set 5 | olyka
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | port augusta
# Processing Record 27 of Set 5 | vaini
# Processing Record 28 of Set 5 | teahupoo
# Processing Record 29 of Set 5 | muros
# Processing Record 30 of Set 5 | severo-kurilsk
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | ryotsu
# Processing Record 34 of Set 5 | sechura
# Processing Record 35 of Set 5 | jalu
# Processing Record 36 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 5 | siteki
# Processing Record 38 of Set 5 | qaanaaq
# Processing Record 39 of Set 5 | piracaia
# Processing Record 40 of Set 5 | sao felix do xingu
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | keti bandar
# Processing Record 43 of Set 5 | alofi
# Processing Record 44 of Set 5 | tanete
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | neuquen
# Processing Record 47 of Set 5 | maxixe
# Processing Record 48 of Set 5 | tanah merah
# Processing Record 49 of Set 5 | tommot
# Processing Record 50 of Set 5 | gawler
# Processing Record 1 of Set 6 | miles city
# Processing Record 2 of Set 6 | razdolnoye
# Processing Record 3 of Set 6 | niquero
# Processing Record 4 of Set 6 | hamilton
# Processing Record 5 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 6 | bridgewater
# Processing Record 7 of Set 6 | nicoya
# Processing Record 8 of Set 6 | takapau
# Processing Record 9 of Set 6 | den helder
# Processing Record 10 of Set 6 | byumba
# Processing Record 11 of Set 6 | sitka
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | kukushtan
# Processing Record 14 of Set 6 | iralaya
# Processing Record 15 of Set 6 | rio gallegos
# Processing Record 16 of Set 6 | inhambane
# Processing Record 17 of Set 6 | littleton
# Processing Record 18 of Set 6 | challapata
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | marolambo
# Processing Record 21 of Set 6 | disna
# Processing Record 22 of Set 6 | tilichiki
# Processing Record 23 of Set 6 | torbay
# Processing Record 24 of Set 6 | mehamn
# Processing Record 25 of Set 6 | alice town
# Processing Record 26 of Set 6 | bontang
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | narsaq
# Processing Record 29 of Set 6 | puerto del rosario
# Processing Record 30 of Set 6 | sakaiminato
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | zhuozhou
# City not found. Skipping...
# Processing Record 33 of Set 6 | heinola
# Processing Record 34 of Set 6 | san luis
# Processing Record 35 of Set 6 | sambava
# Processing Record 36 of Set 6 | wanning
# Processing Record 37 of Set 6 | okoneshnikovo
# Processing Record 38 of Set 6 | antalaha
# Processing Record 39 of Set 6 | ngorongoro
# Processing Record 40 of Set 6 | lensk
# Processing Record 41 of Set 6 | san carlos
# Processing Record 42 of Set 6 | amol
# Processing Record 43 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 6 | teguise
# Processing Record 45 of Set 6 | altay
# Processing Record 46 of Set 6 | santa rosa
# Processing Record 47 of Set 6 | leh
# Processing Record 48 of Set 6 | luziania
# Processing Record 49 of Set 6 | banamba
# Processing Record 50 of Set 6 | san quintin
# Processing Record 1 of Set 7 | luwero
# Processing Record 2 of Set 7 | imeni poliny osipenko
# Processing Record 3 of Set 7 | faanui
# Processing Record 4 of Set 7 | saint-francois
# Processing Record 5 of Set 7 | shakiso
# Processing Record 6 of Set 7 | sistranda
# Processing Record 7 of Set 7 | hasaki
# Processing Record 8 of Set 7 | shieli
# Processing Record 9 of Set 7 | lakhimpur
# Processing Record 10 of Set 7 | plouzane
# Processing Record 11 of Set 7 | tigre
# Processing Record 12 of Set 7 | gamboma
# Processing Record 13 of Set 7 | vila velha
# Processing Record 14 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 7 | walvis bay
# Processing Record 16 of Set 7 | lewiston
# Processing Record 17 of Set 7 | roebourne
# Processing Record 18 of Set 7 | victoria
# Processing Record 19 of Set 7 | ust-uda
# Processing Record 20 of Set 7 | malanje
# Processing Record 21 of Set 7 | velyka oleksandrivka
# Processing Record 22 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 7 | najran
# Processing Record 24 of Set 7 | catamarca
# Processing Record 25 of Set 7 | vanersborg
# Processing Record 26 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 7 | acapulco
# Processing Record 28 of Set 7 | avarua
# Processing Record 29 of Set 7 | gboko
# Processing Record 30 of Set 7 | tateyama
# Processing Record 31 of Set 7 | tiksi
# Processing Record 32 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 35 of Set 7 | awbari
# Processing Record 36 of Set 7 | east stroudsburg
# Processing Record 37 of Set 7 | haines junction
# Processing Record 38 of Set 7 | outjo
# Processing Record 39 of Set 7 | oussouye
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | oshikango
# Processing Record 42 of Set 7 | bani walid
# Processing Record 43 of Set 7 | sarmanovo
# Processing Record 44 of Set 7 | yatou
# Processing Record 45 of Set 7 | tiarei
# Processing Record 46 of Set 7 | danane
# Processing Record 47 of Set 7 | aklavik
# Processing Record 48 of Set 7 | colares
# Processing Record 49 of Set 7 | leningradskiy
# Processing Record 50 of Set 7 | richards bay
# Processing Record 1 of Set 8 | urumqi
# Processing Record 2 of Set 8 | toora-khem
# Processing Record 3 of Set 8 | chacaltianguis
# Processing Record 4 of Set 8 | floro
# Processing Record 5 of Set 8 | springdale
# Processing Record 6 of Set 8 | puerto escondido
# Processing Record 7 of Set 8 | moyale
# Processing Record 8 of Set 8 | misratah
# Processing Record 9 of Set 8 | san julian
# Processing Record 10 of Set 8 | ossora
# Processing Record 11 of Set 8 | galle
# Processing Record 12 of Set 8 | tornio
# Processing Record 13 of Set 8 | aktash
# Processing Record 14 of Set 8 | tairua
# Processing Record 15 of Set 8 | inndyr
# Processing Record 16 of Set 8 | honiara
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | dickinson
# Processing Record 19 of Set 8 | guatire
# Processing Record 20 of Set 8 | mokolo
# Processing Record 21 of Set 8 | saskylakh
# Processing Record 22 of Set 8 | bergerac
# Processing Record 23 of Set 8 | havoysund
# Processing Record 24 of Set 8 | bukama
# Processing Record 25 of Set 8 | padang
# Processing Record 26 of Set 8 | povenets
# Processing Record 27 of Set 8 | pacific grove
# Processing Record 28 of Set 8 | nadvirna
# Processing Record 29 of Set 8 | norman wells
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 32 of Set 8 | mogadishu
# Processing Record 33 of Set 8 | constitucion
# Processing Record 34 of Set 8 | aguililla
# Processing Record 35 of Set 8 | saint augustine
# Processing Record 36 of Set 8 | columbia
# Processing Record 37 of Set 8 | pasighat
# Processing Record 38 of Set 8 | mayo
# Processing Record 39 of Set 8 | mmathubudukwane
# Processing Record 40 of Set 8 | novyy urgal
# Processing Record 41 of Set 8 | sarangani
# Processing Record 42 of Set 8 | vardo
# Processing Record 43 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 44 of Set 8 | daru
# Processing Record 45 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 8 | urusha
# Processing Record 47 of Set 8 | yura
# Processing Record 48 of Set 8 | san jeronimo
# Processing Record 49 of Set 8 | ketchikan
# Processing Record 50 of Set 8 | camacupa
# Processing Record 1 of Set 9 | liverpool
# Processing Record 2 of Set 9 | neryungri
# Processing Record 3 of Set 9 | morlaix
# Processing Record 4 of Set 9 | cubulco
# Processing Record 5 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | lata
# Processing Record 7 of Set 9 | strezhevoy
# Processing Record 8 of Set 9 | harper
# Processing Record 9 of Set 9 | jiuquan
# Processing Record 10 of Set 9 | tabat
# Processing Record 11 of Set 9 | lorengau
# Processing Record 12 of Set 9 | ramhormoz
# Processing Record 13 of Set 9 | thano bula khan
# City not found. Skipping...
# Processing Record 14 of Set 9 | barro
# Processing Record 15 of Set 9 | svetlogorsk
# Processing Record 16 of Set 9 | naze
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 9 | preobrazheniye
# Processing Record 20 of Set 9 | petrykivka
# Processing Record 21 of Set 9 | darhan
# Processing Record 22 of Set 9 | adrar
# Processing Record 23 of Set 9 | katsuura
# Processing Record 24 of Set 9 | boende
# Processing Record 25 of Set 9 | deputatskiy
# Processing Record 26 of Set 9 | carutapera
# Processing Record 27 of Set 9 | sandwick
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | naryan-mar
# Processing Record 30 of Set 9 | atambua
# Processing Record 31 of Set 9 | smithers
# Processing Record 32 of Set 9 | atar
# Processing Record 33 of Set 9 | jambi
# Processing Record 34 of Set 9 | balagansk
# Processing Record 35 of Set 9 | yelan-kolenovskiy
# Processing Record 36 of Set 9 | aripuana
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | canarana
# Processing Record 39 of Set 9 | tagpangi
# City not found. Skipping...
# Processing Record 40 of Set 9 | northam
# Processing Record 41 of Set 9 | biryusinsk
# Processing Record 42 of Set 9 | njombe
# Processing Record 43 of Set 9 | guilin
# Processing Record 44 of Set 9 | nalut
# Processing Record 45 of Set 9 | livani
# Processing Record 46 of Set 9 | touros
# Processing Record 47 of Set 9 | bintulu
# Processing Record 48 of Set 9 | la palma
# Processing Record 49 of Set 9 | barcelos
# Processing Record 50 of Set 9 | eyrarbakki
# Processing Record 1 of Set 10 | paralimni
# Processing Record 2 of Set 10 | chengde
# Processing Record 3 of Set 10 | dauphin
# Processing Record 4 of Set 10 | bettange-sur-mess
# Processing Record 5 of Set 10 | changli
# Processing Record 6 of Set 10 | adre
# Processing Record 7 of Set 10 | xiongzhou
# Processing Record 8 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 9 of Set 10 | teguldet
# Processing Record 10 of Set 10 | el sauzal
# Processing Record 11 of Set 10 | avera
# Processing Record 12 of Set 10 | tabou
# Processing Record 13 of Set 10 | yei
# Processing Record 14 of Set 10 | bestobe
# Processing Record 15 of Set 10 | altus
# Processing Record 16 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 17 of Set 10 | brokopondo
# Processing Record 18 of Set 10 | nadym
# Processing Record 19 of Set 10 | bambanglipuro
# Processing Record 20 of Set 10 | opuwo
# Processing Record 21 of Set 10 | la ronge
# Processing Record 22 of Set 10 | birjand
# Processing Record 23 of Set 10 | healdsburg
# Processing Record 24 of Set 10 | mauganj
# Processing Record 25 of Set 10 | sayat
# Processing Record 26 of Set 10 | lagos
# Processing Record 27 of Set 10 | casper
# Processing Record 28 of Set 10 | balabac
# Processing Record 29 of Set 10 | sur
# Processing Record 30 of Set 10 | cururupu
# Processing Record 31 of Set 10 | kathmandu
# Processing Record 32 of Set 10 | waipawa
# Processing Record 33 of Set 10 | kahului
# Processing Record 34 of Set 10 | tomari
# Processing Record 35 of Set 10 | cadca
# Processing Record 36 of Set 10 | noumea
# Processing Record 37 of Set 10 | bayir
# Processing Record 38 of Set 10 | flin flon
# Processing Record 39 of Set 10 | kiruna
# Processing Record 40 of Set 10 | biloela
# Processing Record 41 of Set 10 | ewo
# Processing Record 42 of Set 10 | indiaroba
# Processing Record 43 of Set 10 | aldan
# Processing Record 44 of Set 10 | riyadh
# Processing Record 45 of Set 10 | tahe
# Processing Record 46 of Set 10 | lazaro cardenas
# Processing Record 47 of Set 10 | ambilobe
# Processing Record 48 of Set 10 | aljezur
# Processing Record 49 of Set 10 | marawi
# Processing Record 50 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 11 | camacha
# Processing Record 2 of Set 11 | asmar
# Processing Record 3 of Set 11 | taranagar
# Processing Record 4 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 5 of Set 11 | kristiinankaupunki
# Processing Record 6 of Set 11 | terrace
# Processing Record 7 of Set 11 | the valley
# Processing Record 8 of Set 11 | kingori
# Processing Record 9 of Set 11 | coquimbo
# Processing Record 10 of Set 11 | cabedelo
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | bezhanitsy
# Processing Record 13 of Set 11 | mocuba
# Processing Record 14 of Set 11 | puerto suarez
# Processing Record 15 of Set 11 | luanshya
# Processing Record 16 of Set 11 | zhicheng
# Processing Record 17 of Set 11 | oreanda
# City not found. Skipping...
# Processing Record 18 of Set 11 | matagami
# Processing Record 19 of Set 11 | musoma
# Processing Record 20 of Set 11 | coahuayana
# Processing Record 21 of Set 11 | sisimiut
# Processing Record 22 of Set 11 | hot springs
# Processing Record 23 of Set 11 | srednekolymsk
# Processing Record 24 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 11 | aksu
# Processing Record 26 of Set 11 | akyab
# Processing Record 27 of Set 11 | rosarito
# Processing Record 28 of Set 11 | hvide sande
# Processing Record 29 of Set 11 | salalah
# Processing Record 30 of Set 11 | vila franca do campo
# Processing Record 31 of Set 11 | churapcha
# Processing Record 32 of Set 11 | kibala
# Processing Record 33 of Set 11 | khani
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | batagay-alyta
# Processing Record 36 of Set 11 | ayaviri
# Processing Record 37 of Set 11 | saint-vallier
# Processing Record 38 of Set 11 | koumra
# Processing Record 39 of Set 11 | jalingo
# Processing Record 40 of Set 11 | lilongwe
# Processing Record 41 of Set 11 | carayao
# Processing Record 42 of Set 11 | dauriya
# Processing Record 43 of Set 11 | baruun-urt
# Processing Record 44 of Set 11 | chitipa
# Processing Record 45 of Set 11 | santa maria
# Processing Record 46 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 11 | quatre cocos
# Processing Record 48 of Set 11 | baracoa
# Processing Record 49 of Set 11 | los algarrobos
# Processing Record 50 of Set 11 | abancay
# Processing Record 1 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 2 of Set 12 | cobourg
# Processing Record 3 of Set 12 | mayumba
# Processing Record 4 of Set 12 | jieshi
# Processing Record 5 of Set 12 | tres lagoas
# Processing Record 6 of Set 12 | aktau
# Processing Record 7 of Set 12 | chake chake
# Processing Record 8 of Set 12 | mali
# Processing Record 9 of Set 12 | loiza
# Processing Record 10 of Set 12 | fortuna
# Processing Record 11 of Set 12 | bilibino
# Processing Record 12 of Set 12 | banjarmasin
# Processing Record 13 of Set 12 | pisco
# Processing Record 14 of Set 12 | port lincoln
# Processing Record 15 of Set 12 | camopi
# Processing Record 16 of Set 12 | yumen
# Processing Record 17 of Set 12 | guerrero negro
# Processing Record 18 of Set 12 | takoradi
# Processing Record 19 of Set 12 | saint johnsbury
# Processing Record 20 of Set 12 | marsh harbour
# Processing Record 21 of Set 12 | gladstone
# Processing Record 22 of Set 12 | boddam
# Processing Record 23 of Set 12 | conde
# Processing Record 24 of Set 12 | sabang
# Processing Record 25 of Set 12 | kloulklubed
# Processing Record 26 of Set 12 | laguna
# Processing Record 27 of Set 12 | nome
# Processing Record 28 of Set 12 | talakan
# Processing Record 29 of Set 12 | iracoubo
# Processing Record 30 of Set 12 | tambura
# Processing Record 31 of Set 12 | rosa zarate
# Processing Record 32 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 33 of Set 12 | ardalstangen
# Processing Record 34 of Set 12 | jiblah
# Processing Record 35 of Set 12 | abha
# Processing Record 36 of Set 12 | chateauroux
# Processing Record 37 of Set 12 | acarau
# Processing Record 38 of Set 12 | okha
# Processing Record 39 of Set 12 | kirksville
# Processing Record 40 of Set 12 | chabahar
# Processing Record 41 of Set 12 | tenenkou
# Processing Record 42 of Set 12 | olafsvik
# Processing Record 43 of Set 12 | sortavala
# Processing Record 44 of Set 12 | fukue
# Processing Record 45 of Set 12 | ilhabela
# Processing Record 46 of Set 12 | teshie
# Processing Record 47 of Set 12 | cedral
# Processing Record 48 of Set 12 | kosa
# Processing Record 49 of Set 12 | gao
# Processing Record 50 of Set 12 | sena madureira
# Processing Record 1 of Set 13 | shimoda
# Processing Record 2 of Set 13 | galesong
# Processing Record 3 of Set 13 | presidencia roque saenz pena
# Processing Record 4 of Set 13 | namatanai
# Processing Record 5 of Set 13 | tarazona
# Processing Record 6 of Set 13 | utete
# Processing Record 7 of Set 13 | west bay
# Processing Record 8 of Set 13 | kismayo
# Processing Record 9 of Set 13 | mpulungu
# Processing Record 10 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 13 | inuvik
# Processing Record 12 of Set 13 | fuyang
# Processing Record 13 of Set 13 | yaring
# Processing Record 14 of Set 13 | bardoli
# Processing Record 15 of Set 13 | malkangiri
# Processing Record 16 of Set 13 | rio grande
# Processing Record 17 of Set 13 | lyaskelya
# Processing Record 18 of Set 13 | qaqortoq
# Processing Record 19 of Set 13 | fengrun
# Processing Record 20 of Set 13 | prince rupert
# Processing Record 21 of Set 13 | aykhal
# Processing Record 22 of Set 13 | bitung
# Processing Record 23 of Set 13 | huescar
# Processing Record 24 of Set 13 | san lazaro
# Processing Record 25 of Set 13 | liwonde
# Processing Record 26 of Set 13 | aras
# Processing Record 27 of Set 13 | bambous virieux
# Processing Record 28 of Set 13 | canto do buriti
# Processing Record 29 of Set 13 | broome
# Processing Record 30 of Set 13 | ous
# Processing Record 31 of Set 13 | la rioja
# Processing Record 32 of Set 13 | fez
# Processing Record 33 of Set 13 | xinzhou
# Processing Record 34 of Set 13 | nemuro
# Processing Record 35 of Set 13 | bonavista
# Processing Record 36 of Set 13 | nuevitas
# Processing Record 37 of Set 13 | maniitsoq
# Processing Record 38 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 13 | lompoc
# Processing Record 40 of Set 13 | labuhan
# Processing Record 41 of Set 13 | birecik
# Processing Record 42 of Set 13 | desbiens
# Processing Record 43 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 13 | kobryn
# Processing Record 45 of Set 13 | fare
# Processing Record 46 of Set 13 | meulaboh
# Processing Record 47 of Set 13 | rognan
# Processing Record 48 of Set 13 | hokitika
# Processing Record 49 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 13 | krasnogvardeyets
# Processing Record 1 of Set 14 | ballina
# Processing Record 2 of Set 14 | katherine
# Processing Record 3 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 14 | toba
# Processing Record 5 of Set 14 | mabaruma
# Processing Record 6 of Set 14 | murdochville
# Processing Record 7 of Set 14 | kargat
# Processing Record 8 of Set 14 | mata
# Processing Record 9 of Set 14 | ukiah
# Processing Record 10 of Set 14 | letterkenny
# Processing Record 11 of Set 14 | denpasar
# Processing Record 12 of Set 14 | moose factory
# Processing Record 13 of Set 14 | jacksonville beach
# Processing Record 14 of Set 14 | helsinge
# Processing Record 15 of Set 14 | zhigansk
# Processing Record 16 of Set 14 | tashara
# Processing Record 17 of Set 14 | atasu
# Processing Record 18 of Set 14 | sirfa
# City not found. Skipping...
# Processing Record 19 of Set 14 | sandovo
# Processing Record 20 of Set 14 | bosaso
# Processing Record 21 of Set 14 | kaeo
# Processing Record 22 of Set 14 | ginda
# Processing Record 23 of Set 14 | sorland
# Processing Record 24 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 14 | hukuntsi
# Processing Record 26 of Set 14 | ambon
# Processing Record 27 of Set 14 | tabuk
# Processing Record 28 of Set 14 | itoman
# Processing Record 29 of Set 14 | saint-georges
# Processing Record 30 of Set 14 | wilmington
# Processing Record 31 of Set 14 | kununurra
# Processing Record 32 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 33 of Set 14 | xuddur
# Processing Record 34 of Set 14 | port moresby
# Processing Record 35 of Set 14 | gilgit
# Processing Record 36 of Set 14 | fayetteville
# Processing Record 37 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 14 | iskateley
# Processing Record 39 of Set 14 | mantua
# Processing Record 40 of Set 14 | gat
# Processing Record 41 of Set 14 | xinqing
# Processing Record 42 of Set 14 | ramanuj ganj
# Processing Record 43 of Set 14 | katangli
# Processing Record 44 of Set 14 | brasilia de minas
# Processing Record 45 of Set 14 | zhezkazgan
# Processing Record 46 of Set 14 | dukat
# Processing Record 47 of Set 14 | dicabisagan
# Processing Record 48 of Set 14 | kenai
# Processing Record 49 of Set 14 | gornopravdinsk
# Processing Record 50 of Set 14 | tual
# Processing Record 1 of Set 15 | ovalle
# Processing Record 2 of Set 15 | samarai
# Processing Record 3 of Set 15 | jaru
# Processing Record 4 of Set 15 | russell
# Processing Record 5 of Set 15 | novoselytsya
# Processing Record 6 of Set 15 | petrokhorion
# Processing Record 7 of Set 15 | ugoofaaru
# Processing Record 8 of Set 15 | somerset
# Processing Record 9 of Set 15 | gubkinskiy
# Processing Record 10 of Set 15 | bolondron
# Processing Record 11 of Set 15 | same
# Processing Record 12 of Set 15 | kendari
# Processing Record 13 of Set 15 | dolores
# Processing Record 14 of Set 15 | minab
# Processing Record 15 of Set 15 | watertown
# Processing Record 16 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 18 of Set 15 | altamira
# Processing Record 19 of Set 15 | puerto baquerizo moreno
# Processing Record 20 of Set 15 | qazvin
# Processing Record 21 of Set 15 | mehran
# Processing Record 22 of Set 15 | zlitan
# Processing Record 23 of Set 15 | riohacha
# Processing Record 24 of Set 15 | alice springs
# Processing Record 25 of Set 15 | victoria point
# Processing Record 26 of Set 15 | mantiquil
# Processing Record 27 of Set 15 | yantal
# Processing Record 28 of Set 15 | dibulla
# Processing Record 29 of Set 15 | otjimbingwe
# Processing Record 30 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 31 of Set 15 | kashi
# Processing Record 32 of Set 15 | nishihara
# Processing Record 33 of Set 15 | sioux lookout
# Processing Record 34 of Set 15 | almaty
# Processing Record 35 of Set 15 | gazli
# Processing Record 36 of Set 15 | valdivia
# Processing Record 37 of Set 15 | isangel
# Processing Record 38 of Set 15 | moranbah
# Processing Record 39 of Set 15 | nizhniy odes
# Processing Record 40 of Set 15 | hami
# Processing Record 41 of Set 15 | verkh-usugli
# Processing Record 42 of Set 15 | praya
# Processing Record 43 of Set 15 | san policarpo
# Processing Record 44 of Set 15 | araouane
# Processing Record 45 of Set 15 | port macquarie
# Processing Record 46 of Set 15 | pitea
# Processing Record 47 of Set 15 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 48 of Set 15 | port hedland
# Processing Record 49 of Set 15 | amarillo
# Processing Record 50 of Set 15 | kabanjahe
# Processing Record 1 of Set 16 | necochea
# Processing Record 2 of Set 16 | bell ville
# Processing Record 3 of Set 16 | niquelandia
# Processing Record 4 of Set 16 | pangai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
city_data
# Out:
# [{'City': 'Dubbo',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 66.33,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.76,
#   'Humidity': 78,
#   'Cloudiness': 54,
#   'Wind Speed': 19.17,
#   'Country': 'PF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 81.77,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.06,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 63.7,
#   'Humidity': 85,
#   'Cloudiness': 87,
#   'Wind Speed': 9.6,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 54.75,
#   'Humidity': 38,
#   'Cloudiness': 6,
#   'Wind Speed': 3.6,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 52.72,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 30.2,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 42.17,
#   'Humidity': 65,
#   'Cloudiness': 41,
#   'Wind Speed': 7.25,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 69.55,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 70.43,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 26.6,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 82.13,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.11,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Tevaitoa',
#   'Lat': -16.7833,
#   'Lng': -151.5,
#   'Max Temp': 79.23,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 8.1,
#   'Country': 'PF',
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.78,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 16.17,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 69.91,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.25,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pacifica',
#   'Lat': 37.6138,
#   'Lng': -122.4869,
#   'Max Temp': 67.71,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 17.62,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Kempele',
#   'Lat': 64.9131,
#   'Lng': 25.5034,
#   'Max Temp': 44.62,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'FI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aloleng',
#   'Lat': 16.1307,
#   'Lng': 119.7824,
#   'Max Temp': 84.67,
#   'Humidity': 68,
#   'Cloudiness': 5,
#   'Wind Speed': 3.29,
#   'Country': 'PH',
#   'Current Description': 'clear sky'},
#  {'City': 'Tadine',
#   'Lat': -21.55,
#   'Lng': 167.8833,
#   'Max Temp': 72.9,
#   'Humidity': 55,
#   'Cloudiness': 23,
#   'Wind Speed': 10.98,
#   'Country': 'NC',
#   'Current Description': 'few clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 40.53,
#   'Humidity': 68,
#   'Cloudiness': 4,
#   'Wind Speed': 6.42,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Fairview',
#   'Lat': 40.8126,
#   'Lng': -73.999,
#   'Max Temp': 67.23,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 63.05,
#   'Humidity': 24,
#   'Cloudiness': 6,
#   'Wind Speed': 1.32,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 33.31,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Galeana',
#   'Lat': 24.8333,
#   'Lng': -100.0667,
#   'Max Temp': 62.31,
#   'Humidity': 94,
#   'Cloudiness': 71,
#   'Wind Speed': 2.93,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 47.97,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 77.85,
#   'Humidity': 57,
#   'Cloudiness': 10,
#   'Wind Speed': 7.65,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 53.19,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 60.42,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Mae Sai',
#   'Lat': 20.4335,
#   'Lng': 99.8762,
#   'Max Temp': 74.52,
#   'Humidity': 96,
#   'Cloudiness': 91,
#   'Wind Speed': 1.79,
#   'Country': 'TH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 19.33,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.41,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 33.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 61.81,
#   'Humidity': 52,
#   'Cloudiness': 31,
#   'Wind Speed': 1.95,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 62.46,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 4.97,
#   'Country': 'BW',
#   'Current Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 57.09,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Griffith',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 66.06,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kamen-Na-Obi',
#   'Lat': 53.7884,
#   'Lng': 81.3423,
#   'Max Temp': 34.5,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 12.95,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.85,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 9.57,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 47.48,
#   'Humidity': 82,
#   'Cloudiness': 56,
#   'Wind Speed': 6.91,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 58.64,
#   'Humidity': 91,
#   'Cloudiness': 13,
#   'Wind Speed': 5.28,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Yaan',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp': 69.66,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 67.55,
#   'Humidity': 86,
#   'Cloudiness': 57,
#   'Wind Speed': 14.12,
#   'Country': 'RE',
#   'Current Description': 'light rain'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 68.14,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 10.78,
#   'Country': 'NC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 33.13,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.29,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 35.58,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Neosho',
#   'Lat': 36.869,
#   'Lng': -94.368,
#   'Max Temp': 64.54,
#   'Humidity': 77,
#   'Cloudiness': 11,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 54.75,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 5.3,
#   'Country': 'RO',
#   'Current Description': 'clear sky'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 60.58,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 45.27,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 79.41,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 37.51,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 57.52,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Zhangjiakou',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 62.11,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 33.82,
#   'Humidity': 63,
#   'Cloudiness': 99,
#   'Wind Speed': 1.97,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vigia',
#   'Lat': -0.8583,
#   'Lng': -48.1417,
#   'Max Temp': 77.05,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 91.17,
#   'Humidity': 12,
#   'Cloudiness': 6,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Tumaco',
#   'Lat': 1.7986,
#   'Lng': -78.8156,
#   'Max Temp': 77.25,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kuzhener',
#   'Lat': 56.8111,
#   'Lng': 48.9128,
#   'Max Temp': 40.32,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 48.36,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 78.01,
#   'Humidity': 65,
#   'Cloudiness': 77,
#   'Wind Speed': 2.89,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rupert',
#   'Lat': 42.6191,
#   'Lng': -113.6772,
#   'Max Temp': 69.24,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.18,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 37.44,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 4.99,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 70.72,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.45,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 84.24,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 12.1,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Xining',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 57.74,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 63.21,
#   'Humidity': 67,
#   'Cloudiness': 9,
#   'Wind Speed': 6.71,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 58.89,
#   'Humidity': 88,
#   'Cloudiness': 79,
#   'Wind Speed': 6.64,
#   'Country': 'ZA',
#   'Current Description': 'light rain'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 64.96,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 39.11,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 21.83,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.86,
#   'Humidity': 76,
#   'Cloudiness': 34,
#   'Wind Speed': 11.83,
#   'Country': 'PG',
#   'Current Description': 'light rain'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 47.8,
#   'Humidity': 56,
#   'Cloudiness': 73,
#   'Wind Speed': 15.48,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Itanhem',
#   'Lat': -17.1664,
#   'Lng': -40.33,
#   'Max Temp': 65.1,
#   'Humidity': 83,
#   'Cloudiness': 96,
#   'Wind Speed': 6.17,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 39.04,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'SJ',
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 59.41,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 73.47,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pedernales',
#   'Lat': 18.0384,
#   'Lng': -71.744,
#   'Max Temp': 82.11,
#   'Humidity': 77,
#   'Cloudiness': 82,
#   'Wind Speed': 4.34,
#   'Country': 'DO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 70.79,
#   'Humidity': 72,
#   'Cloudiness': 31,
#   'Wind Speed': 7.43,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Seguela',
#   'Lat': 7.9611,
#   'Lng': -6.6731,
#   'Max Temp': 71.31,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'CI',
#   'Current Description': 'light rain'},
#  {'City': 'Dzhida',
#   'Lat': 50.6772,
#   'Lng': 106.1806,
#   'Max Temp': 39.07,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 61.12,
#   'Humidity': 49,
#   'Cloudiness': 9,
#   'Wind Speed': 13.8,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 60.12,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 5.75,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ornskoldsvik',
#   'Lat': 63.2909,
#   'Lng': 18.7153,
#   'Max Temp': 40.15,
#   'Humidity': 87,
#   'Cloudiness': 35,
#   'Wind Speed': 6.91,
#   'Country': 'SE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bray',
#   'Lat': 53.2028,
#   'Lng': -6.0983,
#   'Max Temp': 62.08,
#   'Humidity': 88,
#   'Cloudiness': 91,
#   'Wind Speed': 10.51,
#   'Country': 'IE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kande',
#   'Lat': 9.9578,
#   'Lng': 1.0447,
#   'Max Temp': 73.76,
#   'Humidity': 90,
#   'Cloudiness': 96,
#   'Wind Speed': 2.86,
#   'Country': 'TG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cosme Y Damian',
#   'Lat': -27.3167,
#   'Lng': -56.35,
#   'Max Temp': 66.38,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.04,
#   'Country': 'PY',
#   'Current Description': 'clear sky'},
#  {'City': 'West Point',
#   'Lat': 33.6076,
#   'Lng': -88.6503,
#   'Max Temp': 64,
#   'Humidity': 97,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 83.08,
#   'Humidity': 83,
#   'Cloudiness': 56,
#   'Wind Speed': 1.99,
#   'Country': 'GF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 60.85,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Dalbandin',
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp': 76.32,
#   'Humidity': 9,
#   'Cloudiness': 6,
#   'Wind Speed': 2.98,
#   'Country': 'PK',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.42,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 8.1,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 66.18,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 6.29,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 84.04,
#   'Humidity': 10,
#   'Cloudiness': 2,
#   'Wind Speed': 17.27,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Roberval',
#   'Lat': 48.5168,
#   'Lng': -72.2324,
#   'Max Temp': 56.03,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cravo Norte',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 76.37,
#   'Humidity': 86,
#   'Cloudiness': 16,
#   'Wind Speed': 4.97,
#   'Country': 'CO',
#   'Current Description': 'few clouds'},
#  {'City': 'Xinyang',
#   'Lat': 32.1228,
#   'Lng': 114.0656,
#   'Max Temp': 69.21,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.43,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 59.05,
#   'Humidity': 95,
#   'Cloudiness': 7,
#   'Wind Speed': 5.7,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 26.85,
#   'Humidity': 90,
#   'Cloudiness': 12,
#   'Wind Speed': 6.02,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 60.04,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.65,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 57.04,
#   'Humidity': 97,
#   'Cloudiness': 58,
#   'Wind Speed': 3.71,
#   'Country': 'UY',
#   'Current Description': 'broken clouds'},
#  {'City': 'Elverum',
#   'Lat': 60.8819,
#   'Lng': 11.5623,
#   'Max Temp': 41.92,
#   'Humidity': 86,
#   'Cloudiness': 36,
#   'Wind Speed': 2.53,
#   'Country': 'NO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 71.98,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'MU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 61.18,
#   'Humidity': 71,
#   'Cloudiness': 16,
#   'Wind Speed': 11.9,
#   'Country': 'ZA',
#   'Current Description': 'few clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 71.44,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 37.56,
#   'Humidity': 61,
#   'Cloudiness': 99,
#   'Wind Speed': 7.58,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 72.5,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 33.53,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 10,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mairi',
#   'Lat': -11.7114,
#   'Lng': -40.1489,
#   'Max Temp': 65.46,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 43.29,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 62.04,
#   'Humidity': 77,
#   'Cloudiness': 63,
#   'Wind Speed': 3.42,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 65.66,
#   'Humidity': 26,
#   'Cloudiness': 81,
#   'Wind Speed': 11.5,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 85.68,
#   'Humidity': 69,
#   'Cloudiness': 35,
#   'Wind Speed': 6.67,
#   'Country': 'SB',
#   'Current Description': 'light rain'},
#  {'City': 'Hargeysa',
#   'Lat': 9.56,
#   'Lng': 44.065,
#   'Max Temp': 70.56,
#   'Humidity': 58,
#   'Cloudiness': 52,
#   'Wind Speed': 16.42,
#   'Country': 'SO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 67.64,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'RE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Oistins',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 78.89,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bayan',
#   'Lat': 46.0833,
#   'Lng': 127.4,
#   'Max Temp': 61.84,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 6.87,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pochutla',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 78.82,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 3.47,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Skjervoy',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 46.94,
#   'Humidity': 77,
#   'Cloudiness': 24,
#   'Wind Speed': 10.36,
#   'Country': 'NO',
#   'Current Description': 'few clouds'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 75.22,
#   'Humidity': 36,
#   'Cloudiness': 79,
#   'Wind Speed': 2.57,
#   'Country': 'YE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 31.78,
#   'Humidity': 82,
#   'Cloudiness': 94,
#   'Wind Speed': 12.06,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 85.66,
#   'Humidity': 71,
#   'Cloudiness': 45,
#   'Wind Speed': 4.76,
#   'Country': 'PH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mahon',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 75.76,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.19,
#   'Humidity': 80,
#   'Cloudiness': 88,
#   'Wind Speed': 17.98,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': 41.79,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 4.54,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Soure',
#   'Lat': -0.7167,
#   'Lng': -48.5233,
#   'Max Temp': 80.06,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 11.52,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 77.18,
#   'Humidity': 98,
#   'Cloudiness': 70,
#   'Wind Speed': 3.74,
#   'Country': 'VE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lethem',
#   'Lat': 3.3803,
#   'Lng': -59.7968,
#   'Max Temp': 80.62,
#   'Humidity': 65,
#   'Cloudiness': 85,
#   'Wind Speed': 4.5,
#   'Country': 'GY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 37.96,
#   'Humidity': 70,
#   'Cloudiness': 96,
#   'Wind Speed': 16.24,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ferrol',
#   'Lat': 43.4832,
#   'Lng': -8.2369,
#   'Max Temp': 66.36,
#   'Humidity': 80,
#   'Cloudiness': 56,
#   'Wind Speed': 9.42,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 40.62,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 15.48,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 85.6,
#   'Humidity': 72,
#   'Cloudiness': 31,
#   'Wind Speed': 5.99,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 40.86,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Current Description': 'light rain'},
#  {'City': 'Tahta',
#   'Lat': 26.7693,
#   'Lng': 31.5021,
#   'Max Temp': 70.12,
#   'Humidity': 48,
#   'Cloudiness': 5,
#   'Wind Speed': 8.3,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 69.82,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MG',
#   'Current Description': 'few clouds'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 81.36,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 14.41,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 34.14,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 3.02,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 86.63,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Darbhanga',
#   'Lat': 26.1667,
#   'Lng': 85.9,
#   'Max Temp': 84.24,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 6.53,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qrendi',
#   'Lat': 35.8347,
#   'Lng': 14.4583,
#   'Max Temp': 75.11,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'MT',
#   'Current Description': 'few clouds'},
#  {'City': 'Yuncheng',
#   'Lat': 35.0231,
#   'Lng': 110.9928,
#   'Max Temp': 63.43,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 69.01,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 9.57,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 72,
#   'Humidity': 77,
#   'Cloudiness': 12,
#   'Wind Speed': 8.01,
#   'Country': 'MU',
#   'Current Description': 'few clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.94,
#   'Humidity': 75,
#   'Cloudiness': 12,
#   'Wind Speed': 10.74,
#   'Country': 'KI',
#   'Current Description': 'light rain'},
#  {'City': 'Le Port',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 67.96,
#   'Humidity': 76,
#   'Cloudiness': 10,
#   'Wind Speed': 8.05,
#   'Country': 'RE',
#   'Current Description': 'clear sky'},
#  {'City': 'Kitzingen',
#   'Lat': 49.7333,
#   'Lng': 10.1667,
#   'Max Temp': 63.95,
#   'Humidity': 90,
#   'Cloudiness': 64,
#   'Wind Speed': 3.13,
#   'Country': 'DE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Dezhou',
#   'Lat': 37.4486,
#   'Lng': 116.2925,
#   'Max Temp': 65.59,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.15,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 64.8,
#   'Humidity': 52,
#   'Cloudiness': 73,
#   'Wind Speed': 12.59,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 78.84,
#   'Humidity': 77,
#   'Cloudiness': 11,
#   'Wind Speed': 18.39,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 71.89,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'MU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 75.94,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'GH',
#   'Current Description': 'light rain'},
#  {'City': 'Moquegua',
#   'Lat': -17.1956,
#   'Lng': -70.9353,
#   'Max Temp': 66.45,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.1,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'Corlu',
#   'Lat': 41.1592,
#   'Lng': 27.8,
#   'Max Temp': 55.38,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'TR',
#   'Current Description': 'clear sky'},
#  {'City': 'Pareora',
#   'Lat': -44.4871,
#   'Lng': 171.2132,
#   'Max Temp': 47.17,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 87.71,
#   'Humidity': 50,
#   'Cloudiness': 7,
#   'Wind Speed': 8.99,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 35.44,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 19.22,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bara',
#   'Lat': 10.3744,
#   'Lng': 10.7288,
#   'Max Temp': 71.35,
#   'Humidity': 91,
#   'Cloudiness': 43,
#   'Wind Speed': 6.46,
#   'Country': 'NG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Luganville',
#   'Lat': -15.5333,
#   'Lng': 167.1667,
#   'Max Temp': 78.46,
#   'Humidity': 84,
#   'Cloudiness': 63,
#   'Wind Speed': 11.56,
#   'Country': 'VU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mpika',
#   'Lat': -11.8343,
#   'Lng': 31.4529,
#   'Max Temp': 58.71,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 5.84,
#   'Country': 'ZM',
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 70.27,
#   'Humidity': 45,
#   'Cloudiness': 25,
#   'Wind Speed': 13.62,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 83.08,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 9.46,
#   'Country': 'TC',
#   'Current Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 45.73,
#   'Humidity': 71,
#   'Cloudiness': 97,
#   'Wind Speed': 10.85,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Banepa',
#   'Lat': 27.6298,
#   'Lng': 85.5214,
#   'Max Temp': 71.92,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'NP',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 71.04,
#   'Humidity': 91,
#   'Cloudiness': 86,
#   'Wind Speed': 0.6,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Terney',
#   'Lat': 45.0503,
#   'Lng': 136.6092,
#   'Max Temp': 66.25,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Otjiwarongo',
#   'Lat': -20.4637,
#   'Lng': 16.6477,
#   'Max Temp': 63.55,
#   'Humidity': 17,
#   'Cloudiness': 5,
#   'Wind Speed': 4.34,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Porto Novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 73.22,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Country': 'BJ',
#   'Current Description': 'light rain'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 61.09,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 57.16,
#   'Humidity': 46,
#   'Cloudiness': 10,
#   'Wind Speed': 4.27,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 81.73,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 0.43,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 60.03,
#   'Humidity': 94,
#   'Cloudiness': 47,
#   'Wind Speed': 2.48,
#   'Country': 'IT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 74.39,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnokamensk',
#   'Lat': 50.0979,
#   'Lng': 118.0369,
#   'Max Temp': 56.34,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 84.42,
#   'Humidity': 74,
#   'Cloudiness': 54,
#   'Wind Speed': 9.98,
#   'Country': 'SB',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 80.94,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'LK',
#   'Current Description': 'scattered clouds'},
#  {'City': 'North Bend',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 59.92,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Newport',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp': 60.08,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 47.82,
#   'Humidity': 70,
#   'Cloudiness': 77,
#   'Wind Speed': 11.25,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 26.62,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Edgecumbe',
#   'Lat': -37.9833,
#   'Lng': 176.8333,
#   'Max Temp': 64.08,
#   'Humidity': 85,
#   'Cloudiness': 83,
#   'Wind Speed': 4.85,
#   'Country': 'NZ',
#   'Current Description': 'light rain'},
#  {'City': 'Sri Aman',
#   'Lat': 1.2376,
#   'Lng': 111.4621,
#   'Max Temp': 84.25,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 85.95,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 34.56,
#   'Humidity': 56,
#   'Cloudiness': 93,
#   'Wind Speed': 4.29,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 67.75,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yunhe',
#   'Lat': 34.0833,
#   'Lng': 119.7167,
#   'Max Temp': 78.31,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'Usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 37.08,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 7.7,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tecoanapa',
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp': 81.18,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Koumac',
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 74.71,
#   'Humidity': 64,
#   'Cloudiness': 24,
#   'Wind Speed': 10.16,
#   'Country': 'NC',
#   'Current Description': 'few clouds'},
#  {'City': 'Creel',
#   'Lat': 27.75,
#   'Lng': -107.6333,
#   'Max Temp': 54.21,
#   'Humidity': 89,
#   'Cloudiness': 33,
#   'Wind Speed': 4.59,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nueve De Julio',
#   'Lat': -35.4444,
#   'Lng': -60.8831,
#   'Max Temp': 57.7,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 9.8,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 85.8,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 7.96,
#   'Country': 'NE',
#   'Current Description': 'clear sky'},
#  {'City': 'Lumberton',
#   'Lat': 34.6182,
#   'Lng': -79.0086,
#   'Max Temp': 65.21,
#   'Humidity': 51,
#   'Cloudiness': 24,
#   'Wind Speed': 2.86,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 33.22,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 3.02,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dir',
#   'Lat': 35.2058,
#   'Lng': 71.8756,
#   'Max Temp': 67.42,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'PK',
#   'Current Description': 'clear sky'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 85.3,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 8.16,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Janauba',
#   'Lat': -15.8025,
#   'Lng': -43.3089,
#   'Max Temp': 74.71,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 8.12,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Rabo De Peixe',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 71.28,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 60.91,
#   'Humidity': 29,
#   'Cloudiness': 76,
#   'Wind Speed': 31.59,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 71.96,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 21.68,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 44.33,
#   'Humidity': 71,
#   'Cloudiness': 83,
#   'Wind Speed': 4.27,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Olyka',
#   'Lat': 50.7186,
#   'Lng': 25.8125,
#   'Max Temp': 58.93,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.74,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 62.91,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 70.7,
#   'Humidity': 22,
#   'Cloudiness': 3,
#   'Wind Speed': 10.69,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'TO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Teahupoo',
#   'Lat': -17.8333,
#   'Lng': -149.2667,
#   'Max Temp': 67.96,
#   'Humidity': 76,
#   'Cloudiness': 15,
#   'Wind Speed': 11.16,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 65.23,
#   'Humidity': 90,
#   'Cloudiness': 42,
#   'Wind Speed': 7.05,
#   'Country': 'ES',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 49.41,
#   'Humidity': 83,
#   'Cloudiness': 76,
#   'Wind Speed': 12.01,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 30.33,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.59,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 48.09,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.61,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ryotsu',
#   'Lat': 38.0833,
#   'Lng': 138.4333,
#   'Max Temp': 73.36,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'JP',
#   'Current Description': 'moderate rain'},
#  {'City': 'Sechura',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 64.9,
#   'Humidity': 82,
#   'Cloudiness': 84,
#   'Wind Speed': 13.04,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Jalu',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 69.58,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 6.06,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'Siteki',
#   'Lat': -26.45,
#   'Lng': 31.95,
#   'Max Temp': 57.74,
#   'Humidity': 81,
#   'Cloudiness': 4,
#   'Wind Speed': 4.54,
#   'Country': 'SZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 20.3,
#   'Humidity': 69,
#   'Cloudiness': 98,
#   'Wind Speed': 6.49,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Piracaia',
#   'Lat': -23.0539,
#   'Lng': -46.3581,
#   'Max Temp': 64.54,
#   'Humidity': 96,
#   'Cloudiness': 18,
#   'Wind Speed': 3.6,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 76.82,
#   'Humidity': 67,
#   'Cloudiness': 56,
#   'Wind Speed': 1.83,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 79.16,
#   'Humidity': 32,
#   'Cloudiness': 71,
#   'Wind Speed': 2.75,
#   'Country': 'TL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Keti Bandar',
#   'Lat': 24.1447,
#   'Lng': 67.4497,
#   'Max Temp': 81.7,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'PK',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 78.69,
#   'Humidity': 53,
#   'Cloudiness': 13,
#   'Wind Speed': 5.75,
#   'Country': 'NU',
#   'Current Description': 'few clouds'},
#  {'City': 'Tanete',
#   'Lat': -3.9443,
#   'Lng': 119.7848,
#   'Max Temp': 86.47,
#   'Humidity': 64,
#   'Cloudiness': 44,
#   'Wind Speed': 9.31,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.54,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 16.42,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neuquen',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 58.89,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Maxixe',
#   'Lat': -23.8597,
#   'Lng': 35.3472,
#   'Max Temp': 66.61,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Country': 'MZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Tanah Merah',
#   'Lat': 5.8,
#   'Lng': 102.15,
#   'Max Temp': 84.02,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 1.21,
#   'Country': 'MY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tommot',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': 45.57,
#   'Humidity': 58,
#   'Cloudiness': 98,
#   'Wind Speed': 9.55,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gawler',
#   'Lat': -34.6,
#   'Lng': 138.7333,
#   'Max Temp': 65.25,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 11.48,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Miles City',
#   'Lat': 46.4083,
#   'Lng': -105.8406,
#   'Max Temp': 81.57,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Razdolnoye',
#   'Lat': 43.55,
#   'Lng': 131.9167,
#   'Max Temp': 64.81,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Niquero',
#   'Lat': 20.0431,
#   'Lng': -77.5828,
#   'Max Temp': 80.96,
#   'Humidity': 79,
#   'Cloudiness': 6,
#   'Wind Speed': 3.06,
#   'Country': 'CU',
#   'Current Description': 'clear sky'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 57.72,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Bridgewater',
#   'Lat': 44.3835,
#   'Lng': -64.5155,
#   'Max Temp': 67.26,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 76.55,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'CR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Takapau',
#   'Lat': -40.0333,
#   'Lng': 176.35,
#   'Max Temp': 57.18,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Den Helder',
#   'Lat': 52.9599,
#   'Lng': 4.7593,
#   'Max Temp': 62.58,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'NL',
#   'Current Description': 'mist'},
#  {'City': 'Byumba',
#   'Lat': -1.5763,
#   'Lng': 30.0675,
#   'Max Temp': 53.8,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'RW',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 51.69,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 47.66,
#   'Humidity': 85,
#   'Cloudiness': 22,
#   'Wind Speed': 9.06,
#   'Country': 'CL',
#   'Current Description': 'few clouds'},
#  {'City': 'Kukushtan',
#   'Lat': 57.6464,
#   'Lng': 56.4952,
#   'Max Temp': 47.82,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 11.59,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Iralaya',
#   'Lat': 15,
#   'Lng': -83.2333,
#   'Max Temp': 77.07,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'HN',
# ...
#  {'City': 'Atasu',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 46.8,
#   'Humidity': 22,
#   'Cloudiness': 98,
#   'Wind Speed': 6.71,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sandovo',
#   'Lat': 58.4602,
#   'Lng': 36.4128,
#   'Max Temp': 45.59,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bosaso',
#   'Lat': 11.2842,
#   'Lng': 49.1816,
#   'Max Temp': 89.96,
#   'Humidity': 44,
#   'Cloudiness': 78,
#   'Wind Speed': 9.8,
#   'Country': 'SO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 59.79,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ginda',
#   'Lat': 30.6945,
#   'Lng': 78.4932,
#   'Max Temp': 63,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 49.35,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 19.28,
#   'Country': 'NO',
#   'Current Description': 'light rain'},
#  {'City': 'Hukuntsi',
#   'Lat': -24,
#   'Lng': 21.75,
#   'Max Temp': 65.23,
#   'Humidity': 23,
#   'Cloudiness': 7,
#   'Wind Speed': 6.22,
#   'Country': 'BW',
#   'Current Description': 'clear sky'},
#  {'City': 'Ambon',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 82.54,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'ID',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Tabuk',
#   'Lat': 17.4189,
#   'Lng': 121.4443,
#   'Max Temp': 85.01,
#   'Humidity': 70,
#   'Cloudiness': 37,
#   'Wind Speed': 3.69,
#   'Country': 'PH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 89.62,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'JP',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 82.02,
#   'Humidity': 76,
#   'Cloudiness': 24,
#   'Wind Speed': 7.47,
#   'Country': 'GD',
#   'Current Description': 'few clouds'},
#  {'City': 'Wilmington',
#   'Lat': 34.2257,
#   'Lng': -77.9447,
#   'Max Temp': 68.86,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 91.38,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Xuddur',
#   'Lat': 4.1213,
#   'Lng': 43.8894,
#   'Max Temp': 70.54,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 13.96,
#   'Country': 'SO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Moresby',
#   'Lat': -9.4431,
#   'Lng': 147.1797,
#   'Max Temp': 87.22,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gilgit',
#   'Lat': 35.9221,
#   'Lng': 74.3087,
#   'Max Temp': 74.79,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 1.48,
#   'Country': 'PK',
#   'Current Description': 'clear sky'},
#  {'City': 'Fayetteville',
#   'Lat': 35.0527,
#   'Lng': -78.8784,
#   'Max Temp': 65.88,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 42.94,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 16.15,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mantua',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp': 70.75,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 3,
#   'Country': 'IT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 72.39,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.05,
#   'Country': 'IL',
#   'Current Description': 'clear sky'},
#  {'City': 'Xinqing',
#   'Lat': 48.2333,
#   'Lng': 129.5,
#   'Max Temp': 65.23,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Ramanuj Ganj',
#   'Lat': 23.8,
#   'Lng': 83.7,
#   'Max Temp': 78.12,
#   'Humidity': 83,
#   'Cloudiness': 23,
#   'Wind Speed': 1.54,
#   'Country': 'IN',
#   'Current Description': 'few clouds'},
#  {'City': 'Katangli',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': 62.64,
#   'Humidity': 60,
#   'Cloudiness': 22,
#   'Wind Speed': 15.14,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Brasilia De Minas',
#   'Lat': -16.2064,
#   'Lng': -44.4333,
#   'Max Temp': 74.57,
#   'Humidity': 44,
#   'Cloudiness': 3,
#   'Wind Speed': 9.53,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 50.77,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind Speed': 15.59,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dukat',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': 34.3,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.34,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dicabisagan',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Max Temp': 85.44,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 45.09,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Gornopravdinsk',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 30,
#   'Humidity': 87,
#   'Cloudiness': 11,
#   'Wind Speed': 4.38,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 81.19,
#   'Humidity': 80,
#   'Cloudiness': 89,
#   'Wind Speed': 15.39,
#   'Country': 'ID',
#   'Current Description': 'light rain'},
#  {'City': 'Ovalle',
#   'Lat': -30.5983,
#   'Lng': -71.2003,
#   'Max Temp': 59.18,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.66,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 80.37,
#   'Humidity': 86,
#   'Cloudiness': 39,
#   'Wind Speed': 11.61,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jaru',
#   'Lat': -10.4389,
#   'Lng': -62.4664,
#   'Max Temp': 81.57,
#   'Humidity': 58,
#   'Cloudiness': 15,
#   'Wind Speed': 3.6,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Russell',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 65.8,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Novoselytsya',
#   'Lat': 48.2193,
#   'Lng': 26.2653,
#   'Max Temp': 63.97,
#   'Humidity': 70,
#   'Cloudiness': 45,
#   'Wind Speed': 4.85,
#   'Country': 'UA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Petrokhorion',
#   'Lat': 41.1167,
#   'Lng': 24.8333,
#   'Max Temp': 65.93,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Country': 'GR',
#   'Current Description': 'clear sky'},
#  {'City': 'Ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 79.9,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 24.25,
#   'Country': 'MV',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Somerset',
#   'Lat': 40.5668,
#   'Lng': -74.5496,
#   'Max Temp': 67.15,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Gubkinskiy',
#   'Lat': 64.434,
#   'Lng': 76.5026,
#   'Max Temp': 32.38,
#   'Humidity': 82,
#   'Cloudiness': 15,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Bolondron',
#   'Lat': 22.7633,
#   'Lng': -81.4469,
#   'Max Temp': 77.2,
#   'Humidity': 89,
#   'Cloudiness': 26,
#   'Wind Speed': 4.85,
#   'Country': 'CU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Same',
#   'Lat': -4.0667,
#   'Lng': 37.7333,
#   'Max Temp': 62.6,
#   'Humidity': 91,
#   'Cloudiness': 11,
#   'Wind Speed': 1.32,
#   'Country': 'TZ',
#   'Current Description': 'few clouds'},
#  {'City': 'Kendari',
#   'Lat': -3.945,
#   'Lng': 122.4989,
#   'Max Temp': 86.27,
#   'Humidity': 59,
#   'Cloudiness': 32,
#   'Wind Speed': 1.43,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dolores',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 52.39,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 7.36,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Minab',
#   'Lat': 27.1467,
#   'Lng': 57.0801,
#   'Max Temp': 85.5,
#   'Humidity': 71,
#   'Cloudiness': 3,
#   'Wind Speed': 3.18,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Watertown',
#   'Lat': 42.3709,
#   'Lng': -71.1828,
#   'Max Temp': 67.69,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Altamira',
#   'Lat': -3.2033,
#   'Lng': -52.2064,
#   'Max Temp': 76.57,
#   'Humidity': 70,
#   'Cloudiness': 11,
#   'Wind Speed': 1.48,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 69.08,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 10.22,
#   'Country': 'EC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qazvin',
#   'Lat': 36.2797,
#   'Lng': 50.0049,
#   'Max Temp': 55.02,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Mehran',
#   'Lat': 33.1222,
#   'Lng': 46.1646,
#   'Max Temp': 75.72,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 10.54,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Zlitan',
#   'Lat': 32.4674,
#   'Lng': 14.5687,
#   'Max Temp': 72.45,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 9.48,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'Riohacha',
#   'Lat': 11.5444,
#   'Lng': -72.9072,
#   'Max Temp': 81.03,
#   'Humidity': 82,
#   'Cloudiness': 28,
#   'Wind Speed': 10.49,
#   'Country': 'CO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 80.15,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Victoria Point',
#   'Lat': -27.5833,
#   'Lng': 153.3,
#   'Max Temp': 80.44,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mantiquil',
#   'Lat': 9.1667,
#   'Lng': 123.05,
#   'Max Temp': 81.45,
#   'Humidity': 72,
#   'Cloudiness': 91,
#   'Wind Speed': 1.86,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yantal',
#   'Lat': 56.8471,
#   'Lng': 105.2542,
#   'Max Temp': 35.02,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Dibulla',
#   'Lat': 11.2725,
#   'Lng': -73.3091,
#   'Max Temp': 79.43,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.46,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Otjimbingwe',
#   'Lat': -22.35,
#   'Lng': 16.1333,
#   'Max Temp': 72.5,
#   'Humidity': 23,
#   'Cloudiness': 10,
#   'Wind Speed': 3.42,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kashi',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 65.41,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 88.88,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'JP',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 53.67,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Almaty',
#   'Lat': 43.25,
#   'Lng': 76.95,
#   'Max Temp': 46.31,
#   'Humidity': 46,
#   'Cloudiness': 3,
#   'Wind Speed': 2.24,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Gazli',
#   'Lat': 40.1333,
#   'Lng': 63.45,
#   'Max Temp': 74.5,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 5.3,
#   'Country': 'UZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Valdivia',
#   'Lat': -39.8142,
#   'Lng': -73.2459,
#   'Max Temp': 41.09,
#   'Humidity': 98,
#   'Cloudiness': 1,
#   'Wind Speed': 1.28,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 75.67,
#   'Humidity': 57,
#   'Cloudiness': 5,
#   'Wind Speed': 10,
#   'Country': 'VU',
#   'Current Description': 'clear sky'},
#  {'City': 'Moranbah',
#   'Lat': -22.0016,
#   'Lng': 148.0466,
#   'Max Temp': 83.77,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 10.18,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Nizhniy Odes',
#   'Lat': 63.6445,
#   'Lng': 54.856,
#   'Max Temp': 39.56,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 59.52,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 9.35,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Verkh-Usugli',
#   'Lat': 52.7,
#   'Lng': 115.1667,
#   'Max Temp': 51.8,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 5.82,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Praya',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 77.54,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'CV',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 84.49,
#   'Humidity': 71,
#   'Cloudiness': 98,
#   'Wind Speed': 1.7,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 93.79,
#   'Humidity': 16,
#   'Cloudiness': 24,
#   'Wind Speed': 4.99,
#   'Country': 'ML',
#   'Current Description': 'few clouds'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 60.76,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 13.09,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pitea',
#   'Lat': 65.3172,
#   'Lng': 21.4794,
#   'Max Temp': 38.08,
#   'Humidity': 90,
#   'Cloudiness': 89,
#   'Wind Speed': 3.89,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 89.65,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Amarillo',
#   'Lat': 35.222,
#   'Lng': -101.8313,
#   'Max Temp': 75.04,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Kabanjahe',
#   'Lat': 3.1001,
#   'Lng': 98.4908,
#   'Max Temp': 65.16,
#   'Humidity': 79,
#   'Cloudiness': 80,
#   'Wind Speed': 2.28,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 56.03,
#   'Humidity': 92,
#   'Cloudiness': 87,
#   'Wind Speed': 13.24,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bell Ville',
#   'Lat': -32.6259,
#   'Lng': -62.6887,
#   'Max Temp': 61.66,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.62,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Niquelandia',
#   'Lat': -14.4739,
#   'Lng': -48.4597,
#   'Max Temp': 76.1,
#   'Humidity': 64,
#   'Cloudiness': 73,
#   'Wind Speed': 4.52,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 72.54,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 11.72,
#   'Country': 'TO',
#   'Current Description': 'overcast clouds'}]

# %%
#Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Dubbo -32.2500  148.6167     66.33        42          40
# 1                 Atuona  -9.8000 -139.0333     77.76        78          54
# 2             Port Blair  11.6667   92.7500     81.77        83         100
# 3                Ushuaia -54.8000  -68.3000     37.06        75          75
# 4                Huarmey -10.0681  -78.1522     63.70        85          87
# 5            New Norfolk -42.7826  147.0587     54.75        38           6
# 6               Klaksvik  62.2266   -6.5890     52.72        94         100
# 7                 Kodiak  57.7900 -152.4072     42.17        65          41
# 8  Los Llanos De Aridane  28.6585  -17.9182     69.55        85          20
# 9        Arraial Do Cabo -22.9661  -42.0278     70.43        80         100
#
#    Wind Speed Country Current Description
# 0       18.41      AU    scattered clouds
# 1       19.17      PF       broken clouds
# 2       12.53      IN     overcast clouds
# 3       16.11      AR       broken clouds
# 4        9.60      PE     overcast clouds
# 5        3.60      AU           clear sky
# 6       30.20      FO     overcast clouds
# 7        7.25      US    scattered clouds
# 8        6.91      ES          few clouds
# 9       26.60      BR     overcast clouds

# %%
new_column_order =  ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dubbo      AU -32.2500  148.6167     66.33        42          40
# 1         Atuona      PF  -9.8000 -139.0333     77.76        78          54
# 2     Port Blair      IN  11.6667   92.7500     81.77        83         100
# 3        Ushuaia      AR -54.8000  -68.3000     37.06        75          75
# 4        Huarmey      PE -10.0681  -78.1522     63.70        85          87
# ..           ...     ...      ...       ...       ...       ...         ...
# 687    Kabanjahe      ID   3.1001   98.4908     65.16        79          80
# 688     Necochea      AR -38.5473  -58.7368     56.03        92          87
# 689   Bell Ville      AR -32.6259  -62.6887     61.66        55           0
# 690  Niquelandia      BR -14.4739  -48.4597     76.10        64          73
# 691       Pangai      TO -19.8000 -174.3500     72.54        60          98
#
#      Wind Speed Current Description
# 0         18.41    scattered clouds
# 1         19.17       broken clouds
# 2         12.53     overcast clouds
# 3         16.11       broken clouds
# 4          9.60     overcast clouds
# ..          ...                 ...
# 687        2.28       broken clouds
# 688       13.24     overcast clouds
# 689        9.62           clear sky
# 690        4.52       broken clouds
# 691       11.72     overcast clouds
#
# [692 rows x 9 columns]

# %%
# Export DF as a CSV file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
