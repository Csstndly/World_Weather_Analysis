# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import o_weather
import requests
import gmaps
from scipy.stats import linregress
from datetime import datetime
from config import g_maps_key
gmaps.configure(api_key=g_maps_key)
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.// to parse 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + o_weather

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
#Create a empty list for df
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters./ want the 1st iteration of the logging for each recorded response
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Looping through every city in the list 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = ["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description":city_descr, hotels["results"][0]["name"]
                            "Date": city_date })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 40 of Set 15 | jamestown
# City not found. Skipping...
# Processing Record 41 of Set 15 | atuona
# City not found. Skipping...
# Processing Record 42 of Set 15 | vila velha
# City not found. Skipping...
# Processing Record 43 of Set 15 | paita
# City not found. Skipping...
# Processing Record 44 of Set 15 | souillac
# City not found. Skipping...
# Processing Record 45 of Set 15 | aswan
# City not found. Skipping...
# Processing Record 46 of Set 15 | san jose de rio tinto
# City not found. Skipping...
# Processing Record 47 of Set 15 | saint-philippe
# City not found. Skipping...
# Processing Record 48 of Set 15 | puerto ayora
# City not found. Skipping...
# Processing Record 49 of Set 15 | nikolskoye
# City not found. Skipping...
# Processing Record 50 of Set 15 | georgetown
# City not found. Skipping...
# Processing Record 51 of Set 15 | sarangani
# City not found. Skipping...
# Processing Record 52 of Set 15 | cayenne
# City not found. Skipping...
# Processing Record 53 of Set 15 | bambous virieux
# City not found. Skipping...
# Processing Record 54 of Set 15 | ushuaia
# City not found. Skipping...
# Processing Record 55 of Set 15 | aripuana
# City not found. Skipping...
# Processing Record 56 of Set 15 | mar del plata
# City not found. Skipping...
# Processing Record 57 of Set 15 | tapayan
# City not found. Skipping...
# Processing Record 58 of Set 15 | japura
# City not found. Skipping...
# Processing Record 59 of Set 15 | busselton
# City not found. Skipping...
# Processing Record 60 of Set 15 | punta arenas
# City not found. Skipping...
# Processing Record 61 of Set 15 | butaritari
# City not found. Skipping...
# Processing Record 62 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 63 of Set 15 | zapolyarnyy
# City not found. Skipping...
# Processing Record 64 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 65 of Set 15 | porto santo
# City not found. Skipping...
# Processing Record 66 of Set 15 | dikson
# City not found. Skipping...
# Processing Record 67 of Set 15 | bredasdorp
# City not found. Skipping...
# Processing Record 68 of Set 15 | kapaa
# City not found. Skipping...
# Processing Record 69 of Set 15 | hermanus
# City not found. Skipping...
# Processing Record 70 of Set 15 | cabo san lucas
# City not found. Skipping...
# Processing Record 71 of Set 15 | grindavik
# City not found. Skipping...
# Processing Record 72 of Set 15 | barrow
# City not found. Skipping...
# Processing Record 73 of Set 15 | provideniya
# City not found. Skipping...
# Processing Record 74 of Set 15 | thompson
# City not found. Skipping...
# Processing Record 75 of Set 15 | severo-kurilsk
# City not found. Skipping...
# Processing Record 76 of Set 15 | rikitea
# City not found. Skipping...
# Processing Record 77 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 78 of Set 15 | san cristobal
# City not found. Skipping...
# Processing Record 79 of Set 15 | ust-nera
# City not found. Skipping...
# Processing Record 80 of Set 15 | lata
# City not found. Skipping...
# Processing Record 81 of Set 15 | zakamensk
# City not found. Skipping...
# Processing Record 82 of Set 15 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 83 of Set 15 | kango
# City not found. Skipping...
# Processing Record 84 of Set 15 | chokurdakh
# City not found. Skipping...
# Processing Record 85 of Set 15 | xai-xai
# City not found. Skipping...
# Processing Record 86 of Set 15 | cherskiy
# City not found. Skipping...
# Processing Record 87 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 88 of Set 15 | samarai
# City not found. Skipping...
# Processing Record 89 of Set 15 | flin flon
# City not found. Skipping...
# Processing Record 1 of Set 16 | muros
# City not found. Skipping...
# Processing Record 2 of Set 16 | lompoc
# City not found. Skipping...
# Processing Record 3 of Set 16 | vuktyl
# City not found. Skipping...
# Processing Record 4 of Set 16 | west bay
# City not found. Skipping...
# Processing Record 5 of Set 16 | saint-jean-de-maurienne
# City not found. Skipping...
# Processing Record 6 of Set 16 | albany
# City not found. Skipping...
# Processing Record 7 of Set 16 | havelock
# City not found. Skipping...
# Processing Record 8 of Set 16 | mataura
# City not found. Skipping...
# Processing Record 9 of Set 16 | vaini
# City not found. Skipping...
# Processing Record 10 of Set 16 | asau
# City not found. Skipping...
# Processing Record 11 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 16 | port macquarie
# City not found. Skipping...
# Processing Record 13 of Set 16 | awjilah
# City not found. Skipping...
# Processing Record 14 of Set 16 | east london
# City not found. Skipping...
# Processing Record 15 of Set 16 | obarsia-closani
# City not found. Skipping...
# Processing Record 16 of Set 16 | omboue
# City not found. Skipping...
# Processing Record 17 of Set 16 | saskylakh
# City not found. Skipping...
# Processing Record 18 of Set 16 | komarov
# City not found. Skipping...
# Processing Record 19 of Set 16 | ambon
# City not found. Skipping...
# Processing Record 20 of Set 16 | castro
# City not found. Skipping...
# Processing Record 21 of Set 16 | geraldton
# City not found. Skipping...
# Processing Record 22 of Set 16 | sao joao da barra
# City not found. Skipping...
# Processing Record 23 of Set 16 | kirkuk
# City not found. Skipping...
# Processing Record 24 of Set 16 | manokwari
# City not found. Skipping...
# Processing Record 25 of Set 16 | ixtapa
# City not found. Skipping...
# Processing Record 26 of Set 16 | lavrentiya
# City not found. Skipping...
# Processing Record 27 of Set 16 | katobu
# City not found. Skipping...
# Processing Record 28 of Set 16 | nome
# City not found. Skipping...
# Processing Record 29 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 16 | hervey bay
# City not found. Skipping...
# Processing Record 31 of Set 16 | cody
# City not found. Skipping...
# Processing Record 32 of Set 16 | labuhan
# City not found. Skipping...
# Processing Record 33 of Set 16 | hobart
# City not found. Skipping...
# Processing Record 34 of Set 16 | brae
# City not found. Skipping...
# Processing Record 35 of Set 16 | irricana
# City not found. Skipping...
# Processing Record 36 of Set 16 | new norfolk
# City not found. Skipping...
# Processing Record 37 of Set 16 | oxbow
# City not found. Skipping...
# Processing Record 38 of Set 16 | bulgan
# City not found. Skipping...
# Processing Record 39 of Set 16 | pundaguitan
# City not found. Skipping...
# Processing Record 40 of Set 16 | virden
# City not found. Skipping...
# Processing Record 41 of Set 16 | kaitangata
# City not found. Skipping...
# Processing Record 42 of Set 16 | taoudenni
# City not found. Skipping...
# Processing Record 43 of Set 16 | lagoa
# City not found. Skipping...
# Processing Record 44 of Set 16 | narsaq
# City not found. Skipping...
# Processing Record 45 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 16 | port alfred
# City not found. Skipping...
# Processing Record 47 of Set 16 | cape town
# City not found. Skipping...
# Processing Record 48 of Set 16 | hithadhoo
# City not found. Skipping...
# Processing Record 49 of Set 16 | udachnyy
# City not found. Skipping...
# Processing Record 50 of Set 16 | kalmunai
# City not found. Skipping...
# Processing Record 1 of Set 17 | la palma
# City not found. Skipping...
# Processing Record 2 of Set 17 | goya
# City not found. Skipping...
# Processing Record 3 of Set 17 | vao
# City not found. Skipping...
# Processing Record 4 of Set 17 | guntur
# City not found. Skipping...
# Processing Record 5 of Set 17 | fare
# City not found. Skipping...
# Processing Record 6 of Set 17 | hofn
# City not found. Skipping...
# Processing Record 7 of Set 17 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 8 of Set 17 | kodinsk
# City not found. Skipping...
# Processing Record 9 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 17 | salalah
# City not found. Skipping...
# Processing Record 11 of Set 17 | vestmanna
# City not found. Skipping...
# Processing Record 12 of Set 17 | esperance
# City not found. Skipping...
# Processing Record 13 of Set 17 | carnarvon
# City not found. Skipping...
# Processing Record 14 of Set 17 | faanui
# City not found. Skipping...
# Processing Record 15 of Set 17 | bluff
# City not found. Skipping...
# Processing Record 16 of Set 17 | kodiak
# City not found. Skipping...
# Processing Record 17 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 17 | cidreira
# City not found. Skipping...
# Processing Record 19 of Set 17 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 17 | saint george
# City not found. Skipping...
# Processing Record 21 of Set 17 | alofi
# City not found. Skipping...
# Processing Record 22 of Set 17 | suntar
# City not found. Skipping...
# Processing Record 23 of Set 17 | qaanaaq
# City not found. Skipping...
# Processing Record 24 of Set 17 | fort saint james
# City not found. Skipping...
# Processing Record 25 of Set 17 | xichang
# City not found. Skipping...
# Processing Record 26 of Set 17 | gao
# City not found. Skipping...
# Processing Record 27 of Set 17 | daru
# City not found. Skipping...
# Processing Record 28 of Set 17 | karratha
# City not found. Skipping...
# Processing Record 29 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 17 | tezu
# City not found. Skipping...
# Processing Record 31 of Set 17 | sharjah
# City not found. Skipping...
# Processing Record 32 of Set 17 | san policarpo
# City not found. Skipping...
# Processing Record 33 of Set 17 | mareeba
# City not found. Skipping...
# Processing Record 34 of Set 17 | yarmouth
# City not found. Skipping...
# Processing Record 35 of Set 17 | college
# City not found. Skipping...
# Processing Record 36 of Set 17 | krasnaya polyana
# City not found. Skipping...
# Processing Record 37 of Set 17 | clonmel
# City not found. Skipping...
# Processing Record 38 of Set 17 | vanavara
# City not found. Skipping...
# Processing Record 39 of Set 17 | fortuna
# City not found. Skipping...
# Processing Record 40 of Set 17 | bafra
# City not found. Skipping...
# Processing Record 41 of Set 17 | husavik
# City not found. Skipping...
# Processing Record 42 of Set 17 | provost
# City not found. Skipping...
# Processing Record 43 of Set 17 | hovd
# City not found. Skipping...
# Processing Record 44 of Set 17 | khuzdar
# City not found. Skipping...
# Processing Record 45 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 17 | hilo
# City not found. Skipping...
# Processing Record 47 of Set 17 | livingston
# City not found. Skipping...
# Processing Record 48 of Set 17 | savelugu
# City not found. Skipping...
# Processing Record 49 of Set 17 | guatire
# City not found. Skipping...
# Processing Record 50 of Set 17 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 18 | tiksi
# City not found. Skipping...
# Processing Record 2 of Set 18 | tomatlan
# City not found. Skipping...
# Processing Record 3 of Set 18 | tres arroyos
# City not found. Skipping...
# Processing Record 4 of Set 18 | divnomorskoye
# City not found. Skipping...
# Processing Record 5 of Set 18 | lebu
# City not found. Skipping...
# Processing Record 6 of Set 18 | avera
# City not found. Skipping...
# Processing Record 7 of Set 18 | neuquen
# City not found. Skipping...
# Processing Record 8 of Set 18 | ulaanbaatar
# City not found. Skipping...
# Processing Record 9 of Set 18 | sur
# City not found. Skipping...
# Processing Record 10 of Set 18 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 18 | port keats
# City not found. Skipping...
# Processing Record 12 of Set 18 | san lorenzo
# City not found. Skipping...
# Processing Record 13 of Set 18 | barcelos
# City not found. Skipping...
# Processing Record 14 of Set 18 | talnakh
# City not found. Skipping...
# Processing Record 15 of Set 18 | miri
# City not found. Skipping...
# Processing Record 16 of Set 18 | reforma
# City not found. Skipping...
# Processing Record 17 of Set 18 | rio grande
# City not found. Skipping...
# Processing Record 18 of Set 18 | okha
# City not found. Skipping...
# Processing Record 19 of Set 18 | atambua
# City not found. Skipping...
# Processing Record 20 of Set 18 | tocopilla
# City not found. Skipping...
# Processing Record 21 of Set 18 | berbera
# City not found. Skipping...
# Processing Record 22 of Set 18 | rock sound
# City not found. Skipping...
# Processing Record 23 of Set 18 | southbridge
# City not found. Skipping...
# Processing Record 24 of Set 18 | santo tomas
# City not found. Skipping...
# Processing Record 25 of Set 18 | sibolga
# City not found. Skipping...
# Processing Record 26 of Set 18 | arraial do cabo
# City not found. Skipping...
# Processing Record 27 of Set 18 | longyearbyen
# City not found. Skipping...
# Processing Record 28 of Set 18 | khatanga
# City not found. Skipping...
# Processing Record 29 of Set 18 | riaba
# City not found. Skipping...
# Processing Record 30 of Set 18 | mbanza-ngungu
# City not found. Skipping...
# Processing Record 31 of Set 18 | hamilton
# City not found. Skipping...
# Processing Record 32 of Set 18 | meadow lake
# City not found. Skipping...
# Processing Record 33 of Set 18 | soyo
# City not found. Skipping...
# Processing Record 34 of Set 18 | strelka
# City not found. Skipping...
# Processing Record 35 of Set 18 | ribeira grande
# City not found. Skipping...
# Processing Record 36 of Set 18 | high prairie
# City not found. Skipping...
# Processing Record 37 of Set 18 | ponta do sol
# City not found. Skipping...
# Processing Record 38 of Set 18 | bandarbeyla
# City not found. Skipping...
# Processing Record 39 of Set 18 | kochubey
# City not found. Skipping...
# Processing Record 40 of Set 18 | bethel
# City not found. Skipping...
# Processing Record 41 of Set 18 | biak
# City not found. Skipping...
# Processing Record 42 of Set 18 | krasnaya zarya
# City not found. Skipping...
# Processing Record 43 of Set 18 | upernavik
# City not found. Skipping...
# Processing Record 44 of Set 18 | marabba
# City not found. Skipping...
# Processing Record 45 of Set 18 | nishihara
# City not found. Skipping...
# Processing Record 46 of Set 18 | sao filipe
# City not found. Skipping...
# Processing Record 47 of Set 18 | bengkulu
# City not found. Skipping...
# Processing Record 48 of Set 18 | okhotsk
# City not found. Skipping...
# Processing Record 49 of Set 18 | malakal
# City not found. Skipping...
# Processing Record 50 of Set 18 | los llanos de aridane
# City not found. Skipping...
# Processing Record 1 of Set 19 | orshanka
# City not found. Skipping...
# Processing Record 2 of Set 19 | wanning
# City not found. Skipping...
# Processing Record 3 of Set 19 | yar-sale
# City not found. Skipping...
# Processing Record 4 of Set 19 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 5 of Set 19 | malanje
# City not found. Skipping...
# Processing Record 6 of Set 19 | tasiilaq
# City not found. Skipping...
# Processing Record 7 of Set 19 | hualmay
# City not found. Skipping...
# Processing Record 8 of Set 19 | poum
# City not found. Skipping...
# Processing Record 9 of Set 19 | lieksa
# City not found. Skipping...
# Processing Record 10 of Set 19 | honiara
# City not found. Skipping...
# Processing Record 11 of Set 19 | torbay
# City not found. Skipping...
# Processing Record 12 of Set 19 | gat
# City not found. Skipping...
# Processing Record 13 of Set 19 | shangqiu
# City not found. Skipping...
# Processing Record 14 of Set 19 | isangel
# City not found. Skipping...
# Processing Record 15 of Set 19 | minot
# City not found. Skipping...
# Processing Record 16 of Set 19 | mpika
# City not found. Skipping...
# Processing Record 17 of Set 19 | rawson
# City not found. Skipping...
# Processing Record 18 of Set 19 | caravelas
# City not found. Skipping...
# Processing Record 19 of Set 19 | burica
# City not found. Skipping...
# Processing Record 20 of Set 19 | dwarka
# City not found. Skipping...
# Processing Record 21 of Set 19 | saldanha
# City not found. Skipping...
# Processing Record 22 of Set 19 | beaverlodge
# City not found. Skipping...
# Processing Record 23 of Set 19 | srednekolymsk
# City not found. Skipping...
# Processing Record 24 of Set 19 | severnyy
# City not found. Skipping...
# Processing Record 25 of Set 19 | berlevag
# City not found. Skipping...
# Processing Record 26 of Set 19 | dingle
# City not found. Skipping...
# Processing Record 27 of Set 19 | athabasca
# City not found. Skipping...
# Processing Record 28 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 19 | vila
# City not found. Skipping...
# Processing Record 30 of Set 19 | mukhen
# City not found. Skipping...
# Processing Record 31 of Set 19 | fuzhou
# City not found. Skipping...
# Processing Record 32 of Set 19 | axim
# City not found. Skipping...
# Processing Record 33 of Set 19 | ancud
# City not found. Skipping...
# Processing Record 34 of Set 19 | hobyo
# City not found. Skipping...
# Processing Record 35 of Set 19 | alice springs
# City not found. Skipping...
# Processing Record 36 of Set 19 | makakilo city
# City not found. Skipping...
# Processing Record 37 of Set 19 | mayo

# %%
len(city_data)
city_data
# Out:
# [{'City': 'Ocos',
#   'Lat': 14.5094,
#   'Lng': -92.1933,
#   'Max Temp': 84.31,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Country': 'GT'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 27.07,
#   'Humidity': 87,
#   'Cloudiness': 11,
#   'Wind Speed': 5.91,
#   'Country': 'CA'},
#  {'City': 'Udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 35.67,
#   'Humidity': 54,
#   'Cloudiness': 14,
#   'Wind Speed': 6.35,
#   'Country': 'RU'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 70.25,
#   'Humidity': 76,
#   'Cloudiness': 17,
#   'Wind Speed': 16.78,
#   'Country': 'MU'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 87.82,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Country': 'US'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 59.9,
#   'Humidity': 90,
#   'Cloudiness': 65,
#   'Wind Speed': 6.46,
#   'Country': 'ZA'},
#  {'City': 'Capreol',
#   'Lat': 46.706,
#   'Lng': -80.9225,
#   'Max Temp': 49.55,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'CA'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 37.11,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 14.32,
#   'Country': 'CL'},
#  {'City': 'Zachary',
#   'Lat': 30.6485,
#   'Lng': -91.1565,
#   'Max Temp': 71.73,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 60.15,
#   'Humidity': 28,
#   'Cloudiness': 6,
#   'Wind Speed': 1.59,
#   'Country': 'CN'},
#  {'City': 'Ulagan',
#   'Lat': 50.6321,
#   'Lng': 87.9563,
#   'Max Temp': 34.09,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'RU'},
#  {'City': 'Salinas',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 75.56,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'US'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'TO'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.28,
#   'Humidity': 87,
#   'Cloudiness': 26,
#   'Wind Speed': 0.78,
#   'Country': 'ZA'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 85.89,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MY'},
#  {'City': 'Sao Domingos',
#   'Lat': -13.3983,
#   'Lng': -46.3183,
#   'Max Temp': 76.1,
#   'Humidity': 54,
#   'Cloudiness': 95,
#   'Wind Speed': 3.31,
#   'Country': 'BR'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 70.72,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Country': 'PT'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 47.48,
#   'Humidity': 84,
#   'Cloudiness': 38,
#   'Wind Speed': 7.25,
#   'Country': 'NZ'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 77.9,
#   'Humidity': 80,
#   'Cloudiness': 32,
#   'Wind Speed': 15.68,
#   'Country': 'BR'},
#  {'City': 'Atraulia',
#   'Lat': 26.3333,
#   'Lng': 82.95,
#   'Max Temp': 79.27,
#   'Humidity': 84,
#   'Cloudiness': 36,
#   'Wind Speed': 4.79,
#   'Country': 'IN'},
#  {'City': 'La Trinitaria',
#   'Lat': 16.1167,
#   'Lng': -92.05,
#   'Max Temp': 60.57,
#   'Humidity': 92,
#   'Cloudiness': 61,
#   'Wind Speed': 6.04,
#   'Country': 'MX'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 61.61,
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 12.57,
#   'Country': 'ZA'},
#  {'City': 'Nakamura',
#   'Lat': 32.9833,
#   'Lng': 132.9333,
#   'Max Temp': 78.06,
#   'Humidity': 70,
#   'Cloudiness': 93,
#   'Wind Speed': 6.4,
#   'Country': 'JP'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 48.09,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 8.52,
#   'Country': 'RU'},
#  {'City': 'Zhuhai',
#   'Lat': 22.2769,
#   'Lng': 113.5678,
#   'Max Temp': 87.96,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'CN'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 64.71,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'Alpena',
#   'Lat': 45.0617,
#   'Lng': -83.4327,
#   'Max Temp': 53.11,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 52.32,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Country': 'CA'},
#  {'City': 'Harrismith',
#   'Lat': -28.2728,
#   'Lng': 29.1295,
#   'Max Temp': 59.38,
#   'Humidity': 36,
#   'Cloudiness': 9,
#   'Wind Speed': 2.28,
#   'Country': 'ZA'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 47.8,
#   'Humidity': 57,
#   'Cloudiness': 72,
#   'Wind Speed': 14.81,
#   'Country': 'NZ'},
#  {'City': 'Kosino',
#   'Lat': 58.4127,
#   'Lng': 51.2782,
#   'Max Temp': 45.16,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'RU'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 42.35,
#   'Humidity': 61,
#   'Cloudiness': 46,
#   'Wind Speed': 5.57,
#   'Country': 'US'},
#  {'City': 'Ampanihy',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 69.49,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 3.94,
#   'Country': 'MG'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 36.54,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Country': 'RU'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 86.56,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 10.87,
#   'Country': 'ML'},
#  {'City': 'Kitimat',
#   'Lat': 54.0524,
#   'Lng': -128.6534,
#   'Max Temp': 55.9,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 2.1,
#   'Country': 'CA'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 69.03,
#   'Humidity': 22,
#   'Cloudiness': 100,
#   'Wind Speed': 7.65,
#   'Country': 'AR'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 32.95,
#   'Humidity': 92,
#   'Cloudiness': 80,
#   'Wind Speed': 2.33,
#   'Country': 'AR'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 34.7,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 17.85,
#   'Country': 'CA'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 32.22,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 7.07,
#   'Country': 'GL'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.89,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 14.83,
#   'Country': 'PF'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.76,
#   'Humidity': 77,
#   'Cloudiness': 23,
#   'Wind Speed': 19.35,
#   'Country': 'PF'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 59.04,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 1.19,
#   'Country': 'AU'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 36.19,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 19.86,
#   'Country': 'RU'},
#  {'City': 'Belur',
#   'Lat': 13.1667,
#   'Lng': 75.8667,
#   'Max Temp': 65.19,
#   'Humidity': 94,
#   'Cloudiness': 83,
#   'Wind Speed': 6.02,
#   'Country': 'IN'},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 82.44,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'AU'},
#  {'City': 'Mill Valley',
#   'Lat': 37.906,
#   'Lng': -122.545,
#   'Max Temp': 75.04,
#   'Humidity': 84,
#   'Cloudiness': 18,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Alugan',
#   'Lat': 12.2188,
#   'Lng': 125.4808,
#   'Max Temp': 82.89,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 0.94,
#   'Country': 'PH'},
#  {'City': 'Mackay',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 82.69,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 7.18,
#   'Country': 'AU'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 54.1,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'AU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.51,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 8.43,
#   'Country': 'EC'},
#  {'City': 'Pabrade',
#   'Lat': 55,
#   'Lng': 25.7833,
#   'Max Temp': 50.43,
#   'Humidity': 97,
#   'Cloudiness': 17,
#   'Wind Speed': 6.58,
#   'Country': 'LT'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 53.74,
#   'Humidity': 41,
#   'Cloudiness': 7,
#   'Wind Speed': 3.65,
#   'Country': 'AU'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 33.08,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 13.22,
#   'Country': 'RU'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 61.59,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Ler',
#   'Lat': 8.3018,
#   'Lng': 30.1418,
#   'Max Temp': 68.9,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'SS'},
#  {'City': 'Nam Som',
#   'Lat': 17.7704,
#   'Lng': 102.1895,
#   'Max Temp': 76.3,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.59,
#   'Country': 'TH'},
#  {'City': 'Dandong',
#   'Lat': 40.1292,
#   'Lng': 124.3947,
#   'Max Temp': 69.17,
#   'Humidity': 76,
#   'Cloudiness': 10,
#   'Wind Speed': 3.62,
#   'Country': 'CN'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 29.91,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 10.8,
#   'Country': 'RU'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 75.69,
#   'Humidity': 37,
#   'Cloudiness': 61,
#   'Wind Speed': 2.53,
#   'Country': 'TL'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 48.24,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 9.55,
#   'Country': 'CL'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 45.41,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'CA'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 66.15,
#   'Humidity': 51,
#   'Cloudiness': 22,
#   'Wind Speed': 17.94,
#   'Country': 'AU'},
#  {'City': 'Puerto Morazan',
#   'Lat': 12.8504,
#   'Lng': -87.1717,
#   'Max Temp': 77.5,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'NI'},
#  {'City': 'Dongsheng',
#   'Lat': 39.8161,
#   'Lng': 109.9776,
#   'Max Temp': 60.12,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 9.08,
#   'Country': 'CN'},
#  {'City': 'Jinchang',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 62.69,
#   'Humidity': 45,
#   'Cloudiness': 94,
#   'Wind Speed': 2.59,
#   'Country': 'CN'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 92.23,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Myaundzha',
#   'Lat': 63.0494,
#   'Lng': 147.1858,
#   'Max Temp': 36.05,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'RU'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 73.47,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 1.1,
#   'Country': 'BR'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 54.75,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 5.55,
#   'Country': 'RO'},
#  {'City': 'Volksrust',
#   'Lat': -27.3654,
#   'Lng': 29.8818,
#   'Max Temp': 57.22,
#   'Humidity': 54,
#   'Cloudiness': 8,
#   'Wind Speed': 3.74,
#   'Country': 'ZA'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 58.32,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Country': 'US'},
#  {'City': 'Boende',
#   'Lat': -0.2167,
#   'Lng': 20.8667,
#   'Max Temp': 68.72,
#   'Humidity': 98,
#   'Cloudiness': 79,
#   'Wind Speed': 0.36,
#   'Country': 'CD'},
#  {'City': 'Illescas',
#   'Lat': 40.1221,
#   'Lng': -3.847,
#   'Max Temp': 61.61,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 6.33,
#   'Country': 'ES'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 70.25,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'PT'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 72.39,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.94,
#   'Country': 'IL'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.8,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 9.13,
#   'Country': 'BR'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 42.19,
#   'Humidity': 91,
#   'Cloudiness': 11,
#   'Wind Speed': 4.94,
#   'Country': 'CA'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 30.6,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'RU'},
#  {'City': 'Santiago Del Estero',
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp': 72.81,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Country': 'AR'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 83.52,
#   'Humidity': 40,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'US'},
#  {'City': 'Irbeyskoye',
#   'Lat': 55.6428,
#   'Lng': 95.4522,
#   'Max Temp': 36.43,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 3.47,
#   'Country': 'RU'},
#  {'City': 'Juneau',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 50.85,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Country': 'US'},
#  {'City': 'Biscarrosse',
#   'Lat': 44.3945,
#   'Lng': -1.1672,
#   'Max Temp': 66.65,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'FR'},
#  {'City': 'Limaong',
#   'Lat': 7.3606,
#   'Lng': 122.3664,
#   'Max Temp': 81.07,
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 4.47,
#   'Country': 'PH'},
#  {'City': 'Santa Lucia',
#   'Lat': 27.9117,
#   'Lng': -15.5407,
#   'Max Temp': 64.11,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'ES'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 40.69,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'IS'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 84.78,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 12.91,
#   'Country': 'NE'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.17,
#   'Humidity': 75,
#   'Cloudiness': 13,
#   'Wind Speed': 10.45,
#   'Country': 'KI'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 81.48,
#   'Humidity': 69,
#   'Cloudiness': 13,
#   'Wind Speed': 5.99,
#   'Country': 'US'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 38.73,
#   'Humidity': 66,
#   'Cloudiness': 3,
#   'Wind Speed': 6.82,
#   'Country': 'CL'},
#  {'City': 'Ust-Kut',
#   'Lat': 56.7938,
#   'Lng': 105.7672,
#   'Max Temp': 35.42,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.21,
#   'Country': 'RU'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 51.19,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 6.73,
#   'Country': 'CL'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 71.58,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'PT'},
#  {'City': 'Xuanzhou',
#   'Lat': 30.9525,
#   'Lng': 118.7553,
#   'Max Temp': 80.62,
#   'Humidity': 69,
#   'Cloudiness': 60,
#   'Wind Speed': 4.94,
#   'Country': 'CN'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 50.92,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'FO'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 62.29,
#   'Humidity': 51,
#   'Cloudiness': 12,
#   'Wind Speed': 2.98,
#   'Country': 'RU'},
#  {'City': 'Castelnaudary',
#   'Lat': 43.3183,
#   'Lng': 1.9545,
#   'Max Temp': 69.94,
#   'Humidity': 86,
#   'Cloudiness': 50,
#   'Wind Speed': 1.01,
#   'Country': 'FR'},
#  {'City': 'Coromoro',
#   'Lat': 6.2946,
#   'Lng': -73.0402,
#   'Max Temp': 61.57,
#   'Humidity': 93,
#   'Cloudiness': 25,
#   'Wind Speed': 5.88,
#   'Country': 'CO'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 56.93,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 7.34,
#   'Country': 'ZA'},
#  {'City': 'Eatonton',
#   'Lat': 33.3268,
#   'Lng': -83.3885,
#   'Max Temp': 65.77,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'US'},
#  {'City': 'Beaumont',
#   'Lat': 30.0861,
#   'Lng': -94.1019,
#   'Max Temp': 73.44,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Bottrop',
#   'Lat': 51.5167,
#   'Lng': 6.9167,
#   'Max Temp': 63.01,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Country': 'DE'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 35.19,
#   'Humidity': 87,
#   'Cloudiness': 5,
#   'Wind Speed': 6.87,
#   'Country': 'CL'},
#  {'City': 'Dukat',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': 33.22,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'RU'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 78.17,
#   'Humidity': 75,
#   'Cloudiness': 21,
#   'Wind Speed': 1.95,
#   'Country': 'CV'},
#  {'City': 'Puerto Madryn',
#   'Lat': -42.7692,
#   'Lng': -65.0385,
#   'Max Temp': 66.79,
#   'Humidity': 29,
#   'Cloudiness': 85,
#   'Wind Speed': 23.71,
#   'Country': 'AR'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 47.7,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3.49,
#   'Country': 'RU'},
#  {'City': 'Olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 76.73,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'BR'},
#  {'City': 'Tokmak',
#   'Lat': 47.2514,
#   'Lng': 35.7058,
#   'Max Temp': 55.83,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 11.77,
#   'Country': 'UA'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 71.51,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'PT'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 52.72,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 29.06,
#   'Country': 'FO'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 75.78,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 46.36,
#   'Humidity': 67,
#   'Cloudiness': 95,
#   'Wind Speed': 10.54,
#   'Country': 'NZ'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 83.93,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'US'},
#  {'City': 'Port Keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 86.52,
#   'Humidity': 51,
#   'Cloudiness': 5,
#   'Wind Speed': 7.56,
#   'Country': 'AU'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 53.28,
#   'Humidity': 93,
#   'Cloudiness': 53,
#   'Wind Speed': 2.48,
#   'Country': 'ZA'},
#  {'City': 'Libreville',
#   'Lat': 0.3925,
#   'Lng': 9.4537,
#   'Max Temp': 78.82,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'GA'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 80.06,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'BR'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 33.84,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 2.51,
#   'Country': 'RU'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 58.01,
#   'Humidity': 97,
#   'Cloudiness': 78,
#   'Wind Speed': 3.87,
#   'Country': 'UY'},
#  {'City': 'Pilar',
#   'Lat': -9.5972,
#   'Lng': -35.9567,
#   'Max Temp': 76.93,
#   'Humidity': 94,
#   'Cloudiness': 53,
#   'Wind Speed': 2.93,
#   'Country': 'BR'},
#  {'City': 'Union City',
#   'Lat': 37.5958,
#   'Lng': -122.0192,
#   'Max Temp': 78.12,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'US'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 67.19,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 37.38,
#   'Humidity': 76,
#   'Cloudiness': 5,
#   'Wind Speed': 5.53,
#   'Country': 'GL'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 74.32,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 12.5,
#   'Country': 'JP'},
#  {'City': 'Fonte Boa',
#   'Lat': -2.4959,
#   'Lng': -66.2662,
#   'Max Temp': 73.18,
#   'Humidity': 94,
#   'Cloudiness': 61,
#   'Wind Speed': 2.21,
#   'Country': 'BR'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 60.04,
#   'Humidity': 71,
#   'Cloudiness': 8,
#   'Wind Speed': 7.61,
#   'Country': 'ZA'},
#  {'City': 'Galle',
#   'Lat': 6.0367,
#   'Lng': 80.217,
#   'Max Temp': 80.04,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 14.41,
#   'Country': 'LK'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 66.25,
#   'Humidity': 98,
#   'Cloudiness': 71,
#   'Wind Speed': 4.27,
#   'Country': 'VE'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 33.17,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 12.12,
#   'Country': 'RU'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 85.71,
#   'Humidity': 70,
#   'Cloudiness': 84,
#   'Wind Speed': 6.22,
#   'Country': 'SB'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 67.55,
#   'Humidity': 87,
#   'Cloudiness': 68,
#   'Wind Speed': 12.73,
#   'Country': 'RE'},
#  {'City': 'Lakatoro',
#   'Lat': -16.0999,
#   'Lng': 167.4164,
#   'Max Temp': 79.11,
#   'Humidity': 77,
#   'Cloudiness': 58,
#   'Wind Speed': 11.32,
#   'Country': 'VU'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.34,
#   'Humidity': 49,
#   'Cloudiness': 48,
#   'Wind Speed': 12.01,
#   'Country': 'ZA'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 61.29,
#   'Humidity': 50,
#   'Cloudiness': 9,
#   'Wind Speed': 13.49,
#   'Country': 'NA'},
#  {'City': 'San Andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 82.8,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.94,
#   'Country': 'CO'},
#  {'City': 'Tungor',
#   'Lat': 53.3808,
#   'Lng': 142.9564,
#   'Max Temp': 57.63,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'RU'},
#  {'City': 'Veseloyarsk',
#   'Lat': 51.2836,
#   'Lng': 81.1056,
#   'Max Temp': 38.59,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 9.17,
#   'Country': 'RU'},
#  {'City': 'Parabel',
#   'Lat': 58.6978,
#   'Lng': 81.4825,
#   'Max Temp': 35.08,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Country': 'RU'},
#  {'City': 'Cruz Grande',
#   'Lat': 16.7333,
#   'Lng': -99.1333,
#   'Max Temp': 77.81,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'MX'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 53.04,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 13.11,
#   'Country': 'AR'},
#  {'City': 'Mesopotamia',
#   'Lat': 33,
#   'Lng': 44,
#   'Max Temp': 71.51,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 11.54,
#   'Country': 'IQ'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 78.89,
#   'Humidity': 53,
#   'Cloudiness': 6,
#   'Wind Speed': 8.81,
#   'Country': 'US'},
#  {'City': 'Belawan',
#   'Lat': 3.7755,
#   'Lng': 98.6832,
#   'Max Temp': 77.29,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 3.49,
#   'Country': 'ID'},
#  {'City': 'Atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 93.51,
#   'Humidity': 25,
#   'Cloudiness': 15,
#   'Wind Speed': 5.75,
#   'Country': 'MR'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Max Temp': 70.72,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'PT'},
#  {'City': 'Cherepovets',
#   'Lat': 59.1333,
#   'Lng': 37.9,
#   'Max Temp': 46.65,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'RU'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 72.28,
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 12.37,
#   'Country': 'JP'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 75.15,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Mangawan',
#   'Lat': 24.6833,
#   'Lng': 81.55,
#   'Max Temp': 79.57,
#   'Humidity': 79,
#   'Cloudiness': 97,
#   'Wind Speed': 2.98,
#   'Country': 'IN'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 30.22,
#   'Humidity': 89,
#   'Cloudiness': 6,
#   'Wind Speed': 9.08,
#   'Country': 'RU'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 88.21,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 1.99,
#   'Country': 'HK'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.01,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 15.59,
#   'Country': 'MV'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 35.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Davila',
#   'Lat': 18.4726,
#   'Lng': 120.5763,
#   'Max Temp': 85.53,
#   'Humidity': 69,
#   'Cloudiness': 2,
#   'Wind Speed': 8.41,
#   'Country': 'PH'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 44.46,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'AR'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 93,
#   'Humidity': 8,
#   'Cloudiness': 50,
#   'Wind Speed': 9.26,
#   'Country': 'ML'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 71.2,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.81,
#   'Country': 'PT'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 19.42,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'GL'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 58.08,
#   'Humidity': 46,
#   'Cloudiness': 2,
#   'Wind Speed': 1.99,
#   'Country': 'AR'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 66.51,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'MG'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 77.49,
#   'Humidity': 81,
#   'Cloudiness': 30,
#   'Wind Speed': 20.51,
#   'Country': 'SO'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 30.34,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 12.59,
#   'Country': 'RU'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 51.98,
#   'Humidity': 54,
#   'Cloudiness': 59,
#   'Wind Speed': 16.28,
#   'Country': 'RU'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 67.64,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'RE'},
#  {'City': 'Along',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 73.92,
#   'Humidity': 93,
#   'Cloudiness': 38,
#   'Wind Speed': 2.1,
#   'Country': 'IN'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 33.76,
#   'Humidity': 86,
#   'Cloudiness': 65,
#   'Wind Speed': 14.65,
#   'Country': 'CA'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 70.21,
#   'Humidity': 76,
#   'Cloudiness': 22,
#   'Wind Speed': 16.58,
#   'Country': 'MU'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 45.75,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'CA'},
#  {'City': 'Sishui',
#   'Lat': 35.6489,
#   'Lng': 117.2758,
#   'Max Temp': 67.15,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Country': 'CN'},
#  {'City': 'Mirabad',
#   'Lat': 30.4362,
#   'Lng': 61.8383,
#   'Max Temp': 78.73,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 7.54,
#   'Country': 'AF'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 69.75,
#   'Humidity': 78,
#   'Cloudiness': 83,
#   'Wind Speed': 9.44,
#   'Country': 'MX'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 76.75,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.28,
#   'Country': 'CI'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 64.4,
#   'Humidity': 31,
#   'Cloudiness': 61,
#   'Wind Speed': 24.16,
#   'Country': 'AR'},
#  {'City': 'Embonas',
#   'Lat': 36.2269,
#   'Lng': 27.8564,
#   'Max Temp': 68.83,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'GR'},
#  {'City': 'Darnah',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 72.55,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.98,
#   'Country': 'LY'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 83.73,
#   'Humidity': 77,
#   'Cloudiness': 64,
#   'Wind Speed': 4.88,
#   'Country': 'PH'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 24.82,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 82.49,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'OM'},
#  {'City': 'Zunyi',
#   'Lat': 27.6867,
#   'Lng': 106.9072,
#   'Max Temp': 72.12,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 5.66,
#   'Country': 'CN'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 68.31,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 10.76,
#   'Country': 'NC'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 34.54,
#   'Humidity': 57,
#   'Cloudiness': 88,
#   'Wind Speed': 3.89,
#   'Country': 'CA'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 71.89,
#   'Humidity': 83,
#   'Cloudiness': 17,
#   'Wind Speed': 21.39,
#   'Country': 'MR'},
#  {'City': 'Gorontalo',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 86.22,
#   'Humidity': 61,
#   'Cloudiness': 39,
#   'Wind Speed': 3.89,
#   'Country': 'ID'},
#  {'City': 'Damghan',
#   'Lat': 36.1683,
#   'Lng': 54.348,
#   'Max Temp': 68.47,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.93,
#   'Country': 'IR'},
#  {'City': 'Mayya',
#   'Lat': 61.7333,
#   'Lng': 130.2811,
#   'Max Temp': 36.72,
#   'Humidity': 71,
#   'Cloudiness': 54,
#   'Wind Speed': 3.96,
#   'Country': 'RU'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 40.01,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 21.07,
#   'Country': 'IS'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 72.23,
#   'Humidity': 73,
#   'Cloudiness': 87,
#   'Wind Speed': 17.85,
#   'Country': 'MX'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 52.14,
#   'Humidity': 49,
#   'Cloudiness': 82,
#   'Wind Speed': 17.02,
#   'Country': 'RU'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 61.81,
#   'Humidity': 96,
#   'Cloudiness': 25,
#   'Wind Speed': 2.17,
#   'Country': 'PT'},
#  {'City': 'Iralaya',
#   'Lat': 15,
#   'Lng': -83.2333,
#   'Max Temp': 77,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.32,
#   'Country': 'HN'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 51.69,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 12.26,
#   'Country': 'NZ'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 19.56,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Country': 'GL'},
#  {'City': 'Herat',
#   'Lat': 34.5,
#   'Lng': 62,
#   'Max Temp': 68.18,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 7.9,
#   'Country': 'AF'},
#  {'City': 'Ganta',
#   'Lat': 7.3022,
#   'Lng': -8.5308,
#   'Max Temp': 70.09,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.1,
#   'Country': 'LR'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 29.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.5,
#   'Country': 'RU'},
#  {'City': 'Jalu',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 70,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 6.62,
#   'Country': 'LY'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 37.18,
#   'Humidity': 57,
#   'Cloudiness': 28,
#   'Wind Speed': 5.19,
#   'Country': 'RU'},
#  {'City': 'Ailigandi',
#   'Lat': 9.2333,
#   'Lng': -78.0167,
#   'Max Temp': 80.73,
#   'Humidity': 87,
#   'Cloudiness': 61,
#   'Wind Speed': 4.07,
#   'Country': 'PA'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 81.07,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 4.81,
#   'Country': 'MX'},
#  {'City': 'Griffith',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 66.06,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Verkh-Usugli',
#   'Lat': 52.7,
#   'Lng': 115.1667,
#   'Max Temp': 49.78,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 2.86,
#   'Country': 'RU'},
#  {'City': 'Luba',
#   'Lat': 3.4568,
#   'Lng': 8.5547,
#   'Max Temp': 77.05,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'GQ'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 32.56,
#   'Humidity': 74,
#   'Cloudiness': 81,
#   'Wind Speed': 2.73,
#   'Country': 'RU'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 40.98,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'NO'},
#  {'City': 'Mariental',
#   'Lat': -24.6333,
#   'Lng': 17.9667,
#   'Max Temp': 68.38,
#   'Humidity': 19,
#   'Cloudiness': 7,
#   'Wind Speed': 3.83,
#   'Country': 'NA'},
#  {'City': 'Adeje',
#   'Lat': 28.1227,
#   'Lng': -16.726,
#   'Max Temp': 74.97,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'ES'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CK'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 79.03,
#   'Humidity': 77,
#   'Cloudiness': 14,
#   'Wind Speed': 18.05,
#   'Country': 'BR'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 33.84,
#   'Humidity': 62,
#   'Cloudiness': 11,
#   'Wind Speed': 9.4,
#   'Country': 'RU'},
#  {'City': 'Rongcheng',
#   'Lat': 30.634,
#   'Lng': 117.8517,
#   'Max Temp': 84.67,
#   'Humidity': 68,
#   'Cloudiness': 71,
#   'Wind Speed': 1.79,
#   'Country': 'CN'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 82.08,
#   'Humidity': 66,
#   'Cloudiness': 36,
#   'Wind Speed': 1.45,
#   'Country': 'IN'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 54.7,
#   'Humidity': 56,
#   'Cloudiness': 33,
#   'Wind Speed': 5.03,
#   'Country': 'AU'},
#  {'City': 'Churapcha',
#   'Lat': 62.0025,
#   'Lng': 132.4325,
#   'Max Temp': 38.97,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Country': 'RU'},
#  {'City': 'Aksarka',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': 30.34,
#   'Humidity': 87,
#   'Cloudiness': 48,
#   'Wind Speed': 6.87,
#   'Country': 'RU'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 32.74,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Country': 'RU'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 57.99,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'NO'},
#  {'City': 'Labytnangi',
#   'Lat': 66.6572,
#   'Lng': 66.4183,
#   'Max Temp': 28.94,
#   'Humidity': 90,
#   'Cloudiness': 59,
#   'Wind Speed': 3.31,
#   'Country': 'RU'},
#  {'City': 'Shetpe',
#   'Lat': 44.1667,
#   'Lng': 52.1167,
#   'Max Temp': 55.49,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Country': 'KZ'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 56.39,
#   'Humidity': 74,
#   'Cloudiness': 79,
#   'Wind Speed': 2.21,
#   'Country': 'JP'},
#  {'City': 'Illapel',
#   'Lat': -31.6308,
#   'Lng': -71.1653,
#   'Max Temp': 56.32,
#   'Humidity': 81,
#   'Cloudiness': 3,
#   'Wind Speed': 2.19,
#   'Country': 'CL'},
#  {'City': 'Mercedes',
#   'Lat': -34.6515,
#   'Lng': -59.4307,
#   'Max Temp': 62.85,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 7.94,
#   'Country': 'AR'},
#  {'City': 'Togur',
#   'Lat': 58.3631,
#   'Lng': 82.8265,
#   'Max Temp': 33.87,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Country': 'RU'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 83.08,
#   'Humidity': 82,
#   'Cloudiness': 12,
#   'Wind Speed': 4,
#   'Country': 'GF'},
#  {'City': 'Pimenta Bueno',
#   'Lat': -11.6725,
#   'Lng': -61.1936,
#   'Max Temp': 85.28,
#   'Humidity': 44,
#   'Cloudiness': 48,
#   'Wind Speed': 3.58,
#   'Country': 'BR'},
#  {'City': 'Petit Goave',
#   'Lat': 18.4314,
#   'Lng': -72.8669,
#   'Max Temp': 77.18,
#   'Humidity': 79,
#   'Cloudiness': 24,
#   'Wind Speed': 4.47,
#   'Country': 'HT'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 33.33,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 3.83,
#   'Country': 'RU'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 70.29,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 27.25,
#   'Country': 'BR'},
#  {'City': 'Maryville',
#   'Lat': 35.7565,
#   'Lng': -83.9705,
#   'Max Temp': 65.57,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Changji',
#   'Lat': 44.0167,
#   'Lng': 87.3167,
#   'Max Temp': 45.39,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'CN'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 82.31,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 18.28,
#   'Country': 'MV'},
#  {'City': 'Simao',
#   'Lat': 22.7886,
#   'Lng': 100.9748,
#   'Max Temp': 65.73,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'CN'},
#  {'City': 'Joshimath',
#   'Lat': 30.5667,
#   'Lng': 79.5667,
#   'Max Temp': 63.97,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4.03,
#   'Country': 'IN'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 59.47,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.16,
#   'Country': 'NZ'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 51.69,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 80.08,
#   'Humidity': 85,
#   'Cloudiness': 6,
#   'Wind Speed': 8.86,
#   'Country': 'GF'},
#  {'City': 'Kosice',
#   'Lat': 48.6667,
#   'Lng': 21.3333,
#   'Max Temp': 54.09,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'SK'},
#  {'City': 'Huambo',
#   'Lat': -12.7761,
#   'Lng': 15.7392,
#   'Max Temp': 60.6,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 2.75,
#   'Country': 'AO'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 79.16,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 8.37,
#   'Country': 'PF'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 47.82,
#   'Humidity': 71,
#   'Cloudiness': 86,
#   'Wind Speed': 11.03,
#   'Country': 'NZ'},
#  {'City': 'Kharitonovo',
#   'Lat': 61.4009,
#   'Lng': 47.4978,
#   'Max Temp': 43.47,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.99,
#   'Country': 'RU'},
#  {'City': 'Kashi',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 62.04,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'CN'},
#  {'City': 'Tottori',
#   'Lat': 35.5,
#   'Lng': 134.2333,
#   'Max Temp': 73.65,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'JP'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 73.47,
#   'Humidity': 57,
#   'Cloudiness': 4,
#   'Wind Speed': 7.7,
#   'Country': 'NU'},
#  {'City': 'Kuznetsk',
#   'Lat': 53.1167,
#   'Lng': 46.6004,
#   'Max Temp': 47.55,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'RU'},
#  {'City': 'Oranjestad',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 83.91,
#   'Humidity': 83,
#   'Cloudiness': 5,
#   'Wind Speed': 8.01,
#   'Country': 'AW'},
#  {'City': 'Zaykovo',
#   'Lat': 57.5613,
#   'Lng': 62.7568,
#   'Max Temp': 38.82,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 10.38,
#   'Country': 'RU'},
#  {'City': 'Gouloure',
#   'Lat': 12.2306,
#   'Lng': -1.9289,
#   'Max Temp': 77.7,
#   'Humidity': 68,
#   'Cloudiness': 4,
#   'Wind Speed': 7.74,
#   'Country': 'BF'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 67.75,
#   'Humidity': 79,
#   'Cloudiness': 11,
#   'Wind Speed': 12.48,
#   'Country': 'MA'},
#  {'City': 'Nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 78.89,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'ID'},
#  {'City': 'Novo Cruzeiro',
#   'Lat': -17.4681,
#   'Lng': -41.8753,
#   'Max Temp': 60.89,
#   'Humidity': 72,
#   'Cloudiness': 74,
#   'Wind Speed': 4.99,
#   'Country': 'BR'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 78.98,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 14.16,
#   'Country': 'VU'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 39.04,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'SJ'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 44.67,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 78.64,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Country': 'AU'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 52.16,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Orchard Homes',
#   'Lat': 46.8633,
#   'Lng': -114.0484,
#   'Max Temp': 78.94,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Zamardi',
#   'Lat': 46.8849,
#   'Lng': 17.9537,
#   'Max Temp': 59.95,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'HU'},
#  {'City': 'Gardelegen',
#   'Lat': 52.5252,
#   'Lng': 11.3952,
#   'Max Temp': 59.99,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Country': 'DE'},
#  {'City': 'Burnie',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 49.19,
#   'Humidity': 56,
#   'Cloudiness': 4,
#   'Wind Speed': 5.12,
#   'Country': 'AU'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 56.05,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 9.08,
#   'Country': 'CN'},
#  {'City': 'Umm Kaddadah',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 80.31,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Country': 'SD'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 20.91,
#   'Humidity': 70,
#   'Cloudiness': 97,
#   'Wind Speed': 6.62,
#   'Country': 'GL'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 39.36,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Country': 'GL'},
#  {'City': 'Quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 67.95,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'MZ'},
#  {'City': 'Maloy',
#   'Lat': 61.9353,
#   'Lng': 5.1136,
#   'Max Temp': 57.72,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 8.99,
#   'Country': 'NO'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 79.47,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Country': 'LK'},
#  {'City': 'Kajiado',
#   'Lat': -1.8524,
#   'Lng': 36.7768,
#   'Max Temp': 56.53,
#   'Humidity': 90,
#   'Cloudiness': 85,
#   'Wind Speed': 7.52,
#   'Country': 'KE'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 79.84,
#   'Humidity': 85,
#   'Cloudiness': 14,
#   'Wind Speed': 9.73,
#   'Country': 'GF'},
#  {'City': 'Kyshtovka',
#   'Lat': 56.555,
#   'Lng': 76.6271,
#   'Max Temp': 33.96,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 9.48,
#   'Country': 'RU'},
#  {'City': 'Maun',
#   'Lat': -19.9833,
#   'Lng': 23.4167,
#   'Max Temp': 66.22,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 7.18,
#   'Country': 'BW'},
#  {'City': 'Santa Cruz De Tenerife',
#   'Lat': 28.4682,
#   'Lng': -16.2546,
#   'Max Temp': 77.68,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'ES'},
#  {'City': 'Tereze',
#   'Lat': 43.9361,
#   'Lng': 42.4434,
#   'Max Temp': 36.1,
#   'Humidity': 79,
#   'Cloudiness': 2,
#   'Wind Speed': 6.96,
#   'Country': 'RU'},
#  {'City': 'Cedar City',
#   'Lat': 37.6775,
#   'Lng': -113.0619,
#   'Max Temp': 77.97,
#   'Humidity': 18,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 72.1,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'JP'},
#  {'City': 'Tamiahua',
#   'Lat': 21.2667,
#   'Lng': -97.45,
#   'Max Temp': 77.77,
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 5.08,
#   'Country': 'MX'},
#  {'City': 'Fort Portal',
#   'Lat': 0.6617,
#   'Lng': 30.2748,
#   'Max Temp': 58.05,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 1.54,
#   'Country': 'UG'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 90.07,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 61.02,
#   'Humidity': 95,
#   'Cloudiness': 47,
#   'Wind Speed': 2.46,
#   'Country': 'IT'},
#  {'City': 'Lujan',
#   'Lat': -34.5703,
#   'Lng': -59.105,
#   'Max Temp': 64.98,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AR'},
#  {'City': 'Moses Lake',
#   'Lat': 47.1301,
#   'Lng': -119.2781,
#   'Max Temp': 81.28,
#   'Humidity': 23,
#   'Cloudiness': 6,
#   'Wind Speed': 6.02,
#   'Country': 'US'},
#  {'City': 'Kostalexis',
#   'Lat': 38.8579,
#   'Lng': 22.3646,
#   'Max Temp': 56.43,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 2.01,
#   'Country': 'GR'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 60.21,
#   'Humidity': 53,
#   'Cloudiness': 68,
#   'Wind Speed': 13.06,
#   'Country': 'AU'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 27.03,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 8.21,
#   'Country': 'GL'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 56.07,
#   'Humidity': 71,
#   'Cloudiness': 21,
#   'Wind Speed': 4.52,
#   'Country': 'CA'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 31.8,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'RU'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 55.13,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CL'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 53.91,
#   'Humidity': 61,
#   'Cloudiness': 11,
#   'Wind Speed': 16.06,
#   'Country': 'CA'},
#  {'City': 'Stykkisholmur',
#   'Lat': 65.0757,
#   'Lng': -22.7297,
#   'Max Temp': 40.86,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 36.66,
#   'Country': 'IS'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 84.25,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU'},
#  {'City': 'Tiarei',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 77,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 8.88,
#   'Country': 'PF'},
#  {'City': 'Santa Maria',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 56.73,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'BR'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 67.71,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'US'},
#  {'City': 'Houma',
#   'Lat': 29.5958,
#   'Lng': -90.7195,
#   'Max Temp': 75.2,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 3.98,
#   'Country': 'US'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 81.28,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.55,
#   'Country': 'IN'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 71.67,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AU'},
#  {'City': 'Kuminskiy',
#   'Lat': 58.6667,
#   'Lng': 66.5667,
#   'Max Temp': 28.47,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 5.12,
#   'Country': 'RU'},
#  {'City': 'Khani',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 44.17,
#   'Humidity': 89,
#   'Cloudiness': 92,
#   'Wind Speed': 1.92,
#   'Country': 'GE'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 40.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 18.9,
#   'Country': 'IS'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 85.68,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'JP'},
#  {'City': 'Iqaluit',
# ...
#   'Cloudiness': 0,
#   'Wind Speed': 5.61,
#   'Country': 'MG'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 45.91,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 12.5,
#   'Country': 'NO'},
#  {'City': 'Gusau',
#   'Lat': 12.1628,
#   'Lng': 6.6614,
#   'Max Temp': 74.79,
#   'Humidity': 81,
#   'Cloudiness': 30,
#   'Wind Speed': 8.28,
#   'Country': 'NG'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 69.55,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'ES'},
#  {'City': 'Fairview',
#   'Lat': 40.8126,
#   'Lng': -73.999,
#   'Max Temp': 69.03,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'North Bend',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 62.24,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Karasburg',
#   'Lat': -28.0167,
#   'Lng': 18.75,
#   'Max Temp': 64.76,
#   'Humidity': 23,
#   'Cloudiness': 6,
#   'Wind Speed': 6.15,
#   'Country': 'NA'},
#  {'City': 'Ayr',
#   'Lat': 55.4627,
#   'Lng': -4.6339,
#   'Max Temp': 62.92,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'GB'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 53.06,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'CA'},
#  {'City': 'Songkhla',
#   'Lat': 6.8333,
#   'Lng': 100.6667,
#   'Max Temp': 75.25,
#   'Humidity': 84,
#   'Cloudiness': 65,
#   'Wind Speed': 2.24,
#   'Country': 'TH'},
#  {'City': 'Eastlake',
#   'Lat': 41.6539,
#   'Lng': -81.4504,
#   'Max Temp': 57.22,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': 53.02,
#   'Humidity': 45,
#   'Cloudiness': 15,
#   'Wind Speed': 4.5,
#   'Country': 'CA'},
#  {'City': 'Copiapo',
#   'Lat': -27.3667,
#   'Lng': -70.3333,
#   'Max Temp': 49.69,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 1.43,
#   'Country': 'CL'},
#  {'City': 'Borovskoy',
#   'Lat': 53.8,
#   'Lng': 64.15,
#   'Max Temp': 48.88,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 13.62,
#   'Country': 'KZ'},
#  {'City': 'Orlik',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 31.71,
#   'Humidity': 79,
#   'Cloudiness': 46,
#   'Wind Speed': 2.82,
#   'Country': 'RU'},
#  {'City': 'Gizo',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 84.11,
#   'Humidity': 71,
#   'Cloudiness': 80,
#   'Wind Speed': 4.29,
#   'Country': 'SB'},
#  {'City': 'Cedar Rapids',
#   'Lat': 42.0083,
#   'Lng': -91.6441,
#   'Max Temp': 65.08,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'US'},
#  {'City': 'Seoul',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 73.81,
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 3.58,
#   'Country': 'KR'},
#  {'City': 'Aktas',
#   'Lat': 49.7789,
#   'Lng': 72.9608,
#   'Max Temp': 41.83,
#   'Humidity': 34,
#   'Cloudiness': 95,
#   'Wind Speed': 5.88,
#   'Country': 'KZ'},
#  {'City': 'Buchanan',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 76.96,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'LR'},
#  {'City': 'Pierre',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp': 74.86,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 69.28,
#   'Humidity': 89,
#   'Cloudiness': 46,
#   'Wind Speed': 10.96,
#   'Country': 'EC'},
#  {'City': 'Kraskino',
#   'Lat': 42.7114,
#   'Lng': 130.7794,
#   'Max Temp': 64.81,
#   'Humidity': 87,
#   'Cloudiness': 85,
#   'Wind Speed': 1.45,
#   'Country': 'RU'},
#  {'City': 'Kondagaon',
#   'Lat': 19.6,
#   'Lng': 81.6667,
#   'Max Temp': 71.74,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Country': 'IN'},
#  {'City': 'Sandane',
#   'Lat': 61.7728,
#   'Lng': 6.215,
#   'Max Temp': 57.29,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'NO'},
#  {'City': 'Liwale',
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp': 63.1,
#   'Humidity': 96,
#   'Cloudiness': 2,
#   'Wind Speed': 1.88,
#   'Country': 'TZ'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 73,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Country': 'AO'},
#  {'City': 'Iwanai',
#   'Lat': 42.9744,
#   'Lng': 140.5089,
#   'Max Temp': 64.89,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Country': 'JP'},
#  {'City': 'Isiro',
#   'Lat': 2.7739,
#   'Lng': 27.616,
#   'Max Temp': 65.14,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'CD'},
#  {'City': 'Dom Pedrito',
#   'Lat': -30.9828,
#   'Lng': -54.6731,
#   'Max Temp': 53.98,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 5.93,
#   'Country': 'BR'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 58.42,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 0.78,
#   'Country': 'UZ'},
#  {'City': 'Beidao',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp': 61.09,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'CN'},
#  {'City': 'Yuksekova',
#   'Lat': 37.5736,
#   'Lng': 44.2872,
#   'Max Temp': 43.5,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.17,
#   'Country': 'TR'},
#  {'City': 'Rudnogorsk',
#   'Lat': 57.2639,
#   'Lng': 103.7519,
#   'Max Temp': 33.46,
#   'Humidity': 68,
#   'Cloudiness': 25,
#   'Wind Speed': 4.61,
#   'Country': 'RU'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 70.93,
#   'Humidity': 86,
#   'Cloudiness': 58,
#   'Wind Speed': 4.63,
#   'Country': 'US'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82.26,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 19.35,
#   'Country': 'MV'},
#  {'City': 'Almaznyy',
#   'Lat': 48.0448,
#   'Lng': 40.045,
#   'Max Temp': 50.14,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 12.28,
#   'Country': 'RU'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 66.61,
#   'Humidity': 55,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'AU'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 67.42,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PT'},
#  {'City': 'Palana',
#   'Lat': 59.1167,
#   'Lng': 159.9667,
#   'Max Temp': 45.34,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'RU'},
#  {'City': 'Portoferraio',
#   'Lat': 42.8115,
#   'Lng': 10.3146,
#   'Max Temp': 73.08,
#   'Humidity': 84,
#   'Cloudiness': 7,
#   'Wind Speed': 16.53,
#   'Country': 'IT'},
#  {'City': 'Manicore',
#   'Lat': -5.8092,
#   'Lng': -61.3003,
#   'Max Temp': 74.73,
#   'Humidity': 90,
#   'Cloudiness': 72,
#   'Wind Speed': 0.47,
#   'Country': 'BR'},
#  {'City': 'Puerto Leguizamo',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 68.56,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 2.51,
#   'Country': 'CO'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 46.69,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3,
#   'Country': 'RU'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 60.39,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.24,
#   'Country': 'NZ'},
#  {'City': 'Kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 64.81,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'JP'},
#  {'City': 'Cavalcante',
#   'Lat': -13.7975,
#   'Lng': -47.4583,
#   'Max Temp': 73.63,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 0.63,
#   'Country': 'BR'},
#  {'City': 'Chadiza',
#   'Lat': -14.0678,
#   'Lng': 32.4392,
#   'Max Temp': 65.01,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Country': 'ZM'},
#  {'City': 'Uyovu',
#   'Lat': -3.2833,
#   'Lng': 31.5258,
#   'Max Temp': 66.02,
#   'Humidity': 77,
#   'Cloudiness': 84,
#   'Wind Speed': 3.38,
#   'Country': 'TZ'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 31.53,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 6.44,
#   'Country': 'GL'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 55.24,
#   'Humidity': 97,
#   'Cloudiness': 65,
#   'Wind Speed': 1.16,
#   'Country': 'UY'},
#  {'City': 'Nenjiang',
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp': 58.28,
#   'Humidity': 76,
#   'Cloudiness': 72,
#   'Wind Speed': 8.28,
#   'Country': 'CN'},
#  {'City': 'Tornio',
#   'Lat': 65.8481,
#   'Lng': 24.1466,
#   'Max Temp': 37.42,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Country': 'FI'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 56.48,
#   'Humidity': 73,
#   'Cloudiness': 33,
#   'Wind Speed': 6.35,
#   'Country': 'CL'},
#  {'City': 'Inverell',
#   'Lat': -29.7833,
#   'Lng': 151.1167,
#   'Max Temp': 72.1,
#   'Humidity': 31,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Country': 'AU'},
#  {'City': 'Carhuamayo',
#   'Lat': -10.9167,
#   'Lng': -76.0333,
#   'Max Temp': 36.63,
#   'Humidity': 81,
#   'Cloudiness': 79,
#   'Wind Speed': 3.31,
#   'Country': 'PE'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 56.84,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CL'},
#  {'City': 'Gujrat',
#   'Lat': 32.5728,
#   'Lng': 74.079,
#   'Max Temp': 80.56,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 4.72,
#   'Country': 'PK'},
#  {'City': 'Bure',
#   'Lat': 10.7,
#   'Lng': 37.0667,
#   'Max Temp': 52.79,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'ET'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 68.56,
#   'Humidity': 74,
#   'Cloudiness': 6,
#   'Wind Speed': 13.04,
#   'Country': 'ZA'},
#  {'City': 'Victoria Falls',
#   'Lat': -17.9235,
#   'Lng': 25.843,
#   'Max Temp': 66.11,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.43,
#   'Country': 'ZW'},
#  {'City': 'Prachuap Khiri Khan',
#   'Lat': 12.2167,
#   'Lng': 99.75,
#   'Max Temp': 72.91,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Country': 'TH'},
#  {'City': 'Annau',
#   'Lat': 37.8876,
#   'Lng': 58.516,
#   'Max Temp': 72.9,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'TM'},
#  {'City': 'Lukulu',
#   'Lat': -14.3707,
#   'Lng': 23.242,
#   'Max Temp': 66.04,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 8.03,
#   'Country': 'ZM'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 62.17,
#   'Humidity': 89,
#   'Cloudiness': 59,
#   'Wind Speed': 6.02,
#   'Country': 'AO'},
#  {'City': 'Gilgit',
#   'Lat': 35.9221,
#   'Lng': 74.3087,
#   'Max Temp': 71.19,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 1.88,
#   'Country': 'PK'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 35.28,
#   'Humidity': 72,
#   'Cloudiness': 73,
#   'Wind Speed': 11.25,
#   'Country': 'RU'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 84.78,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'ID'},
#  {'City': 'Estelle',
#   'Lat': 29.8458,
#   'Lng': -90.1067,
#   'Max Temp': 75.2,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Divnoye',
#   'Lat': 45.9089,
#   'Lng': 43.3547,
#   'Max Temp': 51.26,
#   'Humidity': 84,
#   'Cloudiness': 4,
#   'Wind Speed': 14.5,
#   'Country': 'RU'},
#  {'City': 'Ejido',
#   'Lat': 8.5514,
#   'Lng': -71.2375,
#   'Max Temp': 65.98,
#   'Humidity': 89,
#   'Cloudiness': 16,
#   'Wind Speed': 6.98,
#   'Country': 'VE'},
#  {'City': 'Suoyarvi',
#   'Lat': 62.0833,
#   'Lng': 32.35,
#   'Max Temp': 44.31,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Country': 'RU'},
#  {'City': 'Boguchany',
#   'Lat': 58.3814,
#   'Lng': 97.4531,
#   'Max Temp': 35.55,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 3.2,
#   'Country': 'RU'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 79.48,
#   'Humidity': 80,
#   'Cloudiness': 92,
#   'Wind Speed': 10.38,
#   'Country': 'BR'},
#  {'City': 'Dutlwe',
#   'Lat': -23.9833,
#   'Lng': 23.9,
#   'Max Temp': 66.65,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 10.78,
#   'Country': 'BW'},
#  {'City': 'Camana',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 62.74,
#   'Humidity': 81,
#   'Cloudiness': 54,
#   'Wind Speed': 7.83,
#   'Country': 'PE'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 77.05,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Country': 'LR'},
#  {'City': 'Sampit',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 80.26,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 2.08,
#   'Country': 'ID'},
#  {'City': 'Jardim',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 79.79,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'BR'},
#  {'City': 'Athabasca',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': 59.97,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Country': 'CA'},
#  {'City': 'Ostersund',
#   'Lat': 63.1792,
#   'Lng': 14.6357,
#   'Max Temp': 43.25,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'SE'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 78.91,
#   'Humidity': 69,
#   'Cloudiness': 6,
#   'Wind Speed': 6.42,
#   'Country': 'AU'},
#  {'City': 'Platnirovskaya',
#   'Lat': 45.3953,
#   'Lng': 39.3842,
#   'Max Temp': 54.79,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Country': 'RU'},
#  {'City': 'Belle Fourche',
#   'Lat': 44.6714,
#   'Lng': -103.8522,
#   'Max Temp': 74.71,
#   'Humidity': 18,
#   'Cloudiness': 13,
#   'Wind Speed': 9.15,
#   'Country': 'US'},
#  {'City': 'Mumford',
#   'Lat': 5.2618,
#   'Lng': -0.759,
#   'Max Temp': 76.89,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Country': 'GH'},
#  {'City': 'Menongue',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 60.49,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AO'},
#  {'City': 'Natchitoches',
#   'Lat': 31.7668,
#   'Lng': -93.1335,
#   'Max Temp': 72.28,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Frankfort',
#   'Lat': -27.2667,
#   'Lng': 28.4833,
#   'Max Temp': 60.67,
#   'Humidity': 37,
#   'Cloudiness': 7,
#   'Wind Speed': 4.56,
#   'Country': 'ZA'},
#  {'City': 'Tromso',
#   'Lat': 69.6496,
#   'Lng': 18.957,
#   'Max Temp': 42.82,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'NO'},
#  {'City': 'Port Hawkesbury',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 64.9,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 7,
#   'Country': 'CA'},
#  {'City': 'Aitape',
#   'Lat': -3.1374,
#   'Lng': 142.3475,
#   'Max Temp': 84.56,
#   'Humidity': 73,
#   'Cloudiness': 47,
#   'Wind Speed': 4.03,
#   'Country': 'PG'},
#  {'City': 'Kizilskoye',
#   'Lat': 52.7255,
#   'Lng': 58.8937,
#   'Max Temp': 49.82,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Country': 'RU'},
#  {'City': 'Bloomingdale',
#   'Lat': 27.8936,
#   'Lng': -82.2404,
#   'Max Temp': 83.05,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Gouyave',
#   'Lat': 12.1646,
#   'Lng': -61.7296,
#   'Max Temp': 81.37,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'GD'},
#  {'City': 'San-Pedro',
#   'Lat': 4.7485,
#   'Lng': -6.6363,
#   'Max Temp': 75.81,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Country': 'CI'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 55.13,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.61,
#   'Country': 'CA'},
#  {'City': 'Prescott',
#   'Lat': 34.54,
#   'Lng': -112.4685,
#   'Max Temp': 75.69,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Heiligenhafen',
#   'Lat': 54.3667,
#   'Lng': 10.9833,
#   'Max Temp': 60.94,
#   'Humidity': 97,
#   'Cloudiness': 15,
#   'Wind Speed': 4.9,
#   'Country': 'DE'},
#  {'City': 'Manado',
#   'Lat': 1.487,
#   'Lng': 124.8455,
#   'Max Temp': 88.57,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'ID'},
#  {'City': 'Waiuku',
#   'Lat': -37.25,
#   'Lng': 174.75,
#   'Max Temp': 64.85,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Country': 'NZ'},
#  {'City': 'San Jeronimo',
#   'Lat': -11.9472,
#   'Lng': -75.2829,
#   'Max Temp': 53.49,
#   'Humidity': 64,
#   'Cloudiness': 91,
#   'Wind Speed': 3.18,
#   'Country': 'PE'}]

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
